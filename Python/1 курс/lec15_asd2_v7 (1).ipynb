# %% [markdown]
# # Лекция 15 "Поиск и сортировка."
#
# ### Финансовый университет при Правительстве РФ, лектор С.В. Макрушин
#
# __Автор: Сергей Вячеславович Макрушин__ e-mail: SVMakrushin@fa.ru
#
# Финансовый универсиет, 2021 г.
#
# v 0.7 26.04.2021

# %% [markdown]
# ## Разделы: <a class="anchor" id="разделы"></a>
#
# * [Поиск](#поиск)
#     * [Бинарный поиск](#бинарный)
# * [Сортировка](#сортировка)
# * [Простые методы сортировки](#простые-сортировки)
#     * [Обменные сортировки](#обменные-сортировки)
#     * [Сортировка выбором (извлечением)](#сортировка-выбором)
#     * [Сортировка включением (вставками)](#включением)
# * [Эффективные методы сортировки](#эффективные)
#     * [Быстрая сортировка](#быстрая)
#     * [Сортировка Шелла](#шелла)
#     * [Сортировка слиянием](#слиянием)
# * [Итоги](#итоги)
# * [Сортировка в Python](#в-python)
# -
#
# * [к оглавлению](#разделы)

# %%
# загружаем стиль для оформления презентации
from IPython.display import HTML
from urllib.request import urlopen
html = urlopen("file:./lec_v1.css")
HTML(html.read().decode('utf-8'))
# Out:
# ﻿<style>
#
#
# b.n {
#     font-weight: normal;
# }
#
# b.grbg {
#     background-color: #a0a0a0;
# }
#
# b.r {
#     color: #ff0000;
# }
#
#
# b.b {
#     color: #0000ff;
# }
#
# b.g {
#     color: #00ff00;
# }
#
#
# // add your CSS styling here
#
# list-style: none;
#
# ul.s {
# //    list-style-type: none;
#     list-style: none;
# //    background-color: #ff0000;
# //    color: #ffff00;
# //  padding-left: 1.2em;
# //  text-indent: -1.2em;
# }
#
# li.t {
#     list-style: none;
# //  padding-left: 1.2em;
# //  text-indent: -1.2em;
# }
#
#
# *.r {
#     color: #ff0000;
# }
#
# li.t:before {
#     content: "\21D2";
# //    content: "►";
# //    padding-left: -1.2em;
#     text-indent: -1.2em;
#     display: block;
#     float: left;
#
#
# //    width: 1.2em;
# //    color: #ff0000;
# }
#
# i.m:before {
#     font-style: normal;
#     content: "\21D2";
# }
# i.m {
#     font-style: normal;
# }
#
# /*--------------------*/
# /* em {
#     font-style: normal;
# } */
#
#
# em.bl {
#     font-style: normal;
#     font-weight: bold;
# }
#
# /* em.grbg {
#     font-style: normal;
#     background-color: #a0a0a0;
# } */
#
# em.cr {
#     font-style: normal;
#     color: #ff0000;
# }
#
# em.cb {
#     font-style: normal;
#     color: #0000ff;
# }
#
# em.cg {
#     font-style: normal;
#     color: #00ff00;
# }
#
# /*--------------------*/
#
# em.qs {
#     font-style: normal;
# }
#
# em.qs::before {
#     font-weight: bold;
#     color: #ff0000;
#     content: "Q:";
# }
#
# em.an {
#     font-style: normal;
# }
#
# em.an:before {
#     font-weight: bold;
#     color: #0000ff;
#     content: "A:";
# }
#
# em.nt {
#     font-style: normal;
# }
#
# em.nt:before {
#     font-weight: bold;
#     color: #0000ff;
#     content: "Note:";
# }
#
# em.ex {
#     font-style: normal;
# }
#
# em.ex:before {
#     font-weight: bold;
#     color: #00ff00;
#     content: "Ex:";
# }
#
# em.df {
#     font-style: normal;
# }
#
# em.df:before {
#     font-weight: bold;
#     color: #0000ff;
#     content: "Def:";
# }
#
# em.pl {
#     font-style: normal;
# }
#
# em.pl:before {
#     font-weight: bold;
#     color: #0000ff;
#     content: "+";
# }
#
# em.mn {
#     font-style: normal;
# }
#
# em.mn:before {
#     font-weight: bold;
#     color: #0000ff;
#     content: "-";
# }
#
# em.plmn {
#     font-style: normal;
# }
#
# em.plmn:before {
#     font-weight: bold;
#     color: #0000ff;
#     content: "\00B1";\\"&plusmn;";
# }
#
# em.hn {
#     font-style: normal;
# }
#
# em.hn:before {
#     font-weight: bold;
#     color: #0000ff;
#     content: "\21D2";\\"&rArr;";
# }
#
# </style>

# %% [markdown]
# ---
#
# ## Поиск  <a class="anchor" id="поиск"></a>
# * [к оглавлению](#разделы)

# %%
# Проверка вхождения в список:
23 in [54, 26, 93, 17, 77, 31, 44, 55, 20, 65]
# Out:
# False

# %%
17 in [54, 26, 93, 17, 77, 31, 44, 55, 20, 65]
# Out:
# True

# %%
test_list = [54, 26, 93, 17, 77, 31, 44, 55, 20, 65]

# %% [markdown]
# Пример проведения поиска в списке целых чисел:
#
# ![](seq_search_1.png)

# %%
def sequential_search(a_list, item):
    for current_item in a_list:
        if current_item == item:
            return True
    else:
        return False

# %%
test_list
# Out:
# [54, 26, 93, 17, 77, 31, 44, 55, 20, 65]

# %%
sequential_search(test_list, 15)
# Out:
# False

# %%
def sequential_search_2(a_list, item):
    pos = 0
    while pos < len(a_list):
        if a_list[pos] == item:
            return True
        else:
            pos += 1
    return False

# %%
# test_list = [54, 26, 93, 17, 77, 31, 44, 55, 20, 65]
# test_list = [1, 2, 32, 8, 17, 19, 42, 13, 0]

print(sequential_search_2(test_list, 3))
print(sequential_search_2(test_list, 17))
# Out:
# False
# True

# %% [markdown]
# Сравнение количества операций сравнения, используемых при __последовательном__ поиске в __несортированном__ списке:
#
# ![](seq_search_2.png)

# %%
def ordered_sequential_search(a_list, item):
    for current_item in a_list:
        if current_item >= item:            
            if current_item == item:
                return True
            else:
                return False
    else:
        return False

# %% [markdown]
# Сравнение количества операций сравнения, используемых при __последовательном__ поиске в __отсортированном__ списке:
#
# ![](seq_search_3.png)

# %%
ordered_test_list = sorted(test_list) 
ordered_test_list
# Out:
# [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]

# %%
print(ordered_sequential_search(ordered_test_list, 53))
print(ordered_sequential_search(ordered_test_list, 54))
# Out:
# False
# True

# %% [markdown]
# ### Бинарный поиск  <a class="anchor" id="бинарный"></a>
# * [к оглавлению](#разделы)

# %% [markdown]
# Пример проведения двоичного посика в отсортированном списке целых чисел:
#
# ![](seq_search_4.png)

# %%
def binary_search(a_list, item):
    first = 0
    last = len(a_list) - 1

    while first <= last:
        midpoint = (first + last) // 2
#         print(a_list[first:last+1], midpoint, a_list[midpoint])        
        if a_list[midpoint] == item:
            return True
        else:
            if item < a_list[midpoint]:
                last = midpoint - 1
            else:
                first = midpoint + 1
    return False

# %%
ordered_test_list
# Out:
# [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]

# %%
print(binary_search(ordered_test_list, 54))
# Out:
# [17, 20, 26, 31, 44, 54, 55, 65, 77, 93] 4 44
# [54, 55, 65, 77, 93] 7 65
# [54, 55] 5 54
# True

# %%
print(binary_search(ordered_test_list, 53))
# Out:
# [17, 20, 26, 31, 44, 54, 55, 65, 77, 93] 4 44
# [54, 55, 65, 77, 93] 7 65
# [54, 55] 5 54
# False

# %% [markdown]
# Сравнение количества оставшихся для рассмотрения элементов в зависимости от количества выполненных операций сравнения:
#
# ![](seq_search_5.png)

# %% [markdown]
# Бинарный поиск в отсортированном списке имеет сложность $O(\ln n)$.

# %% [markdown]
# * Отдельная задача: поиск строк (поиск подстрок)

# %% [markdown]
# ---
#
# ## Сортировка  <a class="anchor" id="сортировка"></a>
# * [к оглавлению](#разделы)

# %% [markdown]
# Формулировка задачи сортировки:
# * Имеется последовательность однотипных записей, одно из полей которых выбрано в качестве ключевого (ключ сортировки).
# * Тип данных ключа должен включать операции сравнения ("==", "<", и производных от них ">", ">=", "<=").
# * Требуется преобразовать исходную последовательность в последовательность, содержащую те же записи, но в порядке возрастания (или убывания) значений ключа.

# %% [markdown]
# Принято различать два типа сортировки:
# * внутренняя сортировка, в которой предполагается, что данные находятся в оперативной памяти, и важно оптимизировать число действий программы (для методов, основанных на сравнении, число сравнений, обменов элементов и пр.)
# * внешняя, в которой данные хранятся на внешнем устройстве с медленным доступом (магнитные лента, барабан, диск) и прежде всего надо снизить число обращений к этому устройству.

# %% [markdown]
# Классификация основных методов сортировки:
#
# ![](sort_1.png)

# %% [markdown]
# ---
#
# ## Простые методы сортировки  <a class="anchor" id="простые-сортировки"></a>
# * [к оглавлению](#разделы)

# %% [markdown]
# ### Обменные сортировки (Bubble Sort)  <a class="anchor" id="обменные-сортировки"></a>
# * [к оглавлению](#разделы)

# %% [markdown]
# Алгоритм прямого обмена основывается на сравнении и смене позиций пары соседних элементов. Процесс продолжается до тех
# пор, пока не будут упорядочены все элементы.

# %% [markdown]
# Пример первого прохода алгоритма сортировки пузырьком:
#
# ![](sort_2.png)

# %%
# Сортировка пузырьком:
def bubble_sort(a_list):
    for pass_num in range(len(a_list) - 1, 0, -1):
        for i in range(pass_num):
            if a_list[i] > a_list[i + 1]:
                temp = a_list[i]
                a_list[i] = a_list[i + 1]
                a_list[i + 1] = temp
    return a_list

# %%
test_list
# Out:
# [54, 26, 93, 17, 77, 31, 44, 55, 20, 65]

# %%
bubble_sort(list(test_list))
# Out:
# [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]

# %%
# Сортировка пузырьком:
def bubble_sort_2(a_list):
    for pass_num in range(len(a_list) - 1, 0, -1):
        flag = False
        for i in range(pass_num):
            if a_list[i] > a_list[i + 1]:
                temp = a_list[i]
                a_list[i] = a_list[i + 1]
                a_list[i + 1] = temp
                flag = True
        if not flag:
            return a_list

# %%
bubble_sort_2(list(test_list))
# Out:
# [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]

# %% [markdown]
# Алгоритм имеет среднюю и максимальную временные сложности $O(n^2)$ (два вложенных цикла, зависящих от n линейно). Введение переменной Flag и прерывание работы в случае отсортированного массива позволяет свести минимальную временную сложность к $O(n)$. Отметим одну особенность приведенного алгоритма: легкий пузырек снизу поднимется наверх за один проход, тяжелые пузырьки опускаются с минимальной скоростью: один шаг за итерацию.

# %% [markdown]
# ## Сортировка выбором (извлечением) (Selection Sort)  <a class="anchor" id="сортировка-выбором"></a>
# * [к оглавлению](#разделы)

# %% [markdown]
# Массив делится на уже отсортированную часть:
#
# $A_{i+1}, A_{i+2} … {А_n}$
#
# и неотсортированную:
#
# $A_1, A_2, … ,A_i$.
#
# На каждом шаге извлекается максимальный элемент из неотсортированной части и ставится в начало отсортированной части. Оптимизация по сравнению с сортировкой пузырьком происходит за счет выполнения только одного обмена за каждый проход через список. В результате каждого прохода находится наибольшее значение в неотсортированной части и устанавливается в корректное место отсортированного фрагмента массива.

# %% [markdown]
# Пример работы алгоритма сортировки выбором:
#
# ![](sort_3.png)

# %%
def selection_sort(a_list):
    for fill_slot in range(len(a_list) - 1, 0, -1):
        pos_of_max = 0
        for location in range(1, fill_slot + 1):
            if a_list[location] > a_list[pos_of_max]:
                pos_of_max = location

        temp = a_list[fill_slot]
        a_list[fill_slot] = a_list[pos_of_max]
        a_list[pos_of_max] = temp
        # Реализацию можно улучшить!
    return a_list

# %%
test_list
# Out:
# [54, 26, 93, 17, 77, 31, 44, 55, 20, 65]

# %%
selection_sort(list(test_list))
# Out:
# [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]

# %% [markdown]
# С учетом того, что количество рассматриваемых на очередном шаге элементов уменьшается на единицу, общее количество операций:
#
# $(n-1) + (n-2) + (n-3) +... + 1 = 1/2 (n-1)(n-1+1)= 1/2(n^2-n) = O(n^2)$.
#
# По сравнению с обменной сортировкой:
# * (+) существенно меньше перестановок элементов $O(n)$ по сравнению $O(n^2)$
# * (-) нет возможности быстро отсортировать почти отсортированный массив
#
# Естественной идеей улучшения алгоритма выбором является идея использования информации, полученной при сравнении элементов при поиске максимального (минимального) элемента на предыдущих шагах.
#
# В общем случае, если n – точный квадрат, можно разделить массив на $\sqrt{n}$ групп по $\sqrt{n}$ элементов и находить максимальный элемент в каждой подгруппе. Любой выбор, кроме первого, требует не более чем $\sqrt{n-2}$ сравнений внутри группы ранее выбранного элемента плюс $\sqrt{n-1}$ сравнений среди "лидеров групп“. Этот метод получил название квадратичный выбор общее время его работы составляет порядка $O(n\sqrt{n})$ что существенно лучше, чем $O(n^2)$.

# %% [markdown]
# ### Сортировка включением (вставками) (Insertion Sort)  <a class="anchor" id="включением"></a>
# * [к оглавлению](#разделы)

# %% [markdown]
# Массив делится на 2 части: отсортированную и неотсортированную. На каждом шаге берется очередной элемент из неотсортированной части и включается в отсортированную. Простое включение предполагает, что отсортировано начало массива $A_1, A_2, … ,A_{i-1}$, остаток массива $A_i,…,A_n$ – неотсортирован. На очередном шаге $A_i$ включается в отсортированную часть на соответствующее место.

# %% [markdown]
# Пример работы алгоритма сортировки включением:
#
# ![](sort_4.png)

# %% [markdown]
# Пример работы 5го прохода алгоритма сортировки включением:
#
# ![](sort_5.png)

# %%
def insertion_sort(a_list):
    for index in range(1, len(a_list)):

        current_value = a_list[index]
        position = index

        while position > 0 and a_list[position - 1] > current_value:
            a_list[position] = a_list[position - 1]
            position -= 1

        a_list[position] = current_value
    return a_list

# %%
test_list
# Out:
# [54, 26, 93, 17, 77, 31, 44, 55, 20, 65]

# %%
insertion_sort(list(test_list))
# Out:
# [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]

# %% [markdown]
# Алгоритм имеет сложность $O(n^2)$, но в случае исходно отсортированного массива внутренний цикл не будет выполняться ни разу, поэтому метод имеет в этом случае временную сложность $O(n)$.
#
# * (+) является эффективным алгоритмом для маленьких наборов данных
# * (+) на практике более эффективен, чем остальные простые квадратичные сортировки

# %% [markdown]
# ---
#
# ## Эффективные методы сортировки  <a class="anchor" id="эффективные"></a>
# * [к оглавлению](#разделы)

# %% [markdown]
# ### Сортировка Шелла (Shell Sort)  <a class="anchor" id="шелла"></a>
# * [к оглавлению](#разделы)

# %% [markdown]
# Сортировка Шелла (Donald Shell, 1959г.) является модификацией алгоритма сортировки включением, которая состоит в следующем: вместо включения A[i] в подмассив предшествующих ему элементов, его включают в подсписок, содержащий элементы A[i-h], A[i-2h], A[i-3h] и тд, где h – положительная константа. Таким образом, формируется массив, в котором «h-серии» элементов, отстоящих друг от друга на h, сортируются отдельно. Процесс возобновляется с новым значением h, меньшим предыдущего. И так до тех пор, пока не будет достигнуто значение h=1.

# %% [markdown]
# Пример работы сортировки Шелла (разбиение исходного массива с шагом 3):
#
# ![](sort_6.png)

# %% [markdown]
# Пример работы сортировки Шелла с шагом 3 (после сортировки каждого подсписка):
#
# ![](sort_7.png)

# %% [markdown]
# Пример работы последней стадии сортировки Шелла с шагом 1 (сортировка вставкой):
#
# ![](sort_8.png)

# %% [markdown]
# Пример работы сортировки Шелла (разбиение исходго массива с шагом 3):
#
# ![](sort_9.png)

# %%
# Модификация сортировки вставкой для подмассива с шагом gap и смещением start:
def gap_insertion_sort(a_list, start, gap):
    for i in range(start + gap, len(a_list), gap):
        current_value = a_list[i]
        position = i
        
        while position >= gap and a_list[position - gap] > current_value:
            a_list[position] = a_list[position - gap]
            position = position - gap

        a_list[position] = current_value

# %%
def shell_sort(a_list):
    sublist_count = len(a_list) // 2
    while sublist_count > 0:
        for start_position in range(sublist_count):
            gap_insertion_sort(a_list, start_position, sublist_count)

        print("After inc. of size", sublist_count, "Lst:", a_list)

        sublist_count = sublist_count // 2

# %%
test_list, len(test_list)
# Out:
# ([54, 26, 93, 17, 77, 31, 44, 55, 20, 65], 10)

# %%
shell_sort(list(test_list))
# Out:
# After inc. of size 5 Lst: [31, 26, 55, 17, 65, 54, 44, 93, 20, 77]
# After inc. of size 2 Lst: [20, 17, 31, 26, 44, 54, 55, 77, 65, 93]
# After inc. of size 1 Lst: [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]

# %% [markdown]
# Для достаточно больших массивов рекомендуемой считается такая последовательность, что
#
# $$h_{i+1}=3h_i+1, h_1=1$$
#
# получается последовательность : 1, 4, 13, 40, 121…($h_{i+1}=3h_i+1$)
#
# Начинается процесс с $h_{m-2}$, такого, что: $$h_{m-2} ≥ [n / 9]$$

# %% [markdown]
# Временная сложность для алгоритма Шелла – $O (n^{4/3})$ и $\Theta (n^{7/6})$, среднее число перемещений ~ $1,66n^{1,25}$.
#
# Количество перестановок элементов по результатам экспериментов со случайным массивом иллюстрируется следующей таблицей.
#
# ![](sort_10.png)

# %% [markdown]
# ### Быстрая сортировка (Quick Sort)  <a class="anchor" id="быстрая"></a>
# * [к оглавлению](#разделы)

# %% [markdown]
# Быстрая сортировка – это алгоритм сортировки, время работы которого для входного массива из n чисел в наихудшем случае равно $O(n^2)$.
# Несмотря на такую медленную работу в наихудшем случае, этот алгоритм на практике зачастую оказывается оптимальным благодаря тому, что в среднем время его работы намного лучше: $O (n \ln n)$. Кроме того, постоянные множители, не учтенные в выражении $O (n \ln n)$, достаточно малы по величине.
# Алгоритм обладает также тем преимуществом, что сортировка в нем выполняется без использования дополнительной памяти, поэтому он хорошо работает даже в средах с виртуальной памятью.

# %% [markdown]
# Алгоритм быстрой сортировки является реализацией парадигмы «разделяй и властвуй». Разделение исходного массива осуществляется по следующему принципу:
#
# 1. Выбрать наугад какой-либо элемент массива – х
# 2. Просмотреть массив слева направо, пока не обнаружим элемент $A_i$ > x
# 3. Просмотреть массив справа налево, пока не встретим $A_i$ < х
# 4. Поменять местами эти два элемента
# 5. Процесс просмотра и обмена продолжается, пока указатели обоих просмотров не встретятся

# %% [markdown]
# Пример работы быстрой сортировки (выбор элемента для разделения массива):
#
# ![](sort_11.png)

# %% [markdown]
# Пример работы быстрой сортировки (разделения массива на две части: со значениями меньшими и большими, чем у разделяющего элемента):
#
# ![](sort_12.png)

# %% [markdown]
# Пример работы быстрой сортировки (подготовка к рекурсивному вызову сортировки двух подмассивов):
#
# ![](sort_13.png)

# %%
def quick_sort(a_list):
    quick_sort_helper(a_list, 0, len(a_list) - 1)
    return a_list

def quick_sort_helper(a_list, first, last):
    if first < last:

        split_point = partition(a_list, first, last)
#         print(a_list[first:split_point-1+1], a_list[split_point], a_list[split_point + 1:last+1])
        
        quick_sort_helper(a_list, first, split_point - 1)
        quick_sort_helper(a_list, split_point + 1, last)

def partition(a_list, first, last):
    pivot_value = a_list[first]

    left_mark = first + 1
    right_mark = last

    done = False
    while not done:

        while left_mark <= right_mark and a_list[left_mark] <= pivot_value:
            left_mark = left_mark + 1

        while a_list[right_mark] >= pivot_value and right_mark >= left_mark:
            right_mark = right_mark - 1

        if right_mark < left_mark:
            done = True
        else:
            temp = a_list[left_mark]
            a_list[left_mark] = a_list[right_mark]
            a_list[right_mark] = temp

    temp = a_list[first]
    a_list[first] = a_list[right_mark]
    a_list[right_mark] = temp

    return right_mark

# %%
test_list
# Out:
# [54, 26, 93, 17, 77, 31, 44, 55, 20, 65]

# %%
quick_sort(list(test_list))
# Out:
# [31, 26, 20, 17, 44] 54 [77, 55, 93, 65]
# [17, 26, 20] 31 [44]
# [] 17 [26, 20]
# [20] 26 []
# [65, 55] 77 [93]
# [55] 65 []
# [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]

# %% [markdown]
# Ожидаемое число обменов в быстром алгоритме – $(n-1)/6$, общее число сравнений $n \ln n$. Наихудший случай – в качестве элемента для разбиения x выбирается наибольшее из всех значений в указанной области, т.е. левая часть состоит из $n-1$ элементов, а правая из 1, тогда временная сложность становится пропорциональна $n^2$.

# %% [markdown]
# ### Сортировка слиянием (Merge Sort)  <a class="anchor" id="слиянием"></a>
# * [к оглавлению](#разделы)

# %% [markdown]
# Многие полезные алгоритмы имеют рекурсивную структуру: для решения данной задачи они рекурсивно вызывают сами себя один или несколько раз, чтобы решить вспомогательную задачу, имеющую непосредственное отношение к поставленной задаче. Такие алгоритмы зачастую разрабатываются с помощью метода декомпозиции, или разбиения:
# * сложная задача разбивается на несколько более простых, которые подобны исходной задаче, но имеют меньший объем;
# * далее эти вспомогательные задачи решаются рекурсивным методом, после чего полученные решения комбинируются с целью получить решение исходной задачи.
#
# Парадигма, лежащая в основе метода декомпозиции «разделяй и властвуй», на каждом уровне рекурсии включает в себя три этапа:
# 1. Разделение задачи на несколько подзадач.
# 2. Покорение – рекурсивное решение этих подзадач. Когда объем подзадачи достаточно мал, выделенные подзадачи решаются непосредственно.
# 3. Комбинирование решения исходной задачи из решений вспомогательных задач.

# %% [markdown]
# Алгоритм сортировки слиянием (merge sort) в большой степени соответствует парадигме метода разбиения.
# На интуитивном уровне его работу можно описать таким образом.
#
#  __Разделение__: сортируемая последовательность, состоящая из n элементов, разбивается на две меньшие последовательности, каждая из которых содержит n/2 элементов.
#
#  __Покорение__: сортировка обеих вспомогательных последовательностей методом слияния.
#
#  __Комбинирование__: слияние двух отсортированных последовательностей для получения окончательного результата.
#
# Рекурсия достигает своего нижнего предела, когда длина сортируемой последовательности становится равной 1. В этом случае вся работа уже сделана, поскольку любую такую последовательность можно считать упорядоченной.
# Основная операция, которая производится в процессе сортировки по методу слияний, – это объединение двух отсортированных последовательностей в ходе комбинирования (последний этап). Это делается с помощью
# вспомогательной процедуры слияния. В этой процедуре предполагается, что элементы подмассивов упорядочены. Она сливает эти два подмассива в один отсортированный, элементы которого заменяют текущие элементы. Для выполнения этой процедуры требуется время в $O(n)$ , где $n$ – количество подлежащих слиянию элементов.
#
# Временная сложность алгоритма сортировки слиянием можно определить как $O(n \ln n)$.

# %% [markdown]
# Разбиение исходного массива в сортировке слиянием:
#
# ![](sort_14.png)

# %% [markdown]
# Слияние разбитого  массива в сортировке слиянием:
#
# ![](sort_15.png)

# %%
def merge_sort(a_list):
    print("Splitting ", a_list)
    if len(a_list) > 1:
        mid = len(a_list) // 2
        left_half = a_list[:mid]
        right_half = a_list[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = 0
        j = 0
        k = 0     
        
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                a_list[k] = left_half[i]
                i += 1
            else:
                a_list[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            a_list[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            a_list[k] = right_half[j]
            j += 1
            k += 1  
            
        print("Merging ", a_list)   
    return a_list

# %%
merge_sort(list(test_list))
# Out:
# Splitting  [54, 26, 93, 17, 77, 31, 44, 55, 20, 65]
# Splitting  [54, 26, 93, 17, 77]
# Splitting  [54, 26]
# Splitting  [54]
# Splitting  [26]
# Merging  [26, 54]
# Splitting  [93, 17, 77]
# Splitting  [93]
# Splitting  [17, 77]
# Splitting  [17]
# Splitting  [77]
# Merging  [17, 77]
# Merging  [17, 77, 93]
# Merging  [17, 26, 54, 77, 93]
# Splitting  [31, 44, 55, 20, 65]
# Splitting  [31, 44]
# Splitting  [31]
# Splitting  [44]
# Merging  [31, 44]
# Splitting  [55, 20, 65]
# Splitting  [55]
# Splitting  [20, 65]
# Splitting  [20]
# Splitting  [65]
# Merging  [20, 65]
# Merging  [20, 55, 65]
# Merging  [20, 31, 44, 55, 65]
# Merging  [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]
# [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]

# %% [markdown]
# ### Итоги  <a class="anchor" id="итоги"></a>
# * [к оглавлению](#разделы)

# %% [markdown]
# Сравнение сортировок:
#
# <img src="./img/animation of sorting algorithms2.gif" alt="Drawing" style="width: 800px;"/>
#
# http://javarevisited.blogspot.ru/2017/02/difference-between-comparison-quicksort-and-non-comparison-counting-sort-algorithms.html
#
# http://www.cprogramming.com/tutorial/computersciencetheory/sortcomp.html
#
# https://en.wikipedia.org/wiki/Sorting_algorithm

# %% [markdown]
# ## Сортировка в Python  <a class="anchor" id="в-python"></a>
# * [к оглавлению](#разделы)

# %%
colors = ['red', 'green', 'blue', 'cyan', 'magenta', 'yellow']

# %%
colors
# Out:
# ['red', 'green', 'blue', 'cyan', 'magenta', 'yellow']

# %%
# Встроенный метод для list (сортирует на месте):
colors.sort() 
# This method has the effect of reordering the elements of the list into order, 
# as deﬁned by the natural meaning of the < operator for those elements

# %%
colors
# Out:
# ['blue', 'cyan', 'green', 'magenta', 'red', 'yellow']

# %%
colors = ['red', 'green', 'blue', 'cyan', 'magenta', 'yellow']

# %%
sorted(colors) # сортирует в новом списке
# Out:
# ['blue', 'cyan', 'green', 'magenta', 'red', 'yellow']

# %%
colors
# Out:
# ['blue', 'cyan', 'green', 'magenta', 'red', 'yellow']

# %%
# задание функции для определения ключа для сортировки:
sorted(colors, key=len)
# Out:
# ['red', 'blue', 'cyan', 'green', 'yellow', 'magenta']

# %% [markdown]
# https://docs.python.org/3/howto/sorting.html#sortinghowto

# %% [markdown]
# Эффективный поиск в отсортированном списке
#
# Библиотека bisect: https://docs.python.org/3/library/bisect.html#module-bisect

# %%
from bisect import bisect_left

def binary_search(a, x, lo=0, hi=None):  # can't use a to specify default for hi
    hi = hi if hi is not None else len(a)  # hi defaults to len(a)   
    pos = bisect_left(a, x, lo, hi)  # find insertion position
    return (pos if pos != hi and a[pos] == x else None)  # don't walk off the end

# %%
test_list_s = sorted(test_list)
test_list_s
# Out:
# [17, 20, 26, 31, 44, 54, 55, 65, 77, 93]

# %%
binary_search(test_list_s, 44)
# Out:
# 4

# %%
print(binary_search(test_list_s, 45))
# Out:
# None

# %%
print(int('ff', 16))
# Out:
# 8

# %%
# Out:
# Found words: ['This', 'text', 'with', 'some', 'words']

# %% [markdown]
# 1) Необходимо отсортировать список студентов по их среднему баллу за сессию и вывести результат на экран. Использовать алгоритмы сортировки: сортировку выбором, сортировку слиянием и быструю сортировку. Сравнить время выполнения алгоритмов сортировки с помощью декоратора. Данные о студентах хранятся в файле.

# %%
import random

names = [
    "Александр", "Екатерина", "Иван", "Ольга", "Дмитрий", "Мария", "Сергей", "Анна", "Павел", "Наталья",
    "Александра", "Владимир", "Татьяна", "Алексей", "Елена", "Виктор", "Юлия", "Артем", "Светлана", "Михаил",
    "Людмила", "Николай", "Ирина", "Андрей", "Оксана", "Анастасия", "Валентин", "Ксения", "Василий", "Евгения",
    "Григорий", "Олеся", "Роман", "Дарья", "Владислав", "Лариса", "Денис", "Марина", "Артемий", "Евгений",
    "София", "Валентина", "Станислав", "Ольга", "Кирилл", "Надежда", "Петр", "Ева", "Игорь", "Алина",
    "Валерий", "Тамара", "Степан", "Лидия", "Федор", "Алла", "Ярослав", "Вера", "Станислава", "Даниил",
    "Любовь", "Сергей", "Нина", "Владислава", "Виктория", "Геннадий", "Мирослава", "Илья", "Зоя",
    "Виталий", "Елизавета", "Валерия", "Руслан", "Раиса", "Павел", "Наталья", "Лев", "Маргарита",
    "Антон",  "Галина","Владлен","Екатерина", "Хонгр", "Умар", "Расул", "Тимур", "Ву Ле", "Лала", "Марьяна", "Тимофей", 
    "Арсений", "Олег", "Аркадий", "Афанасий", "Константин", "Максим", "Андрей", "Ульяна", "Полина", "Милана"
]
 
surnames = [
    "Иванов", "Петров", "Смирнов", "Соколов", "Михайлов", "Федоров", "Волков", "Козлов", "Лебедев", "Егоров",
    "Николаев", "Кузнецов", "Павлов", "Орлов", "Алексеев", "Зайцев", "Семенов", "Голубев", "Виноградов", "Богданов",
    "Воробьев", "Фролов", "Козлов", "Степанов", "Никитин", "Морозов", "Андреев", "Ковалев", "Ильин", "Гусев",
    "Титов", "Куликов", "Ларин", "Фомин", "Давыдов", "Макаров", "Анисимов", "Горбачев", "Константинов", "Исаев",
    "Кудрявцев", "Шарапов", "Романов", "Захаров", "Беляков", "Тарасов", "Буров", "Афанасьев", "Ефимов", "Лукин"
]
 
dictt = {}
for i in range(100000):
    surname = random.choice(surnames)
    name = random.choice(names)
    mark = random.randrange(0, 100)
    dictt[name + ' ' + surname] = mark
 

cd = dictt
qd = dictt

# %%
#comb sort
def comb_sort_decorator(sort_func):
    def wrapper(d):
        start_time = time.perf_counter_ns()
        def comb_sort(arr):
            n = len(arr)
            gap = n
            while gap != 1:
                gap = int(gap * 0.8)
                for i in range(0, n - gap):
                    if arr[i][1] > arr[i + gap][1]:
                        arr[i], arr[i + gap] = arr[i + gap], arr[i]
                        swapped = True
            return arr
        
        items = list(d.items())
        sorted_items = comb_sort(items)
        sorted_dict = {k: v for k, v in sorted_items}
        print((time.perf_counter_ns() - start_time)/1000000000) 
        return sort_func(sorted_dict)
    return wrapper

@comb_sort_decorator
def process_sorted_dict(d):
    print("Отсортированный словарь:")
    return d

process_sorted_dict(cd)
# Out:
# 0.024809
# Отсортированный словарь:
# {'Владимир Гусев': 0,
#  'Расул Иванов': 0,
#  'Раиса Фролов': 0,
#  'Наталья Кудрявцев': 0,
#  'Юлия Смирнов': 0,
#  'Тимофей Орлов': 0,
#  'Лев Лебедев': 0,
#  'Светлана Анисимов': 0,
#  'Валерий Михайлов': 0,
#  'Дарья Орлов': 0,
#  'Оксана Титов': 0,
#  'Федор Фролов': 0,
#  'Виталий Федоров': 0,
#  'Станислав Исаев': 0,
#  'Галина Смирнов': 0,
#  'Дмитрий Анисимов': 0,
#  'Артемий Николаев': 0,
#  'Ирина Зайцев': 0,
#  'Валерий Иванов': 0,
#  'Лидия Лебедев': 0,
#  'Владислава Куликов': 0,
#  'Игорь Петров': 0,
#  'Михаил Захаров': 0,
#  'Людмила Ларин': 0,
#  'Станислав Павлов': 0,
#  'Надежда Зайцев': 0,
#  'Полина Ефимов': 0,
#  'Владлен Ковалев': 0,
#  'Федор Титов': 0,
#  'Ольга Беляков': 1,
#  'Тимофей Фролов': 1,
#  'Степан Волков': 1,
#  'Валентина Михайлов': 1,
#  'Елена Давыдов': 1,
#  'Виктория Ковалев': 1,
#  'Вера Морозов': 1,
#  'Владлен Федоров': 1,
#  'Оксана Михайлов': 1,
#  'Василий Богданов': 1,
#  'Павел Павлов': 1,
#  'Артем Анисимов': 1,
#  'Валерий Богданов': 1,
#  'Елена Буров': 1,
#  'Василий Ларин': 1,
#  'Николай Кузнецов': 1,
#  'Зоя Павлов': 1,
#  'Ирина Алексеев': 1,
#  'Даниил Орлов': 1,
#  'Арсений Иванов': 1,
#  'Петр Смирнов': 1,
#  'Станислав Виноградов': 1,
#  'Евгения Фролов': 1,
#  'Лариса Павлов': 1,
#  'Василий Виноградов': 1,
#  'Ирина Кудрявцев': 1,
#  'Артемий Горбачев': 1,
#  'Арсений Буров': 1,
#  'Валерий Гусев': 1,
#  'Виталий Давыдов': 1,
#  'Валерия Андреев': 1,
#  'Евгений Голубев': 1,
#  'Мирослава Анисимов': 1,
#  'Лидия Ковалев': 1,
#  'Артемий Афанасьев': 1,
#  'Милана Лебедев': 1,
#  'Лариса Семенов': 1,
#  'Павел Ильин': 1,
#  'Светлана Волков': 1,
#  'Валерия Ефимов': 1,
#  'Кирилл Давыдов': 1,
#  'Дарья Макаров': 1,
#  'Тимур Федоров': 1,
#  'Виктория Никитин': 1,
#  'Артем Волков': 1,
#  'Наталья Титов': 1,
#  'Людмила Горбачев': 1,
#  'Роман Смирнов': 1,
#  'Виктор Егоров': 1,
#  'Умар Константинов': 1,
#  'Владислава Андреев': 1,
#  'Игорь Захаров': 1,
#  'Хонгр Афанасьев': 1,
#  'Ольга Ильин': 2,
#  'Даниил Кудрявцев': 2,
#  'Степан Шарапов': 2,
#  'Афанасий Константинов': 2,
#  'Тимофей Андреев': 2,
#  'Валентин Ильин': 2,
#  'Владлен Лебедев': 2,
#  'Евгения Козлов': 2,
#  'Анастасия Лебедев': 2,
#  'Юлия Константинов': 2,
#  'Екатерина Голубев': 2,
#  'Лев Романов': 2,
#  'Владислав Макаров': 2,
#  'Милана Константинов': 2,
#  'Евгений Исаев': 2,
#  'Полина Лукин': 2,
#  'Александра Шарапов': 2,
#  'Ярослав Петров': 2,
#  'Ярослав Семенов': 2,
#  'София Иванов': 2,
#  'Юлия Михайлов': 2,
#  'Геннадий Петров': 2,
#  'Даниил Титов': 2,
#  'Тамара Шарапов': 2,
#  'Игорь Ильин': 2,
#  'Михаил Николаев': 2,
#  'Алексей Фомин': 2,
#  'Афанасий Романов': 2,
#  'Вера Зайцев': 2,
#  'Наталья Степанов': 2,
#  'Николай Волков': 2,
#  'Валерий Андреев': 2,
#  'Иван Титов': 2,
#  'Валерий Смирнов': 2,
#  'Милана Захаров': 2,
#  'Ярослав Павлов': 2,
#  'Ульяна Федоров': 2,
#  'Афанасий Исаев': 2,
#  'Тимур Орлов': 2,
#  'Степан Никитин': 2,
#  'Илья Козлов': 2,
#  'Степан Козлов': 2,
#  'Алексей Иванов': 2,
#  'Антон Анисимов': 2,
#  'Раиса Андреев': 2,
#  'Ярослав Виноградов': 2,
#  'Мария Голубев': 2,
#  'Зоя Макаров': 2,
#  'Павел Морозов': 2,
#  'Екатерина Петров': 2,
#  'Ева Морозов': 2,
#  'Евгения Захаров': 2,
#  'Екатерина Семенов': 2,
#  'Лидия Волков': 2,
#  'Алина Соколов': 2,
#  'Владимир Петров': 2,
#  'Андрей Афанасьев': 2,
#  'Александр Анисимов': 3,
#  'Надежда Смирнов': 3,
#  'Геннадий Андреев': 3,
#  'Марина Семенов': 3,
#  'Ульяна Михайлов': 3,
#  'Мирослава Романов': 3,
#  'Владлен Козлов': 3,
#  'Лев Иванов': 3,
#  'Виктория Павлов': 3,
#  'Милана Федоров': 3,
#  'Маргарита Лукин': 3,
#  'Мирослава Кузнецов': 3,
#  'Олеся Беляков': 3,
#  'Ева Волков': 3,
#  'Дмитрий Титов': 3,
#  'Ева Буров': 3,
#  'Полина Макаров': 3,
#  'Афанасий Голубев': 3,
#  'Ева Павлов': 3,
#  'Тамара Морозов': 3,
#  'Александр Буров': 3,
#  'Олег Егоров': 3,
#  'Павел Ларин': 3,
#  'Татьяна Семенов': 3,
#  'Дмитрий Ковалев': 3,
#  'Евгений Макаров': 3,
#  'Анна Никитин': 3,
#  'Даниил Ефимов': 3,
#  'Валерия Буров': 3,
#  'Валентин Романов': 3,
#  'Виталий Константинов': 3,
#  'Ксения Титов': 3,
#  'Евгений Кузнецов': 3,
#  'Максим Гусев': 3,
#  'Владимир Афанасьев': 3,
#  'Федор Лукин': 3,
#  'Галина Шарапов': 3,
#  'Станислава Беляков': 3,
#  'Михаил Павлов': 3,
#  'Елизавета Воробьев': 3,
#  'Максим Афанасьев': 3,
#  'Иван Ильин': 3,
#  'Валерия Егоров': 4,
#  'Марина Беляков': 4,
#  'Вера Павлов': 4,
#  'Милана Гусев': 4,
#  'Лариса Волков': 4,
#  'Степан Михайлов': 4,
#  'Дмитрий Афанасьев': 4,
#  'Евгений Орлов': 4,
#  'Юлия Макаров': 4,
#  'Василий Макаров': 4,
#  'София Зайцев': 4,
#  'Олеся Титов': 4,
#  'Игорь Давыдов': 4,
#  'Тамара Голубев': 4,
#  'Лев Никитин': 4,
#  'Любовь Павлов': 4,
#  'Нина Воробьев': 4,
#  'Станислава Ефимов': 4,
#  'Константин Кудрявцев': 4,
#  'Иван Куликов': 4,
#  'Олеся Федоров': 4,
#  'Владислава Егоров': 4,
#  'Умар Фомин': 4,
#  'Валерий Анисимов': 4,
#  'Полина Ильин': 4,
#  'Артем Куликов': 4,
#  'Владимир Захаров': 4,
#  'Лидия Иванов': 4,
#  'Григорий Богданов': 4,
#  'Оксана Иванов': 4,
#  'Юлия Зайцев': 4,
#  'Ярослав Горбачев': 4,
#  'Станислава Титов': 4,
#  'Роман Кузнецов': 4,
#  'Максим Морозов': 4,
#  'Александра Морозов': 4,
#  'Валерий Павлов': 4,
#  'Мария Давыдов': 4,
#  'Татьяна Голубев': 4,
#  'Афанасий Тарасов': 4,
#  'София Кузнецов': 4,
#  'Станислав Лукин': 4,
#  'Кирилл Морозов': 4,
#  'Степан Афанасьев': 5,
#  'Григорий Алексеев': 5,
#  'Лариса Гусев': 5,
#  'Умар Петров': 5,
#  'Ярослав Орлов': 5,
#  'Афанасий Кудрявцев': 5,
#  'Марина Ларин': 5,
#  'Даниил Фролов': 5,
#  'Станислава Богданов': 5,
#  'Тамара Егоров': 5,
#  'Тамара Соколов': 5,
#  'Юлия Буров': 5,
#  'Владислав Андреев': 5,
#  'Владимир Тарасов': 5,
#  'Лала Кудрявцев': 5,
#  'Алла Куликов': 5,
#  'Лала Давыдов': 5,
#  'Кирилл Романов': 5,
#  'Степан Голубев': 5,
#  'Владимир Михайлов': 5,
#  'Марина Соколов': 5,
#  'Владислава Буров': 5,
#  'Анастасия Смирнов': 5,
#  'Василий Козлов': 5,
#  'Владлен Семенов': 5,
#  'Виктор Михайлов': 5,
#  'Алина Голубев': 5,
#  'Виталий Тарасов': 5,
#  'Игорь Афанасьев': 5,
#  'Станислава Кузнецов': 5,
#  'Евгений Горбачев': 5,
#  'Наталья Виноградов': 5,
#  'Ирина Тарасов': 5,
#  'Валентин Кузнецов': 5,
#  'Расул Андреев': 5,
#  'Максим Волков': 5,
#  'Петр Никитин': 5,
#  'Елена Ковалев': 5,
#  'Мария Алексеев': 5,
#  'Александра Горбачев': 5,
#  'Екатерина Захаров': 5,
#  'Наталья Волков': 5,
#  'Милана Смирнов': 5,
#  'Кирилл Андреев': 5,
#  'Лариса Соколов': 5,
#  'Григорий Лебедев': 5,
#  'Милана Ефимов': 5,
#  'Михаил Буров': 5,
#  'Полина Буров': 5,
#  'Алексей Шарапов': 5,
#  'Тамара Лебедев': 5,
#  'Вера Куликов': 6,
#  'Нина Константинов': 6,
#  'Ву Ле Воробьев': 6,
#  'Федор Соколов': 6,
#  'Виталий Богданов': 6,
#  'Геннадий Исаев': 6,
#  'Роман Иванов': 6,
#  'Андрей Николаев': 6,
#  'Елизавета Ковалев': 6,
#  'Дмитрий Иванов': 6,
#  'Аркадий Воробьев': 6,
#  'Иван Кузнецов': 6,
#  'Елизавета Шарапов': 6,
#  'Дмитрий Лебедев': 6,
#  'Владислав Кузнецов': 6,
#  'Тимофей Голубев': 6,
#  'Наталья Петров': 6,
#  'Федор Семенов': 6,
#  'Станислава Козлов': 6,
#  'Федор Куликов': 6,
#  'Кирилл Виноградов': 6,
#  'Антон Волков': 6,
#  'Валентин Исаев': 6,
#  'Марьяна Ковалев': 6,
#  'Анна Федоров': 6,
#  'Лала Фролов': 6,
#  'Николай Павлов': 6,
#  'Виктория Горбачев': 6,
#  'Николай Горбачев': 6,
#  'Аркадий Горбачев': 6,
#  'Валентина Ларин': 6,
#  'Артем Иванов': 6,
#  'Андрей Анисимов': 6,
#  'Валерия Титов': 6,
#  'Людмила Тарасов': 6,
#  'Умар Ефимов': 6,
#  'Ульяна Алексеев': 6,
#  'Денис Давыдов': 6,
#  'Галина Егоров': 6,
#  'Наталья Куликов': 6,
#  'Станислав Козлов': 6,
#  'Лала Иванов': 6,
#  'Маргарита Кузнецов': 6,
#  'Анна Афанасьев': 6,
#  'Антон Орлов': 6,
#  'Ева Лебедев': 6,
#  'Надежда Петров': 6,
#  'Анна Волков': 6,
#  'Алина Тарасов': 6,
#  'Виктор Лебедев': 6,
#  'Роман Буров': 6,
#  'Денис Лукин': 6,
#  'Виктор Беляков': 6,
#  'Федор Ильин': 6,
#  'Нина Ковалев': 6,
#  'Артем Петров': 6,
#  'Дарья Федоров': 6,
#  'Ульяна Николаев': 6,
#  'Алина Романов': 6,
#  'Ирина Давыдов': 6,
#  'Лев Козлов': 6,
#  'Олег Лукин': 6,
#  'Андрей Морозов': 6,
#  'Василий Морозов': 6,
#  'Марьяна Титов': 7,
#  'Валентина Горбачев': 7,
#  'Тимур Макаров': 7,
#  'Валерий Давыдов': 7,
#  'Валерия Шарапов': 7,
#  'Григорий Титов': 7,
#  'Юлия Морозов': 7,
#  'Виталий Семенов': 7,
#  'Станислава Егоров': 7,
#  'Степан Смирнов': 7,
#  'Владимир Ефимов': 7,
#  'Илья Виноградов': 7,
#  'Владлен Никитин': 7,
#  'Дарья Иванов': 7,
#  'Ева Алексеев': 7,
#  'Игорь Павлов': 7,
#  'Михаил Ефимов': 7,
#  'Владислава Афанасьев': 7,
#  'Алла Ефимов': 7,
#  'Степан Титов': 7,
#  'Станислава Морозов': 7,
#  'Алексей Гусев': 7,
#  'Виктор Ковалев': 7,
#  'София Воробьев': 7,
#  'Маргарита Смирнов': 7,
#  'Руслан Андреев': 7,
#  'Павел Соколов': 7,
#  'Николай Степанов': 7,
#  'Татьяна Ефимов': 7,
#  'Роман Куликов': 7,
#  'Милана Ковалев': 7,
#  'Марина Константинов': 7,
#  'Маргарита Захаров': 7,
#  'Вера Орлов': 7,
#  'Ульяна Соколов': 7,
#  'Мария Лукин': 7,
#  'Арсений Никитин': 7,
#  'Михаил Зайцев': 7,
#  'Маргарита Афанасьев': 7,
#  'Виктория Анисимов': 7,
#  'Светлана Виноградов': 7,
#  'Тимур Воробьев': 7,
#  'Афанасий Смирнов': 7,
#  'Алексей Тарасов': 7,
#  'Даниил Федоров': 7,
#  'Руслан Шарапов': 8,
#  'Ирина Морозов': 8,
#  'Роман Федоров': 8,
#  'Тимур Шарапов': 8,
#  'Юлия Ларин': 8,
#  'Владислав Куликов': 8,
#  'Елизавета Афанасьев': 8,
#  'Геннадий Лебедев': 8,
#  'Елизавета Никитин': 8,
#  'Владислава Захаров': 8,
#  'Андрей Виноградов': 8,
#  'Степан Алексеев': 8,
#  'Алексей Константинов': 8,
#  'Ева Егоров': 8,
#  'Светлана Куликов': 8,
#  'Екатерина Смирнов': 8,
#  'Наталья Романов': 8,
#  'Вера Титов': 8,
#  'Мария Ковалев': 8,
#  'Умар Андреев': 8,
#  'Вера Кузнецов': 8,
#  'Кирилл Анисимов': 8,
#  'Зоя Богданов': 8,
#  'Анастасия Фомин': 8,
#  'Лала Виноградов': 8,
#  'Умар Голубев': 8,
#  'Хонгр Зайцев': 8,
#  'Константин Иванов': 8,
#  'Ву Ле Тарасов': 8,
#  'Вера Степанов': 8,
#  'Кирилл Павлов': 8,
#  'Афанасий Михайлов': 8,
#  'Станислава Никитин': 8,
#  'Анна Богданов': 8,
#  'Анастасия Виноградов': 8,
#  'Аркадий Буров': 8,
#  'Людмила Давыдов': 8,
#  'Марьяна Егоров': 8,
#  'Раиса Иванов': 8,
#  'Дарья Степанов': 8,
#  'Тимур Ларин': 8,
#  'Андрей Беляков': 8,
#  'Олеся Афанасьев': 8,
#  'Екатерина Титов': 8,
#  'Артемий Ефимов': 9,
#  'Лев Гусев': 9,
#  'Виктория Кузнецов': 9,
#  'Артем Гусев': 9,
#  'Петр Ильин': 9,
#  'Алла Павлов': 9,
#  'Валентин Титов': 9,
#  'Лала Титов': 9,
#  'Любовь Виноградов': 9,
#  'Галина Ковалев': 9,
#  'Виктория Виноградов': 9,
#  'Василий Алексеев': 9,
#  'Анастасия Давыдов': 9,
#  'Станислава Иванов': 9,
#  'София Павлов': 9,
#  'Умар Титов': 9,
#  'Валерия Иванов': 9,
#  'Ксения Давыдов': 9,
#  'Елена Михайлов': 9,
#  'Маргарита Анисимов': 9,
#  'Милана Богданов': 9,
#  'Андрей Лебедев': 9,
#  'Федор Анисимов': 9,
#  'Михаил Морозов': 9,
#  'Хонгр Исаев': 9,
#  'Олеся Морозов': 9,
#  'Арсений Исаев': 9,
#  'Хонгр Фролов': 9,
#  'Арсений Орлов': 9,
#  'Григорий Афанасьев': 9,
#  'Владислав Зайцев': 9,
#  'Владлен Соколов': 9,
#  'Оксана Макаров': 9,
#  'Ольга Иванов': 9,
#  'Василий Шарапов': 9,
#  'Владлен Гусев': 9,
#  'Станислав Фролов': 9,
#  'Александра Буров': 9,
#  'Вера Петров': 9,
#  'Павел Константинов': 9,
#  'Валерий Тарасов': 9,
#  'Расул Степанов': 9,
#  'Виталий Макаров': 9,
#  'Виктор Фролов': 9,
#  'Любовь Николаев': 9,
#  'Елизавета Павлов': 9,
#  'Вера Ильин': 9,
#  'Александра Воробьев': 9,
#  'Зоя Тарасов': 9,
#  'Валентин Морозов': 9,
#  'Владислава Ковалев': 9,
#  'Светлана Зайцев': 10,
#  'Лидия Титов': 10,
#  'Мирослава Титов': 10,
#  'Александра Давыдов': 10,
#  'Максим Степанов': 10,
#  'Хонгр Андреев': 10,
#  'Елена Федоров': 10,
#  'Дарья Козлов': 10,
#  'Любовь Голубев': 10,
#  'Станислав Голубев': 10,
#  'Григорий Беляков': 10,
#  'Светлана Иванов': 10,
#  'Нина Буров': 10,
#  'Станислава Анисимов': 10,
#  'Лев Давыдов': 10,
#  'Антон Ильин': 10,
#  'Илья Павлов': 10,
#  'Татьяна Федоров': 10,
#  'Арсений Фомин': 10,
#  'Валерий Титов': 10,
#  'Валерий Егоров': 10,
#  'Мария Николаев': 10,
#  'Владлен Исаев': 10,
#  'Галина Лукин': 10,
#  'Николай Смирнов': 10,
#  'Елизавета Лебедев': 10,
#  'Валерия Семенов': 10,
#  'Тимур Козлов': 10,
#  'Федор Голубев': 10,
#  'Екатерина Афанасьев': 10,
#  'Максим Воробьев': 10,
#  'Антон Лебедев': 10,
#  'Василий Иванов': 10,
#  'Вера Макаров': 10,
#  'Анастасия Буров': 10,
#  'Олег Соколов': 10,
#  'Илья Лебедев': 10,
#  'Анастасия Волков': 10,
#  'Зоя Смирнов': 10,
#  'Полина Кудрявцев': 10,
#  'Лала Петров': 10,
#  'Руслан Соколов': 10,
#  'Аркадий Куликов': 10,
#  'Тимур Кудрявцев': 10,
#  'Елизавета Морозов': 10,
#  'Денис Воробьев': 11,
#  'Геннадий Константинов': 11,
#  'Руслан Иванов': 11,
#  'Лала Смирнов': 11,
#  'Артемий Степанов': 11,
#  'Александр Лукин': 11,
#  'Оксана Кудрявцев': 11,
#  'Татьяна Морозов': 11,
#  'Раиса Егоров': 11,
#  'Маргарита Константинов': 11,
#  'Кирилл Воробьев': 11,
#  'Геннадий Ковалев': 11,
#  'Степан Буров': 11,
#  'Виктория Куликов': 11,
#  'Алина Макаров': 11,
#  'Галина Кузнецов': 11,
#  'Арсений Федоров': 11,
#  'Алина Кузнецов': 11,
#  'Лидия Давыдов': 11,
#  'Ирина Козлов': 11,
#  'Валентин Степанов': 11,
#  'Валентин Беляков': 11,
#  'Умар Куликов': 11,
#  'Иван Кудрявцев': 11,
#  'Станислава Виноградов': 11,
#  'Валерия Голубев': 11,
#  'Павел Афанасьев': 11,
#  'Светлана Ильин': 11,
#  'Ву Ле Захаров': 11,
#  'Мирослава Зайцев': 11,
#  'Наталья Николаев': 11,
#  'Ву Ле Голубев': 11,
#  'Арсений Лебедев': 11,
#  'Олег Шарапов': 11,
#  'Мирослава Иванов': 11,
#  'Геннадий Волков': 11,
#  'Анна Козлов': 11,
#  'Константин Ковалев': 11,
#  'Роман Шарапов': 11,
#  'Лидия Романов': 11,
#  'Станислав Ильин': 11,
#  'Светлана Афанасьев': 11,
#  'Юлия Тарасов': 11,
#  'Наталья Морозов': 11,
#  'Валерий Горбачев': 11,
#  'Денис Константинов': 11,
#  'Валерий Виноградов': 11,
#  'Екатерина Николаев': 12,
#  'Ксения Соколов': 12,
#  'Андрей Захаров': 12,
#  'Хонгр Захаров': 12,
#  'Алексей Михайлов': 12,
#  'Геннадий Ефимов': 12,
#  'Ву Ле Никитин': 12,
#  'Сергей Титов': 12,
#  'Наталья Лукин': 12,
#  'Валерия Кузнецов': 12,
#  'Алексей Анисимов': 12,
#  'Марина Петров': 12,
#  'Ирина Никитин': 12,
#  'Тимофей Кузнецов': 12,
#  'Анна Михайлов': 12,
#  'Дмитрий Петров': 12,
#  'Екатерина Степанов': 12,
#  'Константин Куликов': 12,
#  'Расул Соколов': 12,
#  'Геннадий Семенов': 12,
#  'Евгения Лукин': 12,
#  'Станислав Семенов': 12,
#  'Антон Тарасов': 12,
#  'Анна Кузнецов': 12,
#  'Олег Федоров': 12,
#  'Умар Алексеев': 12,
#  'Ева Титов': 12,
#  'Алексей Ковалев': 12,
#  'Елизавета Куликов': 12,
#  'Михаил Никитин': 12,
#  'Кирилл Шарапов': 12,
#  'Ольга Зайцев': 12,
#  'Ольга Лукин': 12,
#  'Тимур Тарасов': 12,
#  'Дарья Михайлов': 12,
#  'Мария Гусев': 12,
#  'Евгения Зайцев': 12,
#  'Расул Алексеев': 12,
#  'Ву Ле Петров': 12,
#  'Степан Беляков': 12,
#  'Иван Алексеев': 12,
#  'Геннадий Фролов': 12,
#  'Наталья Гусев': 12,
#  'Андрей Ковалев': 12,
#  'Петр Голубев': 12,
#  'Оксана Давыдов': 12,
#  'Ева Кудрявцев': 13,
#  'Станислава Давыдов': 13,
#  'Ксения Тарасов': 13,
#  'Ву Ле Романов': 13,
#  'Оксана Алексеев': 13,
#  'Григорий Ильин': 13,
#  'Алла Ларин': 13,
#  'Максим Виноградов': 13,
#  'София Макаров': 13,
#  'Петр Захаров': 13,
#  'Светлана Воробьев': 13,
#  'Антон Семенов': 13,
#  'Елена Виноградов': 13,
#  'Людмила Захаров': 13,
#  'Валерия Макаров': 13,
#  'Федор Кузнецов': 13,
#  'Кирилл Макаров': 13,
#  'Василий Голубев': 13,
#  'Константин Лукин': 13,
#  'Мирослава Буров': 13,
#  'Кирилл Гусев': 13,
#  'Оксана Буров': 13,
#  'Денис Кузнецов': 13,
#  'Расул Константинов': 13,
#  'Роман Зайцев': 13,
#  'Иван Орлов': 13,
#  'Нина Кузнецов': 13,
#  'Зоя Козлов': 13,
#  'Владимир Федоров': 13,
#  'Зоя Титов': 13,
#  'Тимофей Козлов': 13,
#  'Андрей Романов': 13,
#  'Константин Богданов': 13,
#  'София Буров': 13,
#  'Валерия Горбачев': 13,
#  'Маргарита Семенов': 13,
#  'Арсений Козлов': 13,
#  'Андрей Волков': 14,
#  'Алла Фролов': 14,
#  'София Волков': 14,
#  'Ксения Афанасьев': 14,
#  'Петр Фомин': 14,
#  'Ксения Павлов': 14,
#  'Лев Николаев': 14,
#  'Владислав Фролов': 14,
#  'Ву Ле Буров': 14,
#  'Василий Никитин': 14,
#  'Алина Егоров': 14,
#  'Федор Воробьев': 14,
#  'Руслан Павлов': 14,
#  'Валерий Фролов': 14,
#  'Дмитрий Козлов': 14,
#  'Валентин Голубев': 14,
#  'Екатерина Горбачев': 14,
#  'Надежда Андреев': 14,
#  'Геннадий Гусев': 14,
#  'Владислава Воробьев': 14,
#  'Игорь Фролов': 14,
#  'София Богданов': 14,
#  'Ксения Буров': 14,
#  'Аркадий Иванов': 14,
#  'Марьяна Федоров': 14,
#  'Маргарита Фролов': 14,
#  'Василий Андреев': 14,
#  'Тамара Ларин': 14,
#  'Григорий Андреев': 14,
#  'Тимофей Афанасьев': 14,
#  'Умар Семенов': 14,
#  'Оксана Горбачев': 14,
#  'Марина Куликов': 14,
#  'Игорь Михайлов': 14,
#  'Олеся Лукин': 14,
#  'Алла Захаров': 14,
#  'Виктор Федоров': 14,
#  'Артемий Павлов': 14,
#  'Владислава Зайцев': 14,
#  'Александра Анисимов': 14,
#  'Алина Беляков': 14,
#  'Тимур Беляков': 14,
#  'Аркадий Ильин': 14,
#  'Владимир Виноградов': 14,
#  'Степан Гусев': 14,
#  'Геннадий Ларин': 14,
#  'Вера Волков': 14,
#  'Игорь Анисимов': 14,
#  'Павел Кузнецов': 15,
#  'Валерия Афанасьев': 15,
#  'Владислав Романов': 15,
#  'Хонгр Иванов': 15,
#  'Александра Козлов': 15,
#  'Андрей Давыдов': 15,
#  'Василий Константинов': 15,
#  'Марина Афанасьев': 15,
#  'Лидия Алексеев': 15,
#  'Надежда Ковалев': 15,
#  'Умар Захаров': 15,
#  'Илья Ларин': 15,
#  'Артемий Шарапов': 15,
#  'Лариса Зайцев': 15,
#  'Тимур Исаев': 15,
#  'Артем Михайлов': 15,
#  'Олеся Соколов': 15,
#  'Тимофей Павлов': 15,
#  'Мария Фролов': 15,
#  'Иван Захаров': 15,
#  'Антон Буров': 15,
#  'Лев Виноградов': 15,
#  'Виталий Степанов': 15,
#  'Александр Николаев': 15,
#  'Алла Афанасьев': 15,
#  'Станислав Кузнецов': 15,
#  'Ирина Захаров': 15,
#  'Игорь Лебедев': 15,
#  'Хонгр Ефимов': 15,
#  'Умар Никитин': 15,
#  'Ярослав Буров': 15,
#  'Алексей Андреев': 15,
#  'Виктор Анисимов': 16,
#  'Валерия Зайцев': 16,
#  'Владислава Смирнов': 16,
#  'Лала Соколов': 16,
#  'Григорий Куликов': 16,
#  'Наталья Андреев': 16,
#  'Денис Соколов': 16,
#  'Вера Лукин': 16,
#  'Мирослава Михайлов': 16,
#  'Валерий Семенов': 16,
#  'Анна Виноградов': 16,
#  'Маргарита Макаров': 16,
#  'Полина Исаев': 16,
#  'Марина Фомин': 16,
#  'Анастасия Беляков': 16,
#  'Илья Воробьев': 16,
#  'Ирина Петров': 16,
#  'Раиса Ильин': 16,
#  'Милана Семенов': 16,
#  'Лев Андреев': 16,
#  'Тамара Буров': 16,
#  'Владислава Иванов': 16,
#  'Арсений Горбачев': 16,
#  'Хонгр Николаев': 16,
#  'Владислав Ларин': 16,
#  'Валентин Лукин': 16,
#  'Нина Титов': 16,
#  'Антон Давыдов': 16,
#  'Любовь Фомин': 16,
#  'Валерия Беляков': 16,
#  'Виктория Константинов': 16,
#  'Дмитрий Захаров': 16,
#  'Аркадий Лебедев': 16,
#  'Игорь Козлов': 16,
#  'Лев Куликов': 16,
#  'Олеся Давыдов': 17,
#  'Лала Алексеев': 17,
#  'Полина Егоров': 17,
#  'Людмила Никитин': 17,
#  'Александр Иванов': 17,
#  'Наталья Ковалев': 17,
#  'Зоя Гусев': 17,
#  'Игорь Титов': 17,
#  'Мария Горбачев': 17,
#  'Владислав Виноградов': 17,
#  'Алина Фомин': 17,
#  'Анна Давыдов': 17,
#  'Николай Лукин': 17,
#  'Ирина Виноградов': 17,
#  'Олеся Голубев': 17,
#  'Расул Гусев': 17,
#  'Ирина Иванов': 17,
#  'Афанасий Буров': 17,
#  'Антон Зайцев': 17,
#  'Дмитрий Романов': 17,
#  'Марьяна Иванов': 17,
#  'Лариса Анисимов': 17,
#  'Умар Фролов': 17,
#  'Валентин Константинов': 17,
#  'Тимофей Кудрявцев': 17,
#  'Илья Захаров': 17,
#  'Игорь Голубев': 17,
#  'Григорий Романов': 17,
#  'Кирилл Егоров': 17,
#  'Расул Петров': 17,
#  'Андрей Макаров': 17,
#  'Артем Исаев': 17,
#  'Лев Степанов': 17,
#  'Умар Беляков': 17,
#  'Анна Орлов': 17,
#  'Ву Ле Титов': 17,
#  'Мирослава Ковалев': 17,
#  'Арсений Петров': 17,
#  'Ирина Соколов': 17,
#  'Ева Фролов': 17,
#  'Людмила Михайлов': 17,
#  'Алина Шарапов': 17,
#  'Михаил Куликов': 17,
#  'Ольга Ларин': 17,
#  'Геннадий Иванов': 17,
#  'Галина Иванов': 17,
#  'Даниил Фомин': 17,
#  'Федор Андреев': 17,
#  'Нина Иванов': 17,
#  'Алла Макаров': 17,
#  'Петр Тарасов': 17,
#  'Владимир Куликов': 17,
#  'Маргарита Горбачев': 17,
#  'Анастасия Орлов': 18,
#  'Марина Давыдов': 18,
#  'Максим Исаев': 18,
#  'София Ковалев': 18,
#  'Екатерина Гусев': 18,
#  'Елизавета Титов': 18,
#  'Владлен Кузнецов': 18,
#  'Виталий Зайцев': 18,
#  'Валентина Андреев': 18,
#  'Григорий Волков': 18,
#  'Людмила Федоров': 18,
#  'Виктория Смирнов': 18,
#  'Сергей Воробьев': 18,
#  'Олеся Андреев': 18,
#  'Лала Лукин': 18,
#  'Тимофей Ефимов': 18,
#  'Афанасий Егоров': 18,
#  'Полина Анисимов': 18,
#  'Виктор Захаров': 18,
#  'Сергей Лебедев': 18,
#  'Степан Андреев': 18,
#  'Татьяна Козлов': 18,
#  'Полина Лебедев': 18,
#  'Аркадий Николаев': 18,
#  'Анастасия Никитин': 18,
#  'Галина Богданов': 18,
#  'Станислава Ларин': 18,
#  'Валентин Кудрявцев': 18,
#  'Иван Фролов': 18,
#  'Руслан Ларин': 18,
#  'Валерий Куликов': 18,
#  'Владислав Морозов': 18,
#  'Денис Макаров': 18,
#  'Владислава Горбачев': 18,
#  'Валентина Морозов': 18,
#  'Валентина Волков': 19,
#  'Наталья Павлов': 19,
#  'Михаил Воробьев': 19,
#  'Владислава Титов': 19,
#  'Александра Фомин': 19,
#  'Станислав Давыдов': 19,
#  'Елизавета Беляков': 19,
#  'Галина Кудрявцев': 19,
#  'Расул Макаров': 19,
#  'Лев Анисимов': 19,
#  'Тимофей Ковалев': 19,
#  'Елена Павлов': 19,
#  'Ева Афанасьев': 19,
#  'Елизавета Фролов': 19,
#  'Светлана Семенов': 19,
#  'Полина Петров': 19,
#  'Расул Смирнов': 19,
#  'Маргарита Никитин': 19,
#  'Ву Ле Николаев': 19,
#  'София Куликов': 19,
#  'Светлана Алексеев': 19,
#  'Мирослава Куликов': 19,
#  'Иван Соколов': 19,
#  'Виктор Волков': 19,
#  'Мирослава Волков': 19,
#  'Лидия Ларин': 19,
#  'Зоя Ковалев': 19,
#  'Максим Николаев': 19,
#  'Галина Павлов': 19,
#  'Владимир Волков': 19,
#  'Сергей Смирнов': 19,
#  'Сергей Буров': 19,
#  'Елизавета Ефимов': 19,
#  'Раиса Алексеев': 19,
#  'Павел Виноградов': 19,
#  'Ву Ле Горбачев': 19,
#  'Валерия Орлов': 19,
#  'Василий Давыдов': 19,
#  'Геннадий Козлов': 19,
#  'Юлия Иванов': 19,
#  'Евгений Буров': 19,
#  'Алина Горбачев': 20,
#  'Ксения Исаев': 20,
#  'Валерий Буров': 20,
#  'Афанасий Давыдов': 20,
#  'Александра Петров': 20,
#  'Игорь Соколов': 20,
#  'Елена Егоров': 20,
#  'Лидия Голубев': 20,
#  'Алла Смирнов': 20,
#  'Андрей Петров': 20,
#  'Маргарита Зайцев': 20,
#  'Дмитрий Алексеев': 20,
#  'Кирилл Никитин': 20,
#  'Ирина Лукин': 20,
#  'Владислав Козлов': 20,
#  'Афанасий Николаев': 20,
#  'Мария Козлов': 20,
#  'Ву Ле Иванов': 20,
#  'Евгений Гусев': 20,
#  'Елизавета Константинов': 20,
#  'Ксения Михайлов': 20,
#  'Анна Константинов': 20,
#  'Екатерина Волков': 20,
#  'Галина Фролов': 20,
#  'Алексей Захаров': 20,
#  'Артем Кудрявцев': 20,
#  'Марина Алексеев': 20,
#  'Алла Фомин': 20,
#  'Николай Фомин': 20,
#  'Станислава Кудрявцев': 20,
#  'Константин Федоров': 20,
#  'Михаил Федоров': 20,
#  'Ксения Орлов': 20,
#  'Екатерина Орлов': 20,
#  'Наталья Смирнов': 20,
#  'Зоя Ильин': 20,
#  'Ярослав Волков': 20,
#  'Константин Волков': 20,
#  'Умар Федоров': 20,
#  'Константин Морозов': 20,
#  'Надежда Павлов': 20,
#  'Владислава Федоров': 21,
#  'Елена Фролов': 21,
#  'Марьяна Гусев': 21,
#  'Евгения Макаров': 21,
#  'Татьяна Волков': 21,
#  'Валерия Захаров': 21,
#  'Алла Волков': 21,
#  'Олеся Степанов': 21,
#  'Сергей Тарасов': 21,
#  'Елена Анисимов': 21,
#  'Расул Захаров': 21,
#  'Надежда Шарапов': 21,
#  'Василий Михайлов': 21,
#  'Валентин Зайцев': 21,
#  'Илья Макаров': 21,
#  'Дарья Давыдов': 21,
#  'Геннадий Шарапов': 21,
#  'Наталья Ильин': 21,
#  'Григорий Морозов': 21,
#  'Аркадий Давыдов': 21,
#  'Оксана Фролов': 21,
#  'Максим Тарасов': 21,
#  'Милана Степанов': 21,
#  'Александра Фролов': 21,
#  'Федор Фомин': 21,
#  'Мария Виноградов': 21,
#  'Ульяна Ларин': 21,
#  'Умар Егоров': 21,
#  'Марьяна Ларин': 21,
#  'Владимир Ильин': 21,
#  'Валентина Петров': 21,
#  'Лариса Лебедев': 21,
#  'Михаил Горбачев': 21,
#  'Артемий Гусев': 21,
#  'Евгения Фомин': 22,
#  'Антон Павлов': 22,
#  'Федор Гусев': 22,
#  'Руслан Константинов': 22,
#  'Олеся Петров': 22,
#  'Анна Иванов': 22,
#  'Виктория Орлов': 22,
#  'Ксения Николаев': 22,
#  'Афанасий Виноградов': 22,
#  'Анастасия Козлов': 22,
#  'Павел Буров': 22,
#  'Петр Волков': 22,
#  'Ксения Голубев': 22,
#  'Владлен Павлов': 22,
#  'Артемий Соколов': 22,
#  'Руслан Буров': 22,
#  'Алексей Алексеев': 22,
#  'Алексей Павлов': 22,
#  'Валентина Лукин': 22,
#  'Даниил Павлов': 22,
#  'Олег Горбачев': 22,
#  'Роман Никитин': 22,
#  'Марина Голубев': 22,
#  'София Алексеев': 22,
#  'Дмитрий Соколов': 22,
#  'Екатерина Лебедев': 22,
#  'Владлен Романов': 22,
#  ...}

# %%
#quick comb

def quick_sort_decorator(sort_func):
    def wrapper(d):
        start_time = time.perf_counter_ns()
        def quick_sort(arr):
            if len(arr) <= 1:
                return arr
            else:
                pivot = arr[len(arr) // 2][1]
                left = [x for x in arr if x[1] < pivot]
                middle = [x for x in arr if x[1] == pivot]
                right = [x for x in arr if x[1] > pivot]
                return quick_sort(left) + middle + quick_sort(right)
        
        items = list(d.items())
        sorted_items = quick_sort(items)
        sorted_dict = {k: v for k, v in sorted_items}
        print((time.perf_counter_ns() - start_time)/1000000000) 
        return sort_func(sorted_dict)

    return wrapper

# Пример функции, которая будет использовать отсортированный словарь
@quick_sort_decorator
def process_sorted_dict(d):
    print("Отсортированный словарь:")
    return d


process_sorted_dict(qd)
# Out:
# 0.006295
# Отсортированный словарь:
# {'Галина Смирнов': 0,
#  'Полина Ефимов': 0,
#  'Светлана Анисимов': 0,
#  'Лидия Лебедев': 0,
#  'Дмитрий Анисимов': 0,
#  'Владислава Куликов': 0,
#  'Оксана Титов': 0,
#  'Юлия Смирнов': 0,
#  'Федор Титов': 0,
#  'Раиса Фролов': 0,
#  'Артемий Николаев': 0,
#  'Дарья Орлов': 0,
#  'Станислав Павлов': 0,
#  'Валерий Иванов': 0,
#  'Федор Фролов': 0,
#  'Валерий Михайлов': 0,
#  'Наталья Кудрявцев': 0,
#  'Ирина Зайцев': 0,
#  'Станислав Исаев': 0,
#  'Надежда Зайцев': 0,
#  'Игорь Петров': 0,
#  'Михаил Захаров': 0,
#  'Людмила Ларин': 0,
#  'Расул Иванов': 0,
#  'Виталий Федоров': 0,
#  'Тимофей Орлов': 0,
#  'Владимир Гусев': 0,
#  'Лев Лебедев': 0,
#  'Владлен Ковалев': 0,
#  'Евгения Фролов': 1,
#  'Виктор Егоров': 1,
#  'Даниил Орлов': 1,
#  'Виктория Ковалев': 1,
#  'Артемий Афанасьев': 1,
#  'Василий Богданов': 1,
#  'Умар Константинов': 1,
#  'Наталья Титов': 1,
#  'Станислав Виноградов': 1,
#  'Артем Анисимов': 1,
#  'Евгений Голубев': 1,
#  'Артемий Горбачев': 1,
#  'Мирослава Анисимов': 1,
#  'Кирилл Давыдов': 1,
#  'Дарья Макаров': 1,
#  'Милана Лебедев': 1,
#  'Артем Волков': 1,
#  'Лидия Ковалев': 1,
#  'Елена Давыдов': 1,
#  'Степан Волков': 1,
#  'Валерия Андреев': 1,
#  'Игорь Захаров': 1,
#  'Хонгр Афанасьев': 1,
#  'Ирина Кудрявцев': 1,
#  'Виталий Давыдов': 1,
#  'Василий Ларин': 1,
#  'Лариса Павлов': 1,
#  'Виктория Никитин': 1,
#  'Ирина Алексеев': 1,
#  'Лариса Семенов': 1,
#  'Людмила Горбачев': 1,
#  'Ольга Беляков': 1,
#  'Тимофей Фролов': 1,
#  'Валерий Богданов': 1,
#  'Валерия Ефимов': 1,
#  'Светлана Волков': 1,
#  'Вера Морозов': 1,
#  'Роман Смирнов': 1,
#  'Валентина Михайлов': 1,
#  'Павел Павлов': 1,
#  'Павел Ильин': 1,
#  'Арсений Иванов': 1,
#  'Владлен Федоров': 1,
#  'Валерий Гусев': 1,
#  'Оксана Михайлов': 1,
#  'Петр Смирнов': 1,
#  'Василий Виноградов': 1,
#  'Елена Буров': 1,
#  'Арсений Буров': 1,
#  'Тимур Федоров': 1,
#  'Владислава Андреев': 1,
#  'Николай Кузнецов': 1,
#  'Зоя Павлов': 1,
#  'Алексей Фомин': 2,
#  'Евгения Козлов': 2,
#  'Владимир Петров': 2,
#  'Алексей Иванов': 2,
#  'Ольга Ильин': 2,
#  'Ярослав Петров': 2,
#  'Илья Козлов': 2,
#  'Николай Волков': 2,
#  'Анастасия Лебедев': 2,
#  'Юлия Михайлов': 2,
#  'Даниил Титов': 2,
#  'Валентин Ильин': 2,
#  'Раиса Андреев': 2,
#  'Даниил Кудрявцев': 2,
#  'Александра Шарапов': 2,
#  'Екатерина Семенов': 2,
#  'Екатерина Голубев': 2,
#  'Тамара Шарапов': 2,
#  'Валерий Андреев': 2,
#  'Степан Шарапов': 2,
#  'Андрей Афанасьев': 2,
#  'Антон Анисимов': 2,
#  'Лев Романов': 2,
#  'Тимофей Андреев': 2,
#  'Степан Козлов': 2,
#  'Зоя Макаров': 2,
#  'Иван Титов': 2,
#  'Ева Морозов': 2,
#  'Милана Захаров': 2,
#  'Екатерина Петров': 2,
#  'Владлен Лебедев': 2,
#  'Евгений Исаев': 2,
#  'Тимур Орлов': 2,
#  'Владислав Макаров': 2,
#  'Мария Голубев': 2,
#  'Алина Соколов': 2,
#  'Афанасий Романов': 2,
#  'Павел Морозов': 2,
#  'Ульяна Федоров': 2,
#  'Степан Никитин': 2,
#  'Ярослав Семенов': 2,
#  'Афанасий Константинов': 2,
#  'Наталья Степанов': 2,
#  'Валерий Смирнов': 2,
#  'Евгения Захаров': 2,
#  'Игорь Ильин': 2,
#  'Михаил Николаев': 2,
#  'Милана Константинов': 2,
#  'Афанасий Исаев': 2,
#  'София Иванов': 2,
#  'Юлия Константинов': 2,
#  'Ярослав Виноградов': 2,
#  'Вера Зайцев': 2,
#  'Геннадий Петров': 2,
#  'Ярослав Павлов': 2,
#  'Лидия Волков': 2,
#  'Полина Лукин': 2,
#  'Ева Павлов': 3,
#  'Валентин Романов': 3,
#  'Виктория Павлов': 3,
#  'Станислава Беляков': 3,
#  'Ева Буров': 3,
#  'Павел Ларин': 3,
#  'Александр Анисимов': 3,
#  'Афанасий Голубев': 3,
#  'Максим Гусев': 3,
#  'Марина Семенов': 3,
#  'Надежда Смирнов': 3,
#  'Мирослава Романов': 3,
#  'Милана Федоров': 3,
#  'Татьяна Семенов': 3,
#  'Олег Егоров': 3,
#  'Федор Лукин': 3,
#  'Галина Шарапов': 3,
#  'Олеся Беляков': 3,
#  'Маргарита Лукин': 3,
#  'Ева Волков': 3,
#  'Дмитрий Титов': 3,
#  'Владлен Козлов': 3,
#  'Евгений Кузнецов': 3,
#  'Иван Ильин': 3,
#  'Мирослава Кузнецов': 3,
#  'Александр Буров': 3,
#  'Ульяна Михайлов': 3,
#  'Евгений Макаров': 3,
#  'Владимир Афанасьев': 3,
#  'Михаил Павлов': 3,
#  'Дмитрий Ковалев': 3,
#  'Виталий Константинов': 3,
#  'Ксения Титов': 3,
#  'Валерия Буров': 3,
#  'Тамара Морозов': 3,
#  'Анна Никитин': 3,
#  'Геннадий Андреев': 3,
#  'Максим Афанасьев': 3,
#  'Лев Иванов': 3,
#  'Елизавета Воробьев': 3,
#  'Полина Макаров': 3,
#  'Даниил Ефимов': 3,
#  'Валерия Егоров': 4,
#  'Умар Фомин': 4,
#  'Татьяна Голубев': 4,
#  'Оксана Иванов': 4,
#  'Станислав Лукин': 4,
#  'Степан Михайлов': 4,
#  'Афанасий Тарасов': 4,
#  'Артем Куликов': 4,
#  'Константин Кудрявцев': 4,
#  'Василий Макаров': 4,
#  'Милана Гусев': 4,
#  'Владимир Захаров': 4,
#  'Тамара Голубев': 4,
#  'Лидия Иванов': 4,
#  'Олеся Федоров': 4,
#  'Кирилл Морозов': 4,
#  'Валерий Павлов': 4,
#  'Станислава Титов': 4,
#  'Дмитрий Афанасьев': 4,
#  'Юлия Макаров': 4,
#  'Владислава Егоров': 4,
#  'София Кузнецов': 4,
#  'Мария Давыдов': 4,
#  'Марина Беляков': 4,
#  'Максим Морозов': 4,
#  'София Зайцев': 4,
#  'Валерий Анисимов': 4,
#  'Любовь Павлов': 4,
#  'Иван Куликов': 4,
#  'Олеся Титов': 4,
#  'Игорь Давыдов': 4,
#  'Ярослав Горбачев': 4,
#  'Юлия Зайцев': 4,
#  'Станислава Ефимов': 4,
#  'Евгений Орлов': 4,
#  'Григорий Богданов': 4,
#  'Лев Никитин': 4,
#  'Лариса Волков': 4,
#  'Александра Морозов': 4,
#  'Полина Ильин': 4,
#  'Вера Павлов': 4,
#  'Нина Воробьев': 4,
#  'Роман Кузнецов': 4,
#  'Владимир Тарасов': 5,
#  'Лариса Гусев': 5,
#  'Владимир Михайлов': 5,
#  'Наталья Волков': 5,
#  'Наталья Виноградов': 5,
#  'Михаил Буров': 5,
#  'Александра Горбачев': 5,
#  'Тамара Соколов': 5,
#  'Лариса Соколов': 5,
#  'Григорий Алексеев': 5,
#  'Ярослав Орлов': 5,
#  'Евгений Горбачев': 5,
#  'Валентин Кузнецов': 5,
#  'Мария Алексеев': 5,
#  'Алексей Шарапов': 5,
#  'Василий Козлов': 5,
#  'Степан Голубев': 5,
#  'Григорий Лебедев': 5,
#  'Игорь Афанасьев': 5,
#  'Лала Кудрявцев': 5,
#  'Тамара Егоров': 5,
#  'Лала Давыдов': 5,
#  'Полина Буров': 5,
#  'Владислав Андреев': 5,
#  'Станислава Богданов': 5,
#  'Владлен Семенов': 5,
#  'Юлия Буров': 5,
#  'Марина Ларин': 5,
#  'Алина Голубев': 5,
#  'Петр Никитин': 5,
#  'Ирина Тарасов': 5,
#  'Анастасия Смирнов': 5,
#  'Кирилл Андреев': 5,
#  'Екатерина Захаров': 5,
#  'Тамара Лебедев': 5,
#  'Алла Куликов': 5,
#  'Кирилл Романов': 5,
#  'Елена Ковалев': 5,
#  'Виктор Михайлов': 5,
#  'Даниил Фролов': 5,
#  'Марина Соколов': 5,
#  'Виталий Тарасов': 5,
#  'Степан Афанасьев': 5,
#  'Милана Смирнов': 5,
#  'Расул Андреев': 5,
#  'Максим Волков': 5,
#  'Афанасий Кудрявцев': 5,
#  'Станислава Кузнецов': 5,
#  'Милана Ефимов': 5,
#  'Умар Петров': 5,
#  'Владислава Буров': 5,
#  'Наталья Петров': 6,
#  'Наталья Куликов': 6,
#  'Андрей Морозов': 6,
#  'Лала Фролов': 6,
#  'Аркадий Горбачев': 6,
#  'Станислава Козлов': 6,
#  'Федор Семенов': 6,
#  'Николай Горбачев': 6,
#  'Тимофей Голубев': 6,
#  'Владислав Кузнецов': 6,
#  'Артем Иванов': 6,
#  'Людмила Тарасов': 6,
#  'Артем Петров': 6,
#  'Нина Константинов': 6,
#  'Андрей Анисимов': 6,
#  'Галина Егоров': 6,
#  'Ирина Давыдов': 6,
#  'Лала Иванов': 6,
#  'Валентина Ларин': 6,
#  'Умар Ефимов': 6,
#  'Анна Федоров': 6,
#  'Геннадий Исаев': 6,
#  'Анна Афанасьев': 6,
#  'Виктория Горбачев': 6,
#  'Нина Ковалев': 6,
#  'Виктор Беляков': 6,
#  'Елизавета Шарапов': 6,
#  'Ульяна Николаев': 6,
#  'Андрей Николаев': 6,
#  'Денис Давыдов': 6,
#  'Роман Буров': 6,
#  'Дарья Федоров': 6,
#  'Виктор Лебедев': 6,
#  'Алина Тарасов': 6,
#  'Николай Павлов': 6,
#  'Ву Ле Воробьев': 6,
#  'Станислав Козлов': 6,
#  'Лев Козлов': 6,
#  'Валентин Исаев': 6,
#  'Аркадий Воробьев': 6,
#  'Федор Соколов': 6,
#  'Василий Морозов': 6,
#  'Виталий Богданов': 6,
#  'Кирилл Виноградов': 6,
#  'Дмитрий Иванов': 6,
#  'Роман Иванов': 6,
#  'Денис Лукин': 6,
#  'Алина Романов': 6,
#  'Федор Ильин': 6,
#  'Маргарита Кузнецов': 6,
#  'Анна Волков': 6,
#  'Елизавета Ковалев': 6,
#  'Антон Орлов': 6,
#  'Дмитрий Лебедев': 6,
#  'Валерия Титов': 6,
#  'Марьяна Ковалев': 6,
#  'Ульяна Алексеев': 6,
#  'Антон Волков': 6,
#  'Вера Куликов': 6,
#  'Федор Куликов': 6,
#  'Олег Лукин': 6,
#  'Надежда Петров': 6,
#  'Иван Кузнецов': 6,
#  'Ева Лебедев': 6,
#  'Валерия Шарапов': 7,
#  'Мария Лукин': 7,
#  'Степан Титов': 7,
#  'Григорий Титов': 7,
#  'Владлен Никитин': 7,
#  'Вера Орлов': 7,
#  'Татьяна Ефимов': 7,
#  'Тимур Воробьев': 7,
#  'Николай Степанов': 7,
#  'Игорь Павлов': 7,
#  'Арсений Никитин': 7,
#  'Степан Смирнов': 7,
#  'Илья Виноградов': 7,
#  'Маргарита Афанасьев': 7,
#  'Марина Константинов': 7,
#  'Владимир Ефимов': 7,
#  'Валентина Горбачев': 7,
#  'Ева Алексеев': 7,
#  'Милана Ковалев': 7,
#  'Павел Соколов': 7,
#  'София Воробьев': 7,
#  'Алексей Тарасов': 7,
#  'Алла Ефимов': 7,
#  'Светлана Виноградов': 7,
#  'Виктория Анисимов': 7,
#  'Владислава Афанасьев': 7,
#  'Дарья Иванов': 7,
#  'Роман Куликов': 7,
#  'Виталий Семенов': 7,
#  'Станислава Егоров': 7,
#  'Даниил Федоров': 7,
#  'Ульяна Соколов': 7,
#  'Алексей Гусев': 7,
#  'Руслан Андреев': 7,
#  'Маргарита Смирнов': 7,
#  'Михаил Зайцев': 7,
#  'Марьяна Титов': 7,
#  'Виктор Ковалев': 7,
#  'Михаил Ефимов': 7,
#  'Тимур Макаров': 7,
#  'Юлия Морозов': 7,
#  'Афанасий Смирнов': 7,
#  'Станислава Морозов': 7,
#  'Валерий Давыдов': 7,
#  'Маргарита Захаров': 7,
#  'Людмила Давыдов': 8,
#  'Тимур Шарапов': 8,
#  'Андрей Виноградов': 8,
#  'Аркадий Буров': 8,
#  'Наталья Романов': 8,
#  'Олеся Афанасьев': 8,
#  'Кирилл Анисимов': 8,
#  'Умар Андреев': 8,
#  'Вера Степанов': 8,
#  'Зоя Богданов': 8,
#  'Владислав Куликов': 8,
#  'Лала Виноградов': 8,
#  'Андрей Беляков': 8,
#  'Анна Богданов': 8,
#  'Марьяна Егоров': 8,
#  'Светлана Куликов': 8,
#  'Роман Федоров': 8,
#  'Дарья Степанов': 8,
#  'Екатерина Смирнов': 8,
#  'Ева Егоров': 8,
#  'Елизавета Никитин': 8,
#  'Раиса Иванов': 8,
#  'Алексей Константинов': 8,
#  'Елизавета Афанасьев': 8,
#  'Геннадий Лебедев': 8,
#  'Степан Алексеев': 8,
#  'Константин Иванов': 8,
#  'Станислава Никитин': 8,
#  'Афанасий Михайлов': 8,
#  'Анастасия Фомин': 8,
#  'Мария Ковалев': 8,
#  'Хонгр Зайцев': 8,
#  'Умар Голубев': 8,
#  'Вера Кузнецов': 8,
#  'Вера Титов': 8,
#  'Тимур Ларин': 8,
#  'Владислава Захаров': 8,
#  'Екатерина Титов': 8,
#  'Анастасия Виноградов': 8,
#  'Ву Ле Тарасов': 8,
#  'Юлия Ларин': 8,
#  'Ирина Морозов': 8,
#  'Руслан Шарапов': 8,
#  'Кирилл Павлов': 8,
#  'Елизавета Павлов': 9,
#  'Ольга Иванов': 9,
#  'Хонгр Фролов': 9,
#  'Виталий Макаров': 9,
#  'Любовь Николаев': 9,
#  'София Павлов': 9,
#  'Петр Ильин': 9,
#  'Владислава Ковалев': 9,
#  'Виктор Фролов': 9,
#  'Вера Петров': 9,
#  'Виктория Виноградов': 9,
#  'Валентин Титов': 9,
#  'Ксения Давыдов': 9,
#  'Зоя Тарасов': 9,
#  'Анастасия Давыдов': 9,
#  'Любовь Виноградов': 9,
#  'Станислава Иванов': 9,
#  'Федор Анисимов': 9,
#  'Александра Воробьев': 9,
#  'Расул Степанов': 9,
#  'Андрей Лебедев': 9,
#  'Арсений Орлов': 9,
#  'Павел Константинов': 9,
#  'Станислав Фролов': 9,
#  'Александра Буров': 9,
#  'Милана Богданов': 9,
#  'Маргарита Анисимов': 9,
#  'Валерий Тарасов': 9,
#  'Валентин Морозов': 9,
#  'Вера Ильин': 9,
#  'Елена Михайлов': 9,
#  'Олеся Морозов': 9,
#  'Артемий Ефимов': 9,
#  'Михаил Морозов': 9,
#  'Владлен Соколов': 9,
#  'Галина Ковалев': 9,
#  'Умар Титов': 9,
#  'Валерия Иванов': 9,
#  'Григорий Афанасьев': 9,
#  'Алла Павлов': 9,
#  'Василий Шарапов': 9,
#  'Хонгр Исаев': 9,
#  'Арсений Исаев': 9,
#  'Василий Алексеев': 9,
#  'Лев Гусев': 9,
#  'Оксана Макаров': 9,
#  'Виктория Кузнецов': 9,
#  'Артем Гусев': 9,
#  'Владлен Гусев': 9,
#  'Владислав Зайцев': 9,
#  'Лала Титов': 9,
#  'Любовь Голубев': 10,
#  'Тимур Козлов': 10,
#  'Максим Степанов': 10,
#  'Екатерина Афанасьев': 10,
#  'Зоя Смирнов': 10,
#  'Лидия Титов': 10,
#  'Руслан Соколов': 10,
#  'Максим Воробьев': 10,
#  'Николай Смирнов': 10,
#  'Аркадий Куликов': 10,
#  'Елизавета Лебедев': 10,
#  'Валерия Семенов': 10,
#  'Полина Кудрявцев': 10,
#  'Татьяна Федоров': 10,
#  'Григорий Беляков': 10,
#  'Светлана Зайцев': 10,
#  'Антон Лебедев': 10,
#  'Анастасия Волков': 10,
#  'Олег Соколов': 10,
#  'Нина Буров': 10,
#  'Антон Ильин': 10,
#  'Станислава Анисимов': 10,
#  'Анастасия Буров': 10,
#  'Василий Иванов': 10,
#  'Галина Лукин': 10,
#  'Илья Лебедев': 10,
#  'Дарья Козлов': 10,
#  'Мирослава Титов': 10,
#  'Светлана Иванов': 10,
#  'Валерий Титов': 10,
#  'Владлен Исаев': 10,
#  'Валерий Егоров': 10,
#  'Елизавета Морозов': 10,
#  'Вера Макаров': 10,
#  'Илья Павлов': 10,
#  'Елена Федоров': 10,
#  'Станислав Голубев': 10,
#  'Федор Голубев': 10,
#  'Лала Петров': 10,
#  'Тимур Кудрявцев': 10,
#  'Лев Давыдов': 10,
#  'Мария Николаев': 10,
#  'Хонгр Андреев': 10,
#  'Арсений Фомин': 10,
#  'Александра Давыдов': 10,
#  'Светлана Ильин': 11,
#  'Артемий Степанов': 11,
#  'Мирослава Иванов': 11,
#  'Константин Ковалев': 11,
#  'Роман Шарапов': 11,
#  'Мирослава Зайцев': 11,
#  'Ву Ле Голубев': 11,
#  'Руслан Иванов': 11,
#  'Олег Шарапов': 11,
#  'Кирилл Воробьев': 11,
#  'Лидия Романов': 11,
#  'Павел Афанасьев': 11,
#  'Арсений Федоров': 11,
#  'Ву Ле Захаров': 11,
#  'Геннадий Ковалев': 11,
#  'Иван Кудрявцев': 11,
#  'Валерий Горбачев': 11,
#  'Лала Смирнов': 11,
#  'Ирина Козлов': 11,
#  'Геннадий Константинов': 11,
#  'Станислава Виноградов': 11,
#  'Виктория Куликов': 11,
#  'Валерий Виноградов': 11,
#  'Светлана Афанасьев': 11,
#  'Лидия Давыдов': 11,
#  'Денис Константинов': 11,
#  'Анна Козлов': 11,
#  'Маргарита Константинов': 11,
#  'Геннадий Волков': 11,
#  'Степан Буров': 11,
#  'Татьяна Морозов': 11,
#  'Валентин Беляков': 11,
#  'Наталья Морозов': 11,
#  'Раиса Егоров': 11,
#  'Умар Куликов': 11,
#  'Александр Лукин': 11,
#  'Валентин Степанов': 11,
#  'Алина Кузнецов': 11,
#  'Галина Кузнецов': 11,
#  'Валерия Голубев': 11,
#  'Наталья Николаев': 11,
#  'Юлия Тарасов': 11,
#  'Оксана Кудрявцев': 11,
#  'Арсений Лебедев': 11,
#  'Алина Макаров': 11,
#  'Станислав Ильин': 11,
#  'Денис Воробьев': 11,
#  'Наталья Гусев': 12,
#  'Расул Соколов': 12,
#  'Оксана Давыдов': 12,
#  'Валерия Кузнецов': 12,
#  'Алексей Анисимов': 12,
#  'Андрей Захаров': 12,
#  'Олег Федоров': 12,
#  'Тимур Тарасов': 12,
#  'Умар Алексеев': 12,
#  'Евгения Лукин': 12,
#  'Ольга Лукин': 12,
#  'Андрей Ковалев': 12,
#  'Константин Куликов': 12,
#  'Дарья Михайлов': 12,
#  'Расул Алексеев': 12,
#  'Геннадий Семенов': 12,
#  'Ева Титов': 12,
#  'Михаил Никитин': 12,
#  'Екатерина Николаев': 12,
#  'Хонгр Захаров': 12,
#  'Наталья Лукин': 12,
#  'Ирина Никитин': 12,
#  'Иван Алексеев': 12,
#  'Мария Гусев': 12,
#  'Сергей Титов': 12,
#  'Алексей Ковалев': 12,
#  'Тимофей Кузнецов': 12,
#  'Алексей Михайлов': 12,
#  'Анна Михайлов': 12,
#  'Степан Беляков': 12,
#  'Петр Голубев': 12,
#  'Геннадий Фролов': 12,
#  'Екатерина Степанов': 12,
#  'Ольга Зайцев': 12,
#  'Анна Кузнецов': 12,
#  'Марина Петров': 12,
#  'Ву Ле Петров': 12,
#  'Геннадий Ефимов': 12,
#  'Ву Ле Никитин': 12,
#  'Станислав Семенов': 12,
#  'Антон Тарасов': 12,
#  'Ксения Соколов': 12,
#  'Евгения Зайцев': 12,
#  'Елизавета Куликов': 12,
#  'Дмитрий Петров': 12,
#  'Кирилл Шарапов': 12,
#  'Светлана Воробьев': 13,
#  'Андрей Романов': 13,
#  'София Буров': 13,
#  'Маргарита Семенов': 13,
#  'Тимофей Козлов': 13,
#  'Арсений Козлов': 13,
#  'Зоя Титов': 13,
#  'София Макаров': 13,
#  'Григорий Ильин': 13,
#  'Валерия Макаров': 13,
#  'Федор Кузнецов': 13,
#  'Роман Зайцев': 13,
#  'Максим Виноградов': 13,
#  'Алла Ларин': 13,
#  'Оксана Буров': 13,
#  'Оксана Алексеев': 13,
#  'Расул Константинов': 13,
#  'Василий Голубев': 13,
#  'Ксения Тарасов': 13,
#  'Елена Виноградов': 13,
#  'Кирилл Макаров': 13,
#  'Нина Кузнецов': 13,
#  'Петр Захаров': 13,
#  'Мирослава Буров': 13,
#  'Владимир Федоров': 13,
#  'Валерия Горбачев': 13,
#  'Денис Кузнецов': 13,
#  'Людмила Захаров': 13,
#  'Константин Богданов': 13,
#  'Зоя Козлов': 13,
#  'Константин Лукин': 13,
#  'Ева Кудрявцев': 13,
#  'Ву Ле Романов': 13,
#  'Станислава Давыдов': 13,
#  'Антон Семенов': 13,
#  'Иван Орлов': 13,
#  'Кирилл Гусев': 13,
#  'Тамара Ларин': 14,
#  'Александра Анисимов': 14,
#  'Надежда Андреев': 14,
#  'Геннадий Ларин': 14,
#  'Петр Фомин': 14,
#  'Умар Семенов': 14,
#  'Ву Ле Буров': 14,
#  'Алла Захаров': 14,
#  'Аркадий Иванов': 14,
#  'Марина Куликов': 14,
#  'Владислава Воробьев': 14,
#  'Степан Гусев': 14,
#  'Виктор Федоров': 14,
#  'Василий Андреев': 14,
#  'Олеся Лукин': 14,
#  'Василий Никитин': 14,
#  'Марьяна Федоров': 14,
#  'София Волков': 14,
#  'Владимир Виноградов': 14,
#  'Ксения Павлов': 14,
#  'Екатерина Горбачев': 14,
#  'Игорь Фролов': 14,
#  'Руслан Павлов': 14,
#  'Федор Воробьев': 14,
#  'Тимур Беляков': 14,
#  'Артемий Павлов': 14,
#  'Вера Волков': 14,
#  'Григорий Андреев': 14,
#  'Дмитрий Козлов': 14,
#  'Алина Беляков': 14,
#  'Аркадий Ильин': 14,
#  'София Богданов': 14,
#  'Игорь Михайлов': 14,
#  'Валентин Голубев': 14,
#  'Лев Николаев': 14,
#  'Владислава Зайцев': 14,
#  'Владислав Фролов': 14,
#  'Андрей Волков': 14,
#  'Геннадий Гусев': 14,
#  'Ксения Афанасьев': 14,
#  'Ксения Буров': 14,
#  'Алла Фролов': 14,
#  'Тимофей Афанасьев': 14,
#  'Маргарита Фролов': 14,
#  'Валерий Фролов': 14,
#  'Алина Егоров': 14,
#  'Оксана Горбачев': 14,
#  'Игорь Анисимов': 14,
#  'Мария Фролов': 15,
#  'Умар Захаров': 15,
#  'Артем Михайлов': 15,
#  'Василий Константинов': 15,
#  'Павел Кузнецов': 15,
#  'Александра Козлов': 15,
#  'Умар Никитин': 15,
#  'Тимофей Павлов': 15,
#  'Андрей Давыдов': 15,
#  'Игорь Лебедев': 15,
#  'Илья Ларин': 15,
#  'Лариса Зайцев': 15,
#  'Тимур Исаев': 15,
#  'Марина Афанасьев': 15,
#  'Владислав Романов': 15,
#  'Ирина Захаров': 15,
#  'Александр Николаев': 15,
#  'Алексей Андреев': 15,
#  'Хонгр Ефимов': 15,
#  'Антон Буров': 15,
#  'Станислав Кузнецов': 15,
#  'Хонгр Иванов': 15,
#  'Ярослав Буров': 15,
#  'Виталий Степанов': 15,
#  'Надежда Ковалев': 15,
#  'Лидия Алексеев': 15,
#  'Артемий Шарапов': 15,
#  'Олеся Соколов': 15,
#  'Лев Виноградов': 15,
#  'Алла Афанасьев': 15,
#  'Валерия Афанасьев': 15,
#  'Иван Захаров': 15,
#  'Арсений Горбачев': 16,
#  'Анна Виноградов': 16,
#  'Игорь Козлов': 16,
#  'Наталья Андреев': 16,
#  'Аркадий Лебедев': 16,
#  'Владислава Иванов': 16,
#  'Дмитрий Захаров': 16,
#  'Любовь Фомин': 16,
#  'Денис Соколов': 16,
#  'Тамара Буров': 16,
#  'Валерия Беляков': 16,
#  'Антон Давыдов': 16,
#  'Валерий Семенов': 16,
#  'Григорий Куликов': 16,
#  'Раиса Ильин': 16,
#  'Виктор Анисимов': 16,
#  'Хонгр Николаев': 16,
#  'Анастасия Беляков': 16,
#  'Маргарита Макаров': 16,
#  'Владислав Ларин': 16,
#  'Мирослава Михайлов': 16,
#  'Лала Соколов': 16,
#  'Владислава Смирнов': 16,
#  'Виктория Константинов': 16,
#  'Милана Семенов': 16,
#  'Илья Воробьев': 16,
#  'Ирина Петров': 16,
#  'Валентин Лукин': 16,
#  'Лев Куликов': 16,
#  'Марина Фомин': 16,
#  'Лев Андреев': 16,
#  'Нина Титов': 16,
#  'Полина Исаев': 16,
#  'Вера Лукин': 16,
#  'Валерия Зайцев': 16,
#  'Ольга Ларин': 17,
#  'Дмитрий Романов': 17,
#  'Даниил Фомин': 17,
#  'Валентин Константинов': 17,
#  'Игорь Голубев': 17,
#  'Афанасий Буров': 17,
#  'Петр Тарасов': 17,
#  'Кирилл Егоров': 17,
#  'Лев Степанов': 17,
#  'Николай Лукин': 17,
#  'Лариса Анисимов': 17,
#  'Ву Ле Титов': 17,
#  'Людмила Никитин': 17,
#  'Маргарита Горбачев': 17,
#  'Андрей Макаров': 17,
#  'Ирина Соколов': 17,
#  'Александр Иванов': 17,
#  'Людмила Михайлов': 17,
#  'Ева Фролов': 17,
#  'Алла Макаров': 17,
#  'Тимофей Кудрявцев': 17,
#  'Ирина Иванов': 17,
#  'Владимир Куликов': 17,
#  'Полина Егоров': 17,
#  'Умар Фролов': 17,
#  'Мария Горбачев': 17,
#  'Марьяна Иванов': 17,
#  'Геннадий Иванов': 17,
#  'Владислав Виноградов': 17,
#  'Лала Алексеев': 17,
#  'Наталья Ковалев': 17,
#  'Галина Иванов': 17,
#  'Артем Исаев': 17,
#  'Мирослава Ковалев': 17,
#  'Арсений Петров': 17,
#  'Олеся Давыдов': 17,
#  'Расул Петров': 17,
#  'Михаил Куликов': 17,
#  'Анна Давыдов': 17,
#  'Зоя Гусев': 17,
#  'Федор Андреев': 17,
#  'Алина Фомин': 17,
#  'Умар Беляков': 17,
#  'Игорь Титов': 17,
#  'Анна Орлов': 17,
#  'Нина Иванов': 17,
#  'Олеся Голубев': 17,
#  'Расул Гусев': 17,
#  'Григорий Романов': 17,
#  'Ирина Виноградов': 17,
#  'Алина Шарапов': 17,
#  'Антон Зайцев': 17,
#  'Илья Захаров': 17,
#  'Валентина Андреев': 18,
#  'Руслан Ларин': 18,
#  'Анастасия Никитин': 18,
#  'Екатерина Гусев': 18,
#  'Галина Богданов': 18,
#  'Елизавета Титов': 18,
#  'Валентин Кудрявцев': 18,
#  'Виктор Захаров': 18,
#  'Виктория Смирнов': 18,
#  'Григорий Волков': 18,
#  'Лала Лукин': 18,
#  'Степан Андреев': 18,
#  'Владислава Горбачев': 18,
#  'Сергей Воробьев': 18,
#  'Виталий Зайцев': 18,
#  'София Ковалев': 18,
#  'Валерий Куликов': 18,
#  'Полина Лебедев': 18,
#  'Афанасий Егоров': 18,
#  'Аркадий Николаев': 18,
#  'Олеся Андреев': 18,
#  'Денис Макаров': 18,
#  'Владислав Морозов': 18,
#  'Владлен Кузнецов': 18,
#  'Полина Анисимов': 18,
#  'Татьяна Козлов': 18,
#  'Сергей Лебедев': 18,
#  'Тимофей Ефимов': 18,
#  'Иван Фролов': 18,
#  'Станислава Ларин': 18,
#  'Марина Давыдов': 18,
#  'Анастасия Орлов': 18,
#  'Людмила Федоров': 18,
#  'Максим Исаев': 18,
#  'Валентина Морозов': 18,
#  'София Куликов': 19,
#  'Наталья Павлов': 19,
#  'Павел Виноградов': 19,
#  'Сергей Буров': 19,
#  'Иван Соколов': 19,
#  'Владислава Титов': 19,
#  'Геннадий Козлов': 19,
#  'Светлана Семенов': 19,
#  'Максим Николаев': 19,
#  'Лев Анисимов': 19,
#  'Сергей Смирнов': 19,
#  'Расул Смирнов': 19,
#  'Елизавета Ефимов': 19,
#  'Зоя Ковалев': 19,
#  'Расул Макаров': 19,
#  'Мирослава Волков': 19,
#  'Раиса Алексеев': 19,
#  'Валентина Волков': 19,
#  'Галина Павлов': 19,
#  'Александра Фомин': 19,
#  'Мирослава Куликов': 19,
#  'Владимир Волков': 19,
#  'Елизавета Беляков': 19,
#  'Юлия Иванов': 19,
#  'Ву Ле Николаев': 19,
#  'Галина Кудрявцев': 19,
#  'Светлана Алексеев': 19,
#  'Елизавета Фролов': 19,
#  'Виктор Волков': 19,
#  'Ву Ле Горбачев': 19,
#  'Валерия Орлов': 19,
#  'Тимофей Ковалев': 19,
#  'Евгений Буров': 19,
#  'Елена Павлов': 19,
#  'Маргарита Никитин': 19,
#  'Василий Давыдов': 19,
#  'Михаил Воробьев': 19,
#  'Ева Афанасьев': 19,
#  'Лидия Ларин': 19,
#  'Полина Петров': 19,
#  'Станислав Давыдов': 19,
#  'Умар Федоров': 20,
#  'Владислав Козлов': 20,
#  'Дмитрий Алексеев': 20,
#  'Константин Волков': 20,
#  'Надежда Павлов': 20,
#  'Екатерина Орлов': 20,
#  'Игорь Соколов': 20,
#  'Анна Константинов': 20,
#  'Николай Фомин': 20,
#  'Александра Петров': 20,
#  'Елизавета Константинов': 20,
#  'Евгений Гусев': 20,
#  'Константин Федоров': 20,
#  'Алла Смирнов': 20,
#  'Афанасий Давыдов': 20,
#  'Михаил Федоров': 20,
#  'Ксения Михайлов': 20,
#  'Станислава Кудрявцев': 20,
#  'Лидия Голубев': 20,
#  'Кирилл Никитин': 20,
#  'Ксения Исаев': 20,
#  'Екатерина Волков': 20,
#  'Ву Ле Иванов': 20,
#  'Наталья Смирнов': 20,
#  'Афанасий Николаев': 20,
#  'Алексей Захаров': 20,
#  'Зоя Ильин': 20,
#  'Маргарита Зайцев': 20,
#  'Валерий Буров': 20,
#  'Константин Морозов': 20,
#  'Мария Козлов': 20,
#  'Елена Егоров': 20,
#  'Ксения Орлов': 20,
#  'Андрей Петров': 20,
#  'Ирина Лукин': 20,
#  'Артем Кудрявцев': 20,
#  'Алина Горбачев': 20,
#  'Ярослав Волков': 20,
#  'Галина Фролов': 20,
#  'Марина Алексеев': 20,
#  'Алла Фомин': 20,
#  'Алла Волков': 21,
#  'Елена Фролов': 21,
#  'Лариса Лебедев': 21,
#  'Мария Виноградов': 21,
#  'Григорий Морозов': 21,
#  'Елена Анисимов': 21,
#  'Олеся Степанов': 21,
#  'Расул Захаров': 21,
#  'Геннадий Шарапов': 21,
#  'Артемий Гусев': 21,
#  'Валентин Зайцев': 21,
#  'Ульяна Ларин': 21,
#  'Марьяна Гусев': 21,
#  'Дарья Давыдов': 21,
#  'Илья Макаров': 21,
#  'Оксана Фролов': 21,
#  'Максим Тарасов': 21,
#  'Василий Михайлов': 21,
#  'Марьяна Ларин': 21,
#  'Михаил Горбачев': 21,
#  'Александра Фролов': 21,
#  'Татьяна Волков': 21,
#  'Сергей Тарасов': 21,
#  'Аркадий Давыдов': 21,
#  'Милана Степанов': 21,
#  'Федор Фомин': 21,
#  'Валентина Петров': 21,
#  'Валерия Захаров': 21,
#  'Надежда Шарапов': 21,
#  'Евгения Макаров': 21,
#  'Умар Егоров': 21,
#  'Наталья Ильин': 21,
#  'Владимир Ильин': 21,
#  'Владислава Федоров': 21,
#  'София Алексеев': 22,
#  'Сергей Ковалев': 22,
#  'Денис Федоров': 22,
#  'Анна Иванов': 22,
#  'Олеся Петров': 22,
#  'Илья Фролов': 22,
#  'Дмитрий Соколов': 22,
#  'Евгения Воробьев': 22,
#  'Антон Павлов': 22,
#  'Федор Гусев': 22,
#  'Афанасий Виноградов': 22,
#  'Петр Волков': 22,
#  'Екатерина Лебедев': 22,
#  'Руслан Константинов': 22,
#  'Роман Никитин': 22,
#  'София Федоров': 22,
#  'Даниил Павлов': 22,
#  'Владлен Романов': 22,
#  'Михаил Лукин': 22,
#  'Виталий Андреев': 22,
#  'Ксения Голубев': 22,
#  'Лала Воробьев': 22,
#  'Владлен Павлов': 22,
#  'Сергей Никитин': 22,
#  'Руслан Буров': 22,
#  'Артемий Соколов': 22,
#  'Наталья Ларин': 22,
#  ...}

# %% [markdown]
# 2) Необходимо отсортировать массив объектов по заданному критерию и вывести результат на экран. В зависимости от переданного параметра отсортировать массив объектов класса «Книга» по автору, названию или году издания, используя алгоритмы сортировки: пузырьковую, сортировку вставками и быструю сортировку. Сравнить время выполнения алгоритмов сортировки с помощью декоратора. Данные о книгах хранятся в файле.

# %%
import time
books = [["Роулинг", "2002", "Гарри Поттер"], ["Чехов", "1894", "Студент"], ["Толстой", "1867", "Война и мир"]]

def quick_sort_decorator(sort_func):
    def wrapper(d):
        start_time = time.perf_counter_ns()
        def quick_sort(arr):
            level = 1
            if len(arr) <= 1:
                return arr
            else:
                pivot = arr[len(arr) // 2][level]
                left = [x for x in arr if x[level] < pivot]
                middle = [x for x in arr if x[level] == pivot]
                right = [x for x in arr if x[level] > pivot]
                return quick_sort(left) + middle + quick_sort(right)
        sorted_items = quick_sort(d)
        print(time.perf_counter_ns() - start_time)
        return sort_func(sorted_items)
    
    return wrapper

@quick_sort_decorator
def process_sorted_dict(d):
    print("Отсортированный массив:")
    return d


process_sorted_dict(books)
# Out:
# 5200
# Отсортированный массив:
# [['Толстой', '1867', 'Война и мир'],
#  ['Чехов', '1894', 'Студент'],
#  ['Роулинг', '2002', 'Гарри Поттер']]

# %% [markdown]
# 3) Необходимо отсортировать массив строк по алфавиту и вывести результат на экран.
# Использовать алгоритмы сортировки: сортировку пузырьком, сортировку слиянием и быструю сортировку. Сравнить время выполнения алгоритмов сортировки с помощью декоратора. Строки хранятся в файле.

# %%
stroks = open('rows.txt', 'r')
rows = [line for line in stroks]
print("Оригинальный массив: \n", rows)
def quick_sort_decorator(sort_func):
    def wrapper(d):
        def quick_sort(arr):
            if len(arr) <= 1:
                return arr
            else:
                pivot = arr[len(arr) // 2]
                left = [x for x in arr if x < pivot]
                middle = [x for x in arr if x == pivot]
                right = [x for x in arr if x > pivot]
                return quick_sort(left) + middle + quick_sort(right)
        
        sorted_items = quick_sort(d)
        return sort_func(sorted_items)
    
    return wrapper

@quick_sort_decorator
def process_sorted_dict(d):
    print("Отсортированный массив: \n", d)
    return d


process_sorted_dict(rows)
# Out:
# Оригинальный массив:
#  ['sdsdsdz\n', 'vxca\n', 'sadas\n', 'qwe\n', 'gsdgf\n', 'cvxcv']
# Отсортированный массив:
#  ['cvxcv', 'gsdgf\n', 'qwe\n', 'sadas\n', 'sdsdsdz\n', 'vxca\n']
# ['cvxcv', 'gsdgf\n', 'qwe\n', 'sadas\n', 'sdsdsdz\n', 'vxca\n']

# %% [markdown]
# 4. Необходимо отсортировать список товаров по цене и вывести результат на экран.
# В зависимости от переданного параметра отсортировать список товаров по возрастанию
# цены или по убыванию цены, используя алгоритмы сортировки: сортировку пузырьком,
# сортировку слиянием и быструю сортировку. Сравнить время выполнения алгоритмов
# сортировки с помощью декоратора. Данные о товарах хранятся в файле.

# %%
prices = open('tovari.txt', 'r')
rows = [line for line in stroks]
{'Вода': 50, 'Хлеб': 100, 'Мыло': 30, 'Конфета': 10}

def quick_sort_decorator(sort_func):
    def wrapper(d):
        def quick_sort(arr):
            if len(arr) <= 1:
                return arr
            else:
                pivot = arr[len(arr) // 2][1]
                left = [x for x in arr if x[1] < pivot]
                middle = [x for x in arr if x[1] == pivot]
                right = [x for x in arr if x[1] > pivot]
                return quick_sort(left) + middle + quick_sort(right)
        
        items = list(d.items())
        sorted_items = quick_sort(items)
        sorted_dict = {k: v for k, v in sorted_items}
        return sort_func(sorted_dict)
    
    return wrapper


@quick_sort_decorator
def process_sorted_dict(d):
    print("Отсортированный словарь:")
    return d


process_sorted_dict(prices)
# Out:
# Отсортированный словарь:
# {'Хлеб': 100, 'Вода': 50, 'Мыло': 30, 'Конфета': 10}

# %% [markdown]
# 12. Необходимо отсортировать массив чисел по сумме цифр каждого числа и вывести результат на экран. В зависимости от переданного параметра отсортировать массив чисел по возрастанию или по убыванию суммы цифр каждого числа, используя алгоритмы сортировки: сортировку выбором, сортировку пузырьком и быструю сортировку. Сравнить время выполнения алгоритмов сортировки с помощью декоратора. Числа хранятся в файле.

# %%
import time
numbers =  open('numbers.txt', 'r')
numbers_arr = [int(number.rstrip()) for number in numbers]
print(numbers_arr)

def time_decorator(sort_func):
    def wrapper(*args):
        start_time = time.perf_counter_ns()
        res = sort_func(*args)
        end_time = (time.perf_counter_ns() - start_time) /1000000000
        print(end_time)
        return res
    return wrapper


def sum_numbers(number):
    suma = 0
    for i in str(number):
        suma += int(i)
    return suma

@time_decorator
def quick_sort(arr, increasing):
    if len(arr) <= 1:
        return arr
    else:
        pivot = arr[len(arr) // 2]
        left = [x for x in arr if sum_numbers(x) < sum_numbers(pivot)]
        middle = [x for x in arr if sum_numbers(x) == sum_numbers(pivot)]
        right = [x for x in arr if sum_numbers(x) > sum_numbers(pivot)]
        if increasing == True:
            return quick_sort(left, True) + middle + quick_sort(right, True)
        else:
            return quick_sort(right, False) + middle + quick_sort(left, False)
        

@time_decorator
def bubble_sort(a_list, increasing):
    for pass_num in range(len(a_list) - 1, 0, -1):
        for i in range(pass_num):
            if increasing == True:
                if sum_numbers(a_list[i]) > sum_numbers(a_list[i + 1]):
                    a_list[i], a_list[i + 1] = a_list[i + 1], a_list[i] 
            else:
                if sum_numbers(a_list[i]) < sum_numbers(a_list[i + 1]):
                    a_list[i], a_list[i + 1] = a_list[i + 1], a_list[i] 
    return a_list

@time_decorator
def selection_sort(a_list, increasing):
    for fill_slot in range(len(a_list) - 1, 0, -1):
        pos_of_max = 0
        for location in range(1, fill_slot + 1):
            if increasing == True:
                if sum_numbers(a_list[location]) > sum_numbers(a_list[pos_of_max]):
                    pos_of_max = location
            else:
                if sum_numbers(a_list[location]) < sum_numbers(a_list[pos_of_max]):
                    pos_of_max = location

        a_list[fill_slot], a_list[pos_of_max] = a_list[pos_of_max], a_list[fill_slot]
    return a_list
        

order_inc = False  
#quick_sort(numbers_arr, order_inc)
#bubble_sort(numbers_arr, order_inc)
selection_sort(numbers_arr, order_inc)
# Out:
# [10, 23, 45, 67, 123, 53, 60, 3, 523, 123, 53, 7, 3, 5, 34234, 54, 22, 3, 4, 12, 3]
# 0.0003181
# [34234,
#  67,
#  523,
#  45,
#  54,
#  53,
#  53,
#  7,
#  123,
#  60,
#  123,
#  5,
#  23,
#  22,
#  4,
#  3,
#  3,
#  3,
#  12,
#  3,
#  10]
