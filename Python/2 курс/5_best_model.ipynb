# %% [markdown]
# ## Семинар 5
# # Тема: Отбор наилучшей модели из нескольких с наилучшими гиперпараметрами поиском по сетке

# %% [markdown]
#    Рассмотрим следующую задачу: необходимо подобрать наилучшую модель (из нескольких) с наилучшими гиперпараметрами, а затем для выбранной модели оценить качество обобщающей способности. Это можно сделать с помощью поиска по сетке, в которой присутствует и вид модели тоже (а не только значения гиперпараметров модели) с перекрёстной проверкой.

# %% [markdown]
# Импортируем необходимые библиотеки:

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris, load_breast_cancer
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import metrics
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### 1. Загрузите встроенный датасет load_breast_cancer. Обозначьте признаки за X, а целевую переменную за y и выведите их размеры. Выведите данные в виде датафрейма.

# %%
cancer = load_breast_cancer()
X = cancer.data
y = cancer.target

X.shape, y.shape
# Out:
# ((569, 30), (569,))

# %%
data = pd.DataFrame(X, columns=cancer.feature_names)
data['target'] = y
data.head(5)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
data['target'].value_counts()
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
print(cancer.DESCR)
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 569
#
# :Number of Attributes: 30 numeric, predictive attributes and the class
#
# :Attribute Information:
#     - radius (mean of distances from center to points on the perimeter)
#     - texture (standard deviation of gray-scale values)
#     - perimeter
#     - area
#     - smoothness (local variation in radius lengths)
#     - compactness (perimeter^2 / area - 1.0)
#     - concavity (severity of concave portions of the contour)
#     - concave points (number of concave portions of the contour)
#     - symmetry
#     - fractal dimension ("coastline approximation" - 1)
#
#     The mean, standard error, and "worst" or largest (mean of the three
#     worst/largest values) of these features were computed for each image,
#     resulting in 30 features.  For instance, field 0 is Mean Radius, field
#     10 is Radius SE, field 20 is Worst Radius.
#
#     - class:
#             - WDBC-Malignant
#             - WDBC-Benign
#
# :Summary Statistics:
#
# ===================================== ====== ======
#                                         Min    Max
# ===================================== ====== ======
# radius (mean):                        6.981  28.11
# texture (mean):                       9.71   39.28
# perimeter (mean):                     43.79  188.5
# area (mean):                          143.5  2501.0
# smoothness (mean):                    0.053  0.163
# compactness (mean):                   0.019  0.345
# concavity (mean):                     0.0    0.427
# concave points (mean):                0.0    0.201
# symmetry (mean):                      0.106  0.304
# fractal dimension (mean):             0.05   0.097
# radius (standard error):              0.112  2.873
# texture (standard error):             0.36   4.885
# perimeter (standard error):           0.757  21.98
# area (standard error):                6.802  542.2
# smoothness (standard error):          0.002  0.031
# compactness (standard error):         0.002  0.135
# concavity (standard error):           0.0    0.396
# concave points (standard error):      0.0    0.053
# symmetry (standard error):            0.008  0.079
# fractal dimension (standard error):   0.001  0.03
# radius (worst):                       7.93   36.04
# texture (worst):                      12.02  49.54
# perimeter (worst):                    50.41  251.2
# area (worst):                         185.2  4254.0
# smoothness (worst):                   0.071  0.223
# compactness (worst):                  0.027  1.058
# concavity (worst):                    0.0    1.252
# concave points (worst):               0.0    0.291
# symmetry (worst):                     0.156  0.664
# fractal dimension (worst):            0.055  0.208
# ===================================== ====== ======
#
# :Missing Attribute Values: None
#
# :Class Distribution: 212 - Malignant, 357 - Benign
#
# :Creator:  Dr. William H. Wolberg, W. Nick Street, Olvi L. Mangasarian
#
# :Donor: Nick Street
#
# :Date: November, 1995
#
# This is a copy of UCI ML Breast Cancer Wisconsin (Diagnostic) datasets.
# https://goo.gl/U2Uwz2
#
# Features are computed from a digitized image of a fine needle
# aspirate (FNA) of a breast mass.  They describe
# characteristics of the cell nuclei present in the image.
#
# Separating plane described above was obtained using
# Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree
# Construction Via Linear Programming." Proceedings of the 4th
# Midwest Artificial Intelligence and Cognitive Science Society,
# pp. 97-101, 1992], a classification method which uses linear
# programming to construct a decision tree.  Relevant features
# were selected using an exhaustive search in the space of 1-4
# features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane
# in the 3-dimensional space is that described in:
# [K. P. Bennett and O. L. Mangasarian: "Robust Linear
# Programming Discrimination of Two Linearly Inseparable Sets",
# Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server:
#
# ftp ftp.cs.wisc.edu
# cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# .. dropdown:: References
#
#   - W.N. Street, W.H. Wolberg and O.L. Mangasarian. Nuclear feature extraction
#     for breast tumor diagnosis. IS&T/SPIE 1993 International Symposium on
#     Electronic Imaging: Science and Technology, volume 1905, pages 861-870,
#     San Jose, CA, 1993.
#   - O.L. Mangasarian, W.N. Street and W.H. Wolberg. Breast cancer diagnosis and
#     prognosis via linear programming. Operations Research, 43(4), pages 570-577,
#     July-August 1995.
#   - W.H. Wolberg, W.N. Street, and O.L. Mangasarian. Machine learning techniques
#     to diagnose breast cancer from fine-needle aspirates. Cancer Letters 77 (1994)
#     163-171.

# %% [markdown]
# ### 2. Разбейте данные на два набора обучающий и тестовый при помощи train_test_split, зафиксировав random_state=0. Выведите размеры полученных наборов.

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
x_train.shape, x_test.shape
# Out:
# ((455, 30), (114, 30))

# %% [markdown]
# ### 3. Используя GridSearchCV, подберите наилучшую модель классификатора на обучающем наборе данных, выбирая между методом опорных векторов и деревом решений, подобрав наилучшие гиперпараметры для этих моделей, используя следующие сетки гиперпараметров. Выведите получившуюся модель с наилучшими значениями гиперпараметров.

# %%
param_svc= {'classifier': [SVC()], 
            'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100]}
param_tree = {'classifier': [DecisionTreeClassifier(random_state = 42)],
              "classifier__max_depth": [1, 3, 5, 7, 10],
              "classifier__min_samples_leaf": [1, 3, 5, 10],
              "classifier__criterion": ["gini", "entropy"]}

# %%
param_grid = [param_svc, param_tree]
pipe = Pipeline([('classifier', SVC())])
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('classifier', SVC())],
#  'transform_input': None,
#  'verbose': False,
#  'classifier': SVC(),
#  'classifier__C': 1.0,
#  'classifier__break_ties': False,
#  'classifier__cache_size': 200,
#  'classifier__class_weight': None,
#  'classifier__coef0': 0.0,
#  'classifier__decision_function_shape': 'ovr',
#  'classifier__degree': 3,
#  'classifier__gamma': 'scale',
#  'classifier__kernel': 'rbf',
#  'classifier__max_iter': -1,
#  'classifier__probability': False,
#  'classifier__random_state': None,
#  'classifier__shrinking': True,
#  'classifier__tol': 0.001,
#  'classifier__verbose': False}

# %%
gs = GridSearchCV(estimator=pipe,
                  param_grid=param_grid,
                  cv = 5)

# %%
gs.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Pipeline(steps=[('classifier', SVC())]),
#              param_grid=[{'classifier': [SVC()],
#                           'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100]},
#                          {'classifier': [DecisionTreeClassifier(random_state=42)],
#                           'classifier__criterion': ['gini', 'entropy'],
#                           'classifier__max_depth': [1, 3, 5, 7, 10],
#                           'classifier__min_samples_leaf': [1, 3, 5, 10]}])

# %%
pd.DataFrame(gs.cv_results_)[['params', 'mean_test_score']]
# Out:
#                                                params  mean_test_score
# 0       {'classifier': SVC(), 'classifier__C': 0.001}         0.637363
# 1        {'classifier': SVC(), 'classifier__C': 0.01}         0.701099
# 2         {'classifier': SVC(), 'classifier__C': 0.1}         0.887912
# 3           {'classifier': SVC(), 'classifier__C': 1}         0.905495
# 4          {'classifier': SVC(), 'classifier__C': 10}         0.914286
# 5         {'classifier': SVC(), 'classifier__C': 100}         0.931868
# 6   {'classifier': DecisionTreeClassifier(random_s...         0.892308
# 7   {'classifier': DecisionTreeClassifier(random_s...         0.892308
# 8   {'classifier': DecisionTreeClassifier(random_s...         0.892308
# 9   {'classifier': DecisionTreeClassifier(random_s...         0.892308
# 10  {'classifier': DecisionTreeClassifier(random_s...         0.918681
# 11  {'classifier': DecisionTreeClassifier(random_s...         0.916484
# 12  {'classifier': DecisionTreeClassifier(random_s...         0.920879
# 13  {'classifier': DecisionTreeClassifier(random_s...         0.923077
# 14  {'classifier': DecisionTreeClassifier(random_s...         0.923077
# 15  {'classifier': DecisionTreeClassifier(random_s...         0.916484
# 16  {'classifier': DecisionTreeClassifier(random_s...         0.931868
# 17  {'classifier': DecisionTreeClassifier(random_s...         0.923077
# 18  {'classifier': DecisionTreeClassifier(random_s...         0.916484
# 19  {'classifier': DecisionTreeClassifier(random_s...         0.918681
# 20  {'classifier': DecisionTreeClassifier(random_s...         0.927473
# 21  {'classifier': DecisionTreeClassifier(random_s...         0.923077
# 22  {'classifier': DecisionTreeClassifier(random_s...         0.923077
# 23  {'classifier': DecisionTreeClassifier(random_s...         0.918681
# 24  {'classifier': DecisionTreeClassifier(random_s...         0.927473
# 25  {'classifier': DecisionTreeClassifier(random_s...         0.923077
# 26  {'classifier': DecisionTreeClassifier(random_s...         0.885714
# 27  {'classifier': DecisionTreeClassifier(random_s...         0.885714
# 28  {'classifier': DecisionTreeClassifier(random_s...         0.885714
# 29  {'classifier': DecisionTreeClassifier(random_s...         0.885714
# 30  {'classifier': DecisionTreeClassifier(random_s...         0.909890
# 31  {'classifier': DecisionTreeClassifier(random_s...         0.909890
# 32  {'classifier': DecisionTreeClassifier(random_s...         0.909890
# 33  {'classifier': DecisionTreeClassifier(random_s...         0.905495
# 34  {'classifier': DecisionTreeClassifier(random_s...         0.927473
# 35  {'classifier': DecisionTreeClassifier(random_s...         0.931868
# 36  {'classifier': DecisionTreeClassifier(random_s...         0.925275
# 37  {'classifier': DecisionTreeClassifier(random_s...         0.909890
# 38  {'classifier': DecisionTreeClassifier(random_s...         0.923077
# 39  {'classifier': DecisionTreeClassifier(random_s...         0.934066
# 40  {'classifier': DecisionTreeClassifier(random_s...         0.925275
# 41  {'classifier': DecisionTreeClassifier(random_s...         0.909890
# 42  {'classifier': DecisionTreeClassifier(random_s...         0.923077
# 43  {'classifier': DecisionTreeClassifier(random_s...         0.934066
# 44  {'classifier': DecisionTreeClassifier(random_s...         0.925275
# 45  {'classifier': DecisionTreeClassifier(random_s...         0.909890

# %%
gs.best_params_
# Out:
# {'classifier': DecisionTreeClassifier(random_state=42),
#  'classifier__criterion': 'entropy',
#  'classifier__max_depth': 7,
#  'classifier__min_samples_leaf': 3}

# %%
gs.best_score_
# Out:
# np.float64(0.9340659340659341)

# %% [markdown]
# ### 4. Оцените качество наилучшей модели, выведя значения метрик accuracy и f1-score на тестовых данных.

# %%
gs.score(x_test, y_test)
# Out:
# 0.9298245614035088

# %%
y_test_predict = gs.predict(x_test)
accuracy = gs.score(x_test, y_test)
accuracy
# Out:
# 0.9298245614035088

# %%
f1 = metrics.f1_score(y_test, y_test_predict)
f1
# Out:
# 0.9384615384615385

# %% [markdown]
# ### 5. Добавьте масштабирование данных методом min-max в метод опорных векторов и снова подберите наилучшую модель классификатора, выбирая между методом опорных векторов и деревом решений с теми же диапазонами гиперпараметров. Выведите получившуюся модель с наилучшими значениями гиперпараметров.

# %%
param_svc_scaler= {'classifier': [SVC()], 'preprocessing':[MinMaxScaler()],
            'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100]}
param_tree_scaler = {'classifier': [DecisionTreeClassifier(random_state = 42)], 'preprocessing':[None],
              "classifier__max_depth": [1, 3, 5, 7, 10],
              "classifier__min_samples_leaf": [1, 3, 5, 10],
              "classifier__criterion": ["gini", "entropy"]}

param_grid_scaler = [param_svc_scaler, param_tree_scaler]

# %%
pipe_scaler = Pipeline([('preprocessing', MinMaxScaler()), ('classifier', SVC())])

# %%
gs_scaler = GridSearchCV(estimator = pipe_scaler,
                       param_grid = param_grid_scaler,
                       cv = 5)

# %%
gs_scaler.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessing', MinMaxScaler()),
#                                        ('classifier', SVC())]),
#              param_grid=[{'classifier': [SVC()],
#                           'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100],
#                           'preprocessing': [MinMaxScaler()]},
#                          {'classifier': [DecisionTreeClassifier(random_state=42)],
#                           'classifier__criterion': ['gini', 'entropy'],
#                           'classifier__max_depth': [1, 3, 5, 7, 10],
#                           'classifier__min_samples_leaf': [1, 3, 5, 10],
#                           'preprocessing': [None]}])

# %%
pd.DataFrame(gs_scaler.cv_results_)[['param_classifier', 'param_preprocessing', 'mean_test_score']]
# Out:
#                            param_classifier param_preprocessing  \
# 0                                     SVC()      MinMaxScaler()
# 1                                     SVC()      MinMaxScaler()
# 2                                     SVC()      MinMaxScaler()
# 3                                     SVC()      MinMaxScaler()
# 4                                     SVC()      MinMaxScaler()
# 5                                     SVC()      MinMaxScaler()
# 6   DecisionTreeClassifier(random_state=42)                None
# 7   DecisionTreeClassifier(random_state=42)                None
# 8   DecisionTreeClassifier(random_state=42)                None
# 9   DecisionTreeClassifier(random_state=42)                None
# 10  DecisionTreeClassifier(random_state=42)                None
# 11  DecisionTreeClassifier(random_state=42)                None
# 12  DecisionTreeClassifier(random_state=42)                None
# 13  DecisionTreeClassifier(random_state=42)                None
# 14  DecisionTreeClassifier(random_state=42)                None
# 15  DecisionTreeClassifier(random_state=42)                None
# 16  DecisionTreeClassifier(random_state=42)                None
# 17  DecisionTreeClassifier(random_state=42)                None
# 18  DecisionTreeClassifier(random_state=42)                None
# 19  DecisionTreeClassifier(random_state=42)                None
# 20  DecisionTreeClassifier(random_state=42)                None
# 21  DecisionTreeClassifier(random_state=42)                None
# 22  DecisionTreeClassifier(random_state=42)                None
# 23  DecisionTreeClassifier(random_state=42)                None
# 24  DecisionTreeClassifier(random_state=42)                None
# 25  DecisionTreeClassifier(random_state=42)                None
# 26  DecisionTreeClassifier(random_state=42)                None
# 27  DecisionTreeClassifier(random_state=42)                None
# 28  DecisionTreeClassifier(random_state=42)                None
# 29  DecisionTreeClassifier(random_state=42)                None
# 30  DecisionTreeClassifier(random_state=42)                None
# 31  DecisionTreeClassifier(random_state=42)                None
# 32  DecisionTreeClassifier(random_state=42)                None
# 33  DecisionTreeClassifier(random_state=42)                None
# 34  DecisionTreeClassifier(random_state=42)                None
# 35  DecisionTreeClassifier(random_state=42)                None
# 36  DecisionTreeClassifier(random_state=42)                None
# 37  DecisionTreeClassifier(random_state=42)                None
# 38  DecisionTreeClassifier(random_state=42)                None
# 39  DecisionTreeClassifier(random_state=42)                None
# 40  DecisionTreeClassifier(random_state=42)                None
# 41  DecisionTreeClassifier(random_state=42)                None
# 42  DecisionTreeClassifier(random_state=42)                None
# 43  DecisionTreeClassifier(random_state=42)                None
# 44  DecisionTreeClassifier(random_state=42)                None
# 45  DecisionTreeClassifier(random_state=42)                None
#
#     mean_test_score
# 0          0.637363
# 1          0.637363
# 2          0.949451
# 3          0.980220
# 4          0.973626
# 5          0.953846
# 6          0.892308
# 7          0.892308
# 8          0.892308
# 9          0.892308
# 10         0.918681
# 11         0.916484
# 12         0.920879
# 13         0.923077
# 14         0.923077
# 15         0.916484
# 16         0.931868
# 17         0.923077
# 18         0.916484
# 19         0.918681
# 20         0.927473
# 21         0.923077
# 22         0.923077
# 23         0.918681
# 24         0.927473
# 25         0.923077
# 26         0.885714
# 27         0.885714
# 28         0.885714
# 29         0.885714
# 30         0.909890
# 31         0.909890
# 32         0.909890
# 33         0.905495
# 34         0.927473
# 35         0.931868
# 36         0.925275
# 37         0.909890
# 38         0.923077
# 39         0.934066
# 40         0.925275
# 41         0.909890
# 42         0.923077
# 43         0.934066
# 44         0.925275
# 45         0.909890

# %%
gs_scaler.best_params_
# Out:
# {'classifier': SVC(), 'classifier__C': 1, 'preprocessing': MinMaxScaler()}

# %% [markdown]
# ### 6. Оцените качество полученной наилучшей модели с учётом масштабирования данных, выведя значения метрик accuracy и f1-score на тестовых данных. Сделайте вывод о том нужно ли было делать масштабирование данных.

# %%
gs_scaler.score(x_test, y_test), accuracy
# Out:
# (0.9736842105263158, 0.9298245614035088)

# %%
y_test_predict_scaler = gs_scaler.predict(x_test)
metrics.f1_score(y_test, y_test_predict_scaler), f1
# Out:
# (0.9777777777777777, 0.9384615384615385)

# %% [markdown]
# ## Задания для самостоятельного выполнения
# 1. Загрузите встроенный датасет `load_iris`. Обозначьте данные за `X`, а целевую переменную за `y`.
# 2. Разбейте данные на два набора: обучающий и тестовый, взяв в тестовый набор 20% данных и указав random_state=0.
# 3. Используя `GridSearchCV`, подберите наилучшую модель классификатора на обучающем наборе данных, выбирая между методом логистической регрессии и деревом со следующими наборами гиперпараметров: param_grid = [{'classifier': [LogisticRegression(max_iter=500)],'classifier__C': np.logspace(0,4,10), 'classifier__penalty': ['l2', 'l1'], 'classifier__solver': ['liblinear']}, {'classifier': [LogisticRegression(max_iter=500)],'classifier__C': np.logspace(0,4,10), 'classifier__penalty': ['l2'], 'classifier__solver': ['lbfgs', 'newton-cg']}, {'classifier': [DecisionTreeClassifier(random_state = 42)], 'classifier__max_depth': [1, 3, 5, 7], 'classifier__criterion': ["gini", "entropy"], 'classifier__max_features': [1, 2, 3]}]. Выведите получившуюся модель с наилучшими значениями гиперпараметров.
# 4. Оцените качество наилучшей модели, выведя значения метрик accuracy и f1-score на тестовых данных.
# 5. Добавьте стандартную нормализацию данных в метод логистической регрессии и снова подберите наилучшую модель классификатора, выбирая между методом логистической регрессии и деревом решений с теми же диапазонами гиперпараметров. Выведите получившуюся модель с наилучшими значениями гиперпараметров.
# 6. Оцените качество полученной наилучшей модели с учётом стандартной нормализации данных, выведя значения метрик accuracy и f1-score на тестовых данных. Сделайте вывод о том нужна ли здесь была нормализация данных.
# 7. Добавить в param_grid 3 модель k-ближайший соседей
# 8. Найти лучшую модель с RandomGridSearch

# %%
iris = load_iris()
X = iris.data
y = iris.target

X.shape, y.shape
# Out:
# ((150, 4), (150,))

# %%
data = pd.DataFrame(X, columns=iris.feature_names)
data['target'] = y
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train.shape, X_test.shape
# Out:
# ((120, 4), (30, 4))

# %%
param_grid = [{'classifier': [LogisticRegression(max_iter=500)],
'classifier__C': np.logspace(0,4,10), 'classifier__penalty': ['l2', 'l1'], 'classifier__solver': ['liblinear']},
{'classifier': [LogisticRegression(max_iter=500)],'classifier__C': np.logspace(0,4,10), 'classifier__penalty': ['l2'], 
'classifier__solver': ['lbfgs', 'newton-cg']}, {'classifier': [
DecisionTreeClassifier(random_state = 42)], 'classifier__max_depth': [1, 3, 5, 7],
'classifier__criterion': ["gini", "entropy"], 'classifier__max_features': [1, 2, 3]}]

pipe = Pipeline([('classifier', LogisticRegression(max_iter=500))])
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('classifier', LogisticRegression(max_iter=500))],
#  'transform_input': None,
#  'verbose': False,
#  'classifier': LogisticRegression(max_iter=500),
#  'classifier__C': 1.0,
#  'classifier__class_weight': None,
#  'classifier__dual': False,
#  'classifier__fit_intercept': True,
#  'classifier__intercept_scaling': 1,
#  'classifier__l1_ratio': None,
#  'classifier__max_iter': 500,
#  'classifier__multi_class': 'deprecated',
#  'classifier__n_jobs': None,
#  'classifier__penalty': 'l2',
#  'classifier__random_state': None,
#  'classifier__solver': 'lbfgs',
#  'classifier__tol': 0.0001,
#  'classifier__verbose': 0,
#  'classifier__warm_start': False}

# %%
gs = GridSearchCV(estimator=pipe,
                  param_grid=param_grid,
                  cv = 5)

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('classifier',
#                                         LogisticRegression(max_iter=500))]),
#              param_grid=[{'classifier': [LogisticRegression(max_iter=500)],
#                           'classifier__C': array([1.00000000e+00, 2.78255940e+00, 7.74263683e+00, 2.15443469e+01,
#        5.99484250e+01, 1.66810054e+02, 4.64158883e+02, 1.29154967e+03,
#        3.59381366e+03, 1.00000000e+04]),
#                           'classifier__penalty...
#                           'classifier__C': array([1.00000000e+00, 2.78255940e+00, 7.74263683e+00, 2.15443469e+01,
#        5.99484250e+01, 1.66810054e+02, 4.64158883e+02, 1.29154967e+03,
#        3.59381366e+03, 1.00000000e+04]),
#                           'classifier__penalty': ['l2'],
#                           'classifier__solver': ['lbfgs', 'newton-cg']},
#                          {'classifier': [DecisionTreeClassifier(random_state=42)],
#                           'classifier__criterion': ['gini', 'entropy'],
#                           'classifier__max_depth': [1, 3, 5, 7],
#                           'classifier__max_features': [1, 2, 3]}])

# %%
gs.best_params_
# Out:
# {'classifier': LogisticRegression(max_iter=500),
#  'classifier__C': np.float64(21.544346900318832),
#  'classifier__penalty': 'l1',
#  'classifier__solver': 'liblinear'}

# %%
accuracy = gs.score(X_test, y_test)

# %%
accuracy
# Out:
# 1.0

# %%
y_test_predict = gs.predict(X_test)
f1 = metrics.f1_score(y_test, y_test_predict)
f1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 2
#       1 y_test_predict = gs.predict(X_test)
# ----> 2 f1 = metrics.f1_score(y_test, y_test_predict)
#       3 f1
#
# File c:\Users\alexm\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File c:\Users\alexm\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1324, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1144 @validate_params(
#    1145     {
#    1146         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1171     zero_division="warn",
#    1172 ):
#    1173     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1174
#    1175     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1322     array([0.66666667, 1.        , 0.66666667])
#    1323     """
# -> 1324     return fbeta_score(
#    1325         y_true,
#    1326         y_pred,
#    1327         beta=1,
#    1328         labels=labels,
#    1329         pos_label=pos_label,
#    1330         average=average,
#    1331         sample_weight=sample_weight,
#    1332         zero_division=zero_division,
#    1333     )
#
# File c:\Users\alexm\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:189, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 global_skip_validation = get_config()["skip_parameter_validation"]
#     188 if global_skip_validation:
# --> 189     return func(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
#
# File c:\Users\alexm\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1517, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1336 @validate_params(
#    1337     {
#    1338         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1365     zero_division="warn",
#    1366 ):
#    1367     """Compute the F-beta score.
#    1368
#    1369     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1514     0.12...
#    1515     """
# -> 1517     _, _, f, _ = precision_recall_fscore_support(
#    1518         y_true,
#    1519         y_pred,
#    1520         beta=beta,
#    1521         labels=labels,
#    1522         pos_label=pos_label,
#    1523         average=average,
#    1524         warn_for=("f-score",),
#    1525         sample_weight=sample_weight,
#    1526         zero_division=zero_division,
#    1527     )
#    1528     return f
#
# File c:\Users\alexm\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:189, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 global_skip_validation = get_config()["skip_parameter_validation"]
#     188 if global_skip_validation:
# --> 189     return func(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
#
# File c:\Users\alexm\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1830, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1661 """Compute precision, recall, F-measure and support for each class.
#    1662
#    1663 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1827  array([2, 2, 2]))
#    1828 """
#    1829 _check_zero_division(zero_division)
# -> 1830 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1832 # Calculate tp_sum, pred_sum, true_sum ###
#    1833 samplewise = average == "samples"
#
# File c:\Users\alexm\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1613, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1611         if y_type == "multiclass":
#    1612             average_options.remove("samples")
# -> 1613         raise ValueError(
#    1614             "Target is %s but average='binary'. Please "
#    1615             "choose another average setting, one of %r." % (y_type, average_options)
#    1616         )
#    1617 elif pos_label not in (None, 1):
#    1618     warnings.warn(
#    1619         "Note that pos_label (set to %r) is ignored when "
#    1620         "average != 'binary' (got %r). You may use "
#    (...)
#    1623         UserWarning,
#    1624     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
