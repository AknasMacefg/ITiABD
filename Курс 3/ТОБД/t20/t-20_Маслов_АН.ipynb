# %% [markdown]
# # ИД23-1 Маслов АН
# ## Парсер Википедии (разработан с помощью Cursor)
# ### Парсинг проходил по датам 18-20 ноября (qyy1118.xml - qyy1120.xml), парсились только новые люди и люди у которых не было года или професии в файлах pyy1118.xml - pyy1120.xml

# %%
import requests
from bs4 import BeautifulSoup
import xml.etree.ElementTree as ET
import re
import time
from urllib.parse import unquote, urljoin, urlparse
import html
import sys
import io

# Проверка на UTF-8 в Jupyter/IPython
try:
    if hasattr(sys.stdout, 'buffer') and sys.stdout.encoding != 'utf-8':
        sys.stdout = io.TextIOWrapper(sys.stdout.buffer, encoding='utf-8')
    if hasattr(sys.stderr, 'buffer') and sys.stderr.encoding != 'utf-8':
        sys.stderr = io.TextIOWrapper(sys.stderr.buffer, encoding='utf-8')
except (AttributeError, ValueError):
    pass

# Конфигурация
BASE_URL = "https://ru.wikipedia.org"
CATEGORY_URL = "https://ru.wikipedia.org/wiki/Категория:Родившиеся_19_ноября"
EXISTING_XML = "pyy1119.xml"
OUTPUT_XML = "qyy1119.xml"

# Перечень профессий на русском языке
OCCUPATIONS = [
    "писатель", "поэт", "прозаик", "драматург", "журналист", "публицист", "эссеист", "критик", "литературный критик",
    "библиограф", "библиофил", "лексикограф", "литературовед", "историк литературы", "романист", "новеллист", "сатирик",
    "художник", "скульптор", "архитектор", "дизайнер", "иллюстратор", "график", "живописец", "портретист",
    "карикатурист", "гравёр", "художник-гравёр", "художник-график", "художник-постановщик", "художник-мультипликатор",
    "деятель изобразительного искусства", "керамист", "керамистка", "гобеленистка", "рисовальщик", "рисовальщица",
    "актёр", "актриса", "режиссёр", "кинорежиссёр", "сценарист", "оператор", "кинематографист", "кинооператор",
    "театральный деятель", "танцор", "хореограф", "балетмейстер", "артистка балета", "театральный актёр",
    "театральный педагог", "театральный критик", "театровед", "кинокритик", "киновед", "искусствовед",
    "музыкант", "композитор", "певец", "певица", "дирижёр", "пианист", "пианистка", "басистка", "скрипач", "виолончелист",
    "гитарист", "барабанщик", "трубач", "саксофонист", "вокалист", "оперный певец", "оперная певица",
    "учёный", "исследователь", "профессор", "преподаватель", "учитель", "лектор", "преподаватель университета", "ректор",
    "физик", "химик", "математик", "биолог", "ботаник", "геолог", "историк", "географ", "археолог", "лингвист",
    "антрополог", "этнограф", "палеонтолог", "палеоботаник", "вирусолог", "микробиолог", "биохимик", "физиолог",
    "анатом", "энтомолог", "зоолог", "орнитолог", "ихтиолог", "лепидоптеролог", "лихенолог", "селекционер",
    "филолог", "классицист", "классицистка", "нумизматка", "византолог", "востоковед", "африканист", "американист",
    "врач", "медик", "хирург", "психиатр", "невролог", "патолог", "фармаколог", "военный врач", "терапевт", "педиатр",
    "гинеколог", "офтальмолог", "стоматолог", "ветеринар", "акушер", "акушерка",
    "инженер", "конструктор", "изобретатель", "авиационный инженер", "горный инженер", "военный инженер",
    "инженер-строитель", "инженер-механик", "инженер-гидротехник", "инженер-архитектор", "инженер-электрик",
    "политик", "государственный деятель", "дипломат", "юрист", "адвокат", "практикующий юрист", "судья",
    "прокурор", "депутат", "посол", "министр", "президент", "премьер-министр", "губернатор", "мэр", "сенатор",
    "военный деятель", "военнослужащий", "офицер", "полководец", "лётчик", "солдат", "капитан", "генерал",
    "адмирал", "командир", "разведчик", "мемуарист", "майор", "полковник", "лейтенант", "сержант",
    "спортсмен", "футболист", "тренер", "тренер-преподаватель", "бейсболист", "хоккеист", "биатлонист",
    "бобслеист", "скелетонист", "автогонщик", "раллийный автогонщик", "баскетболист", "теннисист", "боксёр",
    "легкоатлет", "пловец", "лыжник", "конькобежец", "велосипедист", "шахматист", "шашист",
    "предприниматель", "бизнесмен", "торговец", "банкир", "менеджер", "промышленник", "магнат", "инвестор",
    "священник", "религиозный деятель", "монах", "раввин", "настоятель", "миссионер", "теолог", "богослов",
    "философ", "философ науки", "историк науки", "культуролог", "социолог", "экономист", "политолог",
    "библиотекарь", "переводчик", "редактор", "издатель", "фотограф", "кинопродюсер", "телепродюсер",
    "телеведущий", "радиоведущий", "подкастер", "обозреватель", "корреспондент", "репортёр", "комментатор",
    "модель", "фотомодель", "порноактриса", "эротическая модель", "участница конкурса красоты",
    "блогер", "видеоблогер", "стример", "тиктокер", "ютубер",
    "модельер", "кутюрье", "переплётчица", "швея", "портной",
    "долгожитель", "аристократ", "аристократка", "фрейлина", "аэронавт", "капитан судна",
    "капитан речного флота", "шеф-повар", "агроном", "доярка", "свинарка", "шахтёр", "рабочий", "крестьянин",
    "партизан", "революционерка", "активист", "активистка", "гуманистка", "правозащитница",
    "коллекционер", "коллекционерка", "коллекционер искусства", "нумизмат", "филателист"
]

# Категории профессий и соответствующие им ключевые слова на русском языке
OCCUPATION_CATEGORIES = {
    "Писатель": ["поэт", "прозаик", "драматург", "журналист", "публицист", "переводчик", "редактор", "издатель", 
                 "эссеист", "критик", "литературный критик", "библиограф", "библиофил", "лексикограф", "литературовед", 
                 "историк литературы", "романист", "новеллист", "сатирик", "писатель"],
    "Художник": ["скульптор", "архитектор", "дизайнер", "иллюстратор", "график", "живописец", "портретист",
                 "карикатурист", "гравёр", "художник-гравёр", "художник-график", "художник-постановщик", 
                 "художник-мультипликатор", "деятель изобразительного искусства", "керамист", "керамистка", 
                 "гобеленистка", "рисовальщик", "рисовальщица", "фотограф", "художник"],
    "Кинематографист": ["актёр", "актриса", "режиссёр", "кинорежиссёр", "сценарист", "оператор", "кинематографист", 
                        "кинооператор", "кинокритик", "киновед", "кинопродюсер"],
    "Театральный деятель": ["актёр", "актриса", "режиссёр", "танцор", "хореограф", 
                            "балетмейстер", "артистка балета", "театральный актёр", "театральный педагог", 
                            "театральный критик", "театровед", "театральный деятель"],
    "Музыкант": ["композитор", "певец", "певица", "дирижёр", "пианист", "пианистка", "басистка", 
                 "скрипач", "виолончелист", "гитарист", "барабанщик", "трубач", "саксофонист", "вокалист", 
                 "оперный певец", "оперная певица", "музыкант"],
    "Учёный": ["исследователь", "профессор", "преподаватель", "учитель", "лектор", "преподаватель университета", 
               "ректор", "физик", "химик", "математик", "биолог", "ботаник", "геолог", "историк", "географ", 
               "археолог", "лингвист", "антрополог", "этнограф", "палеонтолог", "палеоботаник", "вирусолог", 
               "микробиолог", "биохимик", "физиолог", "анатом", "энтомолог", "зоолог", "орнитолог", "ихтиолог", 
               "лепидоптеролог", "лихенолог", "селекционер", "филолог", "классицист", "классицистка", 
               "нумизматка", "византолог", "востоковед", "африканист", "американист", "искусствовед", "учёный"],
    "Врач": ["медик", "хирург", "психиатр", "невролог", "патолог", "фармаколог", "военный врач", 
             "терапевт", "педиатр", "гинеколог", "офтальмолог", "стоматолог", "ветеринар", "акушер", "акушерка", "врач"],
    "Инженер": ["конструктор", "изобретатель", "авиационный инженер", "горный инженер", "военный инженер",
                "инженер-строитель", "инженер-механик", "инженер-гидротехник", "инженер-архитектор", "инженер-электрик", "инженер"],
    "Военный деятель": ["военнослужащий", "офицер", "полководец", "лётчик", "солдат", "капитан", 
                        "генерал", "адмирал", "командир", "разведчик", "мемуарист", "майор", "полковник", 
                        "лейтенант", "сержант", "военный деятель"],
    "Государственный деятель": ["политик", "дипломат", "юрист", "адвокат", "практикующий юрист", 
                                 "судья", "прокурор", "депутат", "посол", "министр", "президент", "премьер-министр", 
                                 "губернатор", "мэр", "сенатор", "государственный деятель"],
    "Предприниматель": ["бизнесмен", "торговец", "банкир", "менеджер", "промышленник", "магнат", "инвестор", "предприниматель"],
    "Религиозный деятель": ["священник", "монах", "раввин", "настоятель", "миссионер", "теолог", "богослов", "религиозный деятель"],
    "Философ": ["философ науки", "историк науки", "культуролог", "социолог", "экономист", "политолог", "философ"],
    "Спортсмен": ["футболист", "тренер", "тренер-преподаватель", "бейсболист", "хоккеист", "биатлонист",
                  "бобслеист", "скелетонист", "автогонщик", "раллийный автогонщик", "баскетболист", "теннисист", 
                  "боксёр", "легкоатлет", "пловец", "лыжник", "конькобежец", "велосипедист", "шахматист", "шашист", "спортсмен"],
    "Медиа": ["телеведущий", "радиоведущий", "подкастер", "обозреватель", "корреспондент", "репортёр", "комментатор", 
              "блогер", "видеоблогер", "стример", "тиктокер", "ютубер"],
    "Модель": ["фотомодель", "порноактриса", "эротическая модель", "участница конкурса красоты", "модель"],
    "Модельер": ["кутюрье", "переплётчица", "швея", "портной", "модельер"],
    "Персона": ["долгожитель", "аристократ", "аристократка", "фрейлина", "аэронавт", "капитан судна",
                "капитан речного флота", "шеф-повар", "агроном", "доярка", "свинарка", "шахтёр", "рабочий", 
                "крестьянин", "партизан", "революционерка", "активист", "активистка", "гуманистка", "правозащитница",
                "коллекционер", "коллекционерка", "коллекционер искусства", "нумизмат", "филателист", "библиотекарь", "персона"]
}

print("Конфигурация загружена.")
# Out:
# Конфигурация загружена.

# %%
def normalize_name(name):
    """Normalize a name to a standard format for comparison"""
    if not name:
        return ''
    # Декодировать URL-encoded строки
    normalized = unquote(name)
    # Заменить пробелы на подчеркивания для соответствия формату XML
    normalized = normalized.replace(' ', '_')
    return normalized

def load_existing_entries(xml_file):
    """Загрузить существующие записи из XML-файла с их данными для сравнения"""
    existing_data = {}  # Словарь: normalized_name -> {'year': year, 'occupation_data': occupation_data}
    existing_names = set()  # Множество всех вариантов имен для быстрого поиска
    
    try:
        tree = ET.parse(xml_file)
        root = tree.getroot()
        for psn in root.findall('psn'):
            name = psn.get('h', '')
            if name:
                # Нормализовать имя
                normalized = normalize_name(name)
                
                # Извлечь год и профессию
                year = psn.get('y', '')
                occupation_attr = psn.get('p', '')
                
                # Извлечь профессию в формате "Категория;элемент1, элемент2, ..."
                occupation_data = None
                if occupation_attr:
                    if ';' in occupation_attr:
                        parts = occupation_attr.split(';', 1)
                        category = parts[0].strip()
                        occupations_str = parts[1].strip()
                        # Разделить элементы по запятой
                        occupations = [occ.strip() for occ in occupations_str.split(',') if occ.strip()]
                        occupation_data = {
                            'category': category,
                            'occupations': occupations
                        }
                    else:
                        # Старый формат без категории - используем как список профессий
                        occupations = [occ.strip() for occ in occupation_attr.split(',') if occ.strip()]
                        if occupations:
                            occupation_data = {
                                'category': 'Персона',
                                'occupations': occupations
                            }
                
                # Сохранить данные в словарь
                existing_data[normalized] = {
                    'year': year if year and year != 'yyyy' else None,
                    'occupation_data': occupation_data
                }
                
                # Добавить все варианты имен в множество для быстрого поиска
                existing_names.add(normalized)
                existing_names.add(name)
                try:
                    from urllib.parse import quote
                    existing_names.add(quote(normalized, safe=''))
                    existing_names.add(quote(name, safe=''))
                except:
                    pass
        
        print(f"Загружено {len(existing_data)} существующих записей из {xml_file}")
        print(f"Пример записей: {list(existing_data.keys())[:3] if existing_data else 'None'}")
    except FileNotFoundError:
        print(f"Файл {xml_file} не найден, начинаем с чистого листа")
    except Exception as e:
        print(f"Ошибка загрузки {xml_file}: {e}")
    
    return existing_data, existing_names

existing_data, existing_names = load_existing_entries(EXISTING_XML)
# Out:
# Загружено 1314 существующих записей из pyy1119.xml
# Пример записей: ['Абаджян,_Гаррий_Артушевич', 'Абдеррахим,_Муни', 'Абдулкагиров,_Магомед_Камингаджиевич']

# %%
def get_page_content(url):
    """Ищет содержимое страницы Википедии"""
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
        }
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        return BeautifulSoup(response.content, 'html.parser')
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return None

def extract_year_of_birth(soup):
    """Вытаскивает год рождения из страницы Википедии"""
    # Пытаемся найти в инфобоксе (самый надежный)
    infobox = soup.find('table', class_='infobox')
    if infobox:
        # Ищет "Дата рождения" или "Родился/Родилась"
        for row in infobox.find_all('tr'):
            th = row.find('th')
            if th:
                th_text = th.get_text().strip()
                if 'Дата рождения' in th_text or 'Родился' in th_text or 'Родилась' in th_text:
                    td = row.find('td')
                    if td:
                        text = td.get_text()
                        # Ищем шаблоны даты с 4-значным годом (между 1000-2099)
                        years = re.findall(r'\b(1[0-9]{3}|20[0-2][0-9])\b', text)
                        if years:
                            # Возвращаем первый найденный год
                            return years[0]
    
    # Пытаемся найти в первом абзаце
    first_para = soup.find('div', class_='mw-parser-output')
    if first_para:
        paragraphs = first_para.find_all('p', recursive=False)
        for p in paragraphs[:3]:  # Проверяем первые 3 абзаца
            text = p.get_text()
            # Ищем шаблоны вроде "родился 14 ноября 1900 года" или "родился в 1900 году"
            patterns = [
                r'(?:родился|родилась)\s+(?:14\s+ноября\s+)?(\d{4})\s*(?:года|г\.|г)',
                r'(?:родился|родилась)\s+в\s+(\d{4})\s*(?:году|г\.|г)',
                r'(\d{4})\s*(?:года|г\.|г)\s*—\s*(?:родился|родилась)',
                r'14\s+ноября\s+(\d{4})',  # Прямой шаблон для "XX ноября YYYY"
            ]
            for pattern in patterns:
                year_match = re.search(pattern, text, re.IGNORECASE)
                if year_match:
                    year = year_match.group(1)
                    if 1000 <= int(year) <= 2099:
                        return year
            
            # Или просто найти 4-значный год рядом с "XX ноября" или "ноября"
            if '14 ноября' in text or 'ноября' in text:
                years = re.findall(r'\b(1[0-9]{3}|20[0-2][0-9])\b', text)
                if years:
                    return years[0]
    
    return None

def extract_occupation(soup):
    """Вытаскиваем профессию со страницы Википедии"""
    occupations_found = []
    category_found = None
    
    # Пытаемся найти в инфобоксе (самый надежный)
    infobox = soup.find('table', class_='infobox')
    if infobox:
        # Ищет "Род деятельности" или "Профессия"
        for row in infobox.find_all('tr'):
            th = row.find('th')
            if th:
                th_text = th.get_text().strip()
                if 'Род деятельности' in th_text or 'Профессия' in th_text or 'Род занятий' in th_text:
                    td = row.find('td')
                    if td:
                        text = td.get_text().lower()
                        # Извлекаем профессии
                        for occ in OCCUPATIONS:
                            if occ.lower() in text and occ not in occupations_found:
                                occupations_found.append(occ)
    
    # Пытаемся найти в категориях (внизу страницы)
    categories = soup.find('div', id='catlinks')
    if categories:
        cat_text = categories.get_text().lower()
        # Проверяем каждую категорию
        for cat_name, occs in OCCUPATION_CATEGORIES.items():
            # Проверяем каждое ключевое слово в категории
            for occ in occs:
                if occ.lower() in cat_text:
                    if not category_found:  # Берем первую найденную категорию
                        category_found = cat_name
                    if occ not in occupations_found:
                        occupations_found.append(occ)
                    break
    
    # Пытаемся найти в первом абзаце, если не нашли ранее
    if not occupations_found:
        first_para = soup.find('div', class_='mw-parser-output')
        if first_para:
            paragraphs = first_para.find_all('p', recursive=False)
            for p in paragraphs[:3]:
                text = p.get_text().lower()
                for occ in OCCUPATIONS:
                    if occ.lower() in text and occ not in occupations_found:
                        occupations_found.append(occ)
    
    # Удаляем "персона" из профессий, если присутствует
    occupations_found = [occ for occ in occupations_found if occ != 'персона']
    
    # Если категория не найдена через категории страницы, определяем её по найденным профессиям
    if not category_found and occupations_found:
        # Ищем категорию по найденным профессиям
        for cat_name, occs in OCCUPATION_CATEGORIES.items():
            for occ in occupations_found:
                if occ in occs:
                    category_found = cat_name
                    break
            if category_found:
                break
    
    if occupations_found:
        # Возвращаем словарь с категорией и профессиями
        return {
            'category': category_found or 'Персона',
            'occupations': occupations_found[:5]  # Ограничиваем до 5 профессий
        }
    
    return None

print("Helper functions defined")
# Out:
# Helper functions defined

# %%
def parse_category_page(url):
    """Парсит страницу категории и возвращает список ссылок на людей и ссылку на следующую страницу"""
    soup = get_page_content(url)
    if not soup:
        return [], None
    
    person_links = []
    
    # Находит все ссылки на странице категории
    # Пытается разные возможные контейнеры
    content = soup.find('div', id='mw-pages')
    if not content:
        content = soup.find('div', class_='mw-category')
    if not content:
        content = soup.find('div', class_='mw-category-group')
    
    # Список префиксов специальных страниц для пропуска
    skip_prefixes = ['Категория:', 'Файл:', 'Шаблон:', 'Обсуждение:', 'Участник:', 'Портал:', 
                     'Википедия:', 'Служебная:', 'Медиа:', 'Справка:', 'Обсуждение_шаблона:',
                     'Обсуждение_участника:', 'Обсуждение_файла:', 'Обсуждение_категории:']
    
    if content:
        # Находит все ссылки в списке категории
        for link in content.find_all('a', href=True):
            href = link['href']
            if href.startswith('/wiki/'):
                title_part = href.split('/wiki/')[1].split('#')[0]
                # Декодируем для проверки, является ли это специальной страницей
                title_decoded = unquote(title_part)
                
                # Пропускаем специальные страницы
                should_skip = False
                for prefix in skip_prefixes:
                    if title_part.startswith(prefix) or title_decoded.startswith(prefix):
                        should_skip = True
                        break
                
                if not should_skip:
                    full_url = urljoin(BASE_URL, href)
                    # Используем URL-кодированный заголовок для согласованности с форматом XML  
                    person_links.append((title_part, full_url))
    
    # Удаляем дубликаты, сохраняя порядок
    seen = set()
    unique_links = []
    for title, url in person_links:
        if title not in seen:
            seen.add(title)
            unique_links.append((title, url))
    
    # Находит ссылку "Следующая страница" - улучшенный поиск
    next_link = None
    
    # Метод 1: Ищет ссылку с точным текстом "Следующая страница"
    for link in soup.find_all('a', href=True):
        link_text = link.get_text().strip()
        if link_text == 'Следующая страница':
            next_link = urljoin(BASE_URL, link['href'])
            break
    
    # Метод 2: Ищет в навигационных блоках (более комплексный поиск)
    if not next_link:
        # Пытается разные навигационные контейнеры
        nav_selectors = [
            ('div', {'class': 'mw-category-navigation'}),
            ('div', {'id': 'mw-pages'}),
            ('div', {'class': 'mw-category'}),
        ]
        
        for tag, attrs in nav_selectors:
            nav_divs = soup.find_all(tag, attrs)
            for nav_div in nav_divs:
                for link in nav_div.find_all('a', href=True):
                    link_text = link.get_text().strip()
                    # Проверяет наличие "Следующая страница" или вариаций
                    if 'Следующая' in link_text or 'следующая' in link_text or 'Следующая страница' in link_text:
                        href = link.get('href')
                        if href and href.startswith('/wiki/'):
                            next_link = urljoin(BASE_URL, href)
                            break
                if next_link:
                    break
            if next_link:
                break
    
    # Метод 3: Ищет ссылки с параметром "from" (пагинация)  
    if not next_link:
        # Страницы категорий Wikipedia используют параметр "from" для пагинации
        for link in soup.find_all('a', href=True):
            href = link.get('href', '')
            if 'from=' in href and 'Категория:Родившиеся_14_ноября' in href:
                next_link = urljoin(BASE_URL, href)
                break
    
    # Метод 4: Ищет класс "next" или подобный
    if not next_link:
        next_links = soup.find_all('a', class_=re.compile('next', re.I))
        for link in next_links:
            if link.get('href'):
                next_link = urljoin(BASE_URL, link['href'])
                break
    
    return unique_links, next_link

print("Category parser function defined")
# Out:
# Category parser function defined

# %%
def parse_person_page(url, name):
    """Парсим каждую персону"""
    soup = get_page_content(url)
    if not soup:
        return None
    
    # Вытаскивает год рождения
    year = extract_year_of_birth(soup)
    
    # Вытаскиваем информацию о профессии
    occupation_data = extract_occupation(soup)
    
    # Нормализуем имя для XML формата
    name_normalized = normalize_name(name)
    
    return {
        'year': year,
        'name': name_normalized, 
        'occupation_data': occupation_data 
    }

print("Person parser function defined")
# Out:
# Person parser function defined

# %%
def write_xml(persons, output_file):
    """Записываем информацию о людях в XML-файл"""
    root = ET.Element('persons')
    root.set('day', '14-11')
    root.set('comm', f'Parsed {len(persons)} persons')
    
    # Сортировка по году, потом по имени
    def sort_key(person):
        year = person.get('year')
        name = person.get('name', '')
        # Конвертируем год в строку для правильной сортировки
        year_str = str(year) if year is not None else '9999'
        return (year_str, name)
    
    sorted_persons = sorted(persons, key=sort_key)
    
    for person in sorted_persons:
        psn = ET.SubElement(root, 'psn')
        if person.get('year'):
            psn.set('y', str(person['year']))
        else:
            psn.set('y', 'yyyy')  # Плейсхолдер если год не был найден
        
        psn.set('h', person['name'])
        
        # добавить профессию в формате "Категория;элемент1, элемент2, ..."
        occupation_data = person.get('occupation_data')
        if occupation_data and occupation_data.get('occupations'):
            category = occupation_data.get('category', 'Персона')
            occupations = occupation_data.get('occupations', [])
            # Форматируем как "Категория;элемент1, элемент2, ..."
            occupation_str = f"{category};{', '.join(occupations)}"
            psn.set('p', occupation_str)
    
    # Запись в файл с правильной кодировкой UTF-8
    tree = ET.ElementTree(root)
    ET.indent(tree, space='  ')
    # Запись файла с декларацией XML
    with open(output_file, 'wb') as f:
        f.write('<?xml version="1.0" encoding="utf-8"?>\n'.encode('utf-8'))
        tree.write(f, encoding='utf-8', xml_declaration=False)
    print(f"Written {len(persons)} persons to {output_file}")

print("XML writer function defined")
# Out:
# XML writer function defined

# %%
# Основная функция
def main():
    all_persons = []
    current_url = CATEGORY_URL
    page_count = 0
    total_processed = 0
    total_skipped_identical = 0
    total_updated = 0
    total_new = 0
    total_failed = 0
    
    print(f"Начинаем парсинг категории: {CATEGORY_URL}")
    print(f"Загружено существующих записей: {len(existing_data)}")
    
    while current_url:
        page_count += 1
        print(f"\n{'='*60}")
        print(f"--- Парсинг страницы {page_count} ---")
        print(f"URL: {current_url}")
        print(f"{'='*60}")
        
        # Парсинг страницы категории
        person_links, next_link = parse_category_page(current_url)
        print(f"Найдено {len(person_links)} ссылок на людей на этой странице")
        
        if not person_links:
            print("Ссылки на людей не найдены, пытаемся продолжить...")
        
        # Проходим по каждой персоне
        for idx, (name, url) in enumerate(person_links, 1):
            # Нормализуем имя для проверки
            name_normalized = normalize_name(name)
            name_display = unquote(name).replace('_', ' ')  # для отображения
            
            print(f"[{idx}/{len(person_links)}] Обработка: {name_display}")
            person_data = parse_person_page(url, name)
            
            if not person_data:
                total_failed += 1
                print(f"  ✗ Не удалось извлечь данные")
                time.sleep(0.5)
                continue
            
            # Проверяем, существует ли уже такая персона
            if name_normalized in existing_data:
                existing = existing_data[name_normalized]
                new_year = person_data.get('year')
                new_occupation_data = person_data.get('occupation_data')
                existing_year = existing.get('year')
                existing_occupation_data = existing.get('occupation_data')
                
                # Если не нашли другой год, используем существующий
                if new_year is None:
                    person_data['year'] = existing_year
                    new_year = existing_year
                
                # Нормализуем годы для сравнения (обрабатываем None и 'yyyy')
                new_year_str = str(new_year) if new_year else None
                existing_year_str = str(existing_year) if existing_year else None
                
                # Проверяем, отличаются ли данные
                year_different = new_year_str != existing_year_str
                
                # Меняем данные, только если у оригинала нет профессии
                # Проверяем, пуста ли профессия у существующей записи
                existing_occ_empty = not existing_occupation_data or not existing_occupation_data.get('occupations')
                
                # Меняем профессию только если у существующей записи она пуста
                if existing_occ_empty and new_occupation_data and new_occupation_data.get('occupations'):
                    occupation_different = True
                    # Используем новую профессию
                    person_data['occupation_data'] = new_occupation_data
                else:
                    # Сохраняем существующую профессию (не меняем)
                    occupation_different = False
                    person_data['occupation_data'] = existing_occupation_data
                
                # Обновляем, если год отличается ИЛИ профессия была обновлена
                if year_different or occupation_different:
                    # Данные отличаются, добавляем в вывод (перезапишем)
                    all_persons.append(person_data)
                    total_updated += 1
                    changes = []
                    if year_different:
                        changes.append(f"год: {existing_year_str} → {new_year_str}")
                    if occupation_different:
                        existing_occ_str = ''
                        new_occ_str = ''
                        if existing_occupation_data:
                            existing_occ_str = f"{existing_occupation_data.get('category', '')}; {', '.join(existing_occupation_data.get('occupations', []))}"
                        if new_occupation_data:
                            new_occ_str = f"{new_occupation_data.get('category', '')}; {', '.join(new_occupation_data.get('occupations', []))}"
                        changes.append(f"профессия: '{existing_occ_str}' → '{new_occ_str}'")
                    print(f"  ↻ Обновление: {', '.join(changes)}")
                else:
                    # Данные идентичны, пропускаем
                    total_skipped_identical += 1
                    print(f"  ✓ Данные идентичны, пропускаем")
            else:
                # Новая персона, добавляем
                all_persons.append(person_data)
                total_new += 1
                year = person_data.get('year', 'N/A')
                occupation_data = person_data.get('occupation_data')
                if occupation_data:
                    occ_str = f"{occupation_data.get('category', '')}; {', '.join(occupation_data.get('occupations', []))}"
                else:
                    occ_str = 'N/A'
                print(f"  + Новая: Год: {year}, Профессия: {occ_str}")
            
            total_processed += 1
            
            # Чтобы не забанило
            time.sleep(0.5)
        
        # Переход к следующей странице 
        current_url = next_link
        if next_link:
            print(f"\n→ Переход к следующей странице: {next_link}")
        else:
            print(f"\n→ Следующих страниц не найдено, завершаем парсинг.")
            break
    
    print(f"\n{'='*60}")
    print(f"=== Парсинг завершен ===")
    print(f"Всего страниц запарсено: {page_count}")
    print(f"Всего персон обработано: {total_processed}")
    print(f"Всего новых персон: {total_new}")
    print(f"Всего обновлено (отличающиеся данные): {total_updated}")
    print(f"Всего пропущено (идентичные данные): {total_skipped_identical}")
    print(f"Всего не удалось извлечь: {total_failed}")
    print(f"{'='*60}")
    
    # Запись в XML
    if all_persons:
        write_xml(all_persons, OUTPUT_XML)
        print(f"\n✓ Успешно записано {len(all_persons)} персон в {OUTPUT_XML}")
    else:
        print("\n⚠ Нет персон для записи (все были идентичны существующим данным)")

# Запуск парсера
if __name__ == "__main__":
    main()
# Out:
# Начинаем парсинг категории: https://ru.wikipedia.org/wiki/Категория:Родившиеся_19_ноября
# Загружено существующих записей: 1314
#
# ============================================================
# --- Парсинг страницы 1 ---
# URL: https://ru.wikipedia.org/wiki/Категория:Родившиеся_19_ноября
# ============================================================
# Найдено 200 ссылок на людей на этой странице
# [1/200] Обработка: Абаджян, Гаррий Артушевич
#   ✓ Данные идентичны, пропускаем
# [2/200] Обработка: Абдеррахим, Муни
#   ↻ Обновление: профессия: 'Спортсмен; ' → 'Спортсмен; спортсмен'
#
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист, шахтёр'
# [180/200] Обработка: Бунке, Тамара
#   ✓ Данные идентичны, пропускаем
# [181/200] Обработка: Бургер, Антон
#   ✓ Данные идентичны, пропускаем
# [182/200] Обработка: Бурдиков, Михаил Геннадьевич
#   ✓ Данные идентичны, пропускаем
# [183/200] Обработка: Буркин, Юрий Александрович
#   ✓ Данные идентичны, пропускаем
# [184/200] Обработка: Бурмистрова, Наталья Олеговна
#   ✓ Данные идентичны, пропускаем
# [185/200] Обработка: Буткявичюс, Альгирдас
#   ✓ Данные идентичны, пропускаем
# [186/200] Обработка: Буэндиа, Мигель Маури
#   ✓ Данные идентичны, пропускаем
# [187/200] Обработка: Быканов, Владислав
#   ↻ Обновление: профессия: 'Конькобежец; ' → 'Спортсмен; спортсмен'
# [188/200] Обработка: Бьюкенен, Томас
#   ↻ Обновление: год: n/a → 1808
# [189/200] Обработка: Бьянки, Анджело
#   ✓ Данные идентичны, пропускаем
# [190/200] Обработка: Бэнкс, Маркус
#   ↻ Обновление: профессия: 'Баскетболист; ' → 'Спортсмен; баскетболист'
# [191/200] Обработка: Бэнфилд, Эдвард
#   + Новая: Год: 1916, Профессия: Философ; политолог
# [192/200] Обработка: Бюхлер, Кен
#   ↻ Обновление: профессия: 'Баскетболист; ' → 'Спортсмен; баскетболист'
# [193/200] Обработка: Вакри, Огюст
#   ✓ Данные идентичны, пропускаем
# [194/200] Обработка: Вакуленко, Юрий Евгеньевич
#   ✓ Данные идентичны, пропускаем
# [195/200] Обработка: Валенсуэла Мельид, Эдмундо Понсиано
#   ✓ Данные идентичны, пропускаем
# [196/200] Обработка: Валетова, Нина Петровна
#   ✓ Данные идентичны, пропускаем
# [197/200] Обработка: Валишевский, Казимир
#   ✓ Данные идентичны, пропускаем
# [198/200] Обработка: Вальдман, Мария
#   ✓ Данные идентичны, пропускаем
# [199/200] Обработка: Валюкевич, Ирина
#   ↻ Обновление: профессия: 'Легкоатлет; ' → 'Спортсмен; легкоатлет'
# [200/200] Обработка: Ван дер Хейде, Арьен
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
#
# → Переход к следующей странице: https://ru.wikipedia.org/w/index.php?title=%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%A0%D0%BE%D0%B4%D0%B8%D0%B2%D1%88%D0%B8%D0%B5%D1%81%D1%8F_19_%D0%BD%D0%BE%D1%8F%D0%B1%D1%80%D1%8F&pagefrom=%D0%92%D0%B0%D0%BD+%D0%AE%D0%B9#mw-pages
#
# ============================================================
# --- Парсинг страницы 2 ---
# URL: https://ru.wikipedia.org/w/index.php?title=%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%A0%D0%BE%D0%B4%D0%B8%D0%B2%D1%88%D0%B8%D0%B5%D1%81%D1%8F_19_%D0%BD%D0%BE%D1%8F%D0%B1%D1%80%D1%8F&pagefrom=%D0%92%D0%B0%D0%BD+%D0%AE%D0%B9#mw-pages
# ============================================================
# Найдено 200 ссылок на людей на этой странице
# [1/200] Обработка: Ван Юй
#   ↻ Обновление: профессия: 'Шахматист; ' → 'Спортсмен; шахматист'
# [2/200] Обработка: Ван-дер-Шкруф, Михаил Ипполитович
#   + Новая: Год: 1853, Профессия: Военный деятель; офицер, военнослужащий
# [3/200] Обработка: Ванаг, Рудольф Янович
#   ✓ Данные идентичны, пропускаем
# [4/200] Обработка: Варганова, Светлана Анатольевна
#   ↻ Обновление: профессия: 'Спортсмен; ' → 'Спортсмен; спортсмен'
# [5/200] Обработка: Василий (Мога)
#   ✓ Данные идентичны, пропускаем
# [6/200] Обработка: Васильев, Юрий Иванович (музыкант)
#   ✓ Данные идентичны, пропускаем
# [7/200] Обработка: Вейсе, Христиан Эрнст
#   ✓ Данные идентичны, пропускаем
# [8/200] Обработка: Венетидис, Стилианос
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
#

#   ↻ Обновление: профессия: 'Государственный деятель; ' → 'Военный деятель; генерал, политик'
# [82/200] Обработка: Голубев, Архип Тихонович
#   ↻ Обновление: профессия: 'Военный деятель; ' → 'Военный деятель; военнослужащий'
# [83/200] Обработка: Голубев, Михаил Кириллович
#   ✓ Данные идентичны, пропускаем
# [84/200] Обработка: Гольдони, Джорджо
#   ↻ Обновление: профессия: 'Волейболист; ' → 'Спортсмен; спортсмен'
# [85/200] Обработка: Голяков, Михаил Николаевич
#   ↻ Обновление: профессия: 'Военный деятель; ' → 'Военный деятель; сержант'
# [86/200] Обработка: Гомоюнов, Константин Константинович
#   ✓ Данные идентичны, пропускаем
# [87/200] Обработка: Гонсалвес, Фабио
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [88/200] Обработка: Гонсалес, Франсиско (теннисист)
#   ↻ Обновление: профессия: 'Теннисист; ' → 'Спортсмен; тренер'
# [89/200] Обработка: Горбач, Михаил Иванович
#   ✓ Данные идентичны, пропускаем
# [90/200] Обработка: Гордейчук, Екатерина Ильинична
#   ✓ Данные идентичны, пропускаем
# [91/200] Обработка: Горелик, Зиновий Самуилович
#   ↻ Обновление: профессия: 'Военный деятель; ' → 'Военный деятель; капитан'
# [92/200] Обработка: Горошко, Олег Владимирович
#   ↻ Обновление: профессия: 'Хоккеист; ' → 'Спортсмен; хоккеист'
# [93/200] Обработка: Горшанов, Иван Григорьевич
#   ↻ Обновление: профессия: 'Военный деятель; ' → 'Военный деятель; военнослужащий'
# [94/200] Обработка: Горшков, Владимир Павлович
#   ✓ Данные идентичны, пропускаем
# [95/200] Обработка: Горшков, Игорь Васильевич
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [96/200] Обработка: Гоэи, Антон
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [97/200] Обработка: Грабовский, Анджей
#   ✓ Данные идентичны, пропускаем
# [98/200] Обработка: Гравьер, Жюрьен де ла
#   ✓ Данные идентичны, пропускаем
# [99/200] Обработка: Грайеб, Джон
#   ↻ Обновление: профессия: 'Спортсмен; ' → 'Спортсмен; легкоатлет'
# [100/200] Обработка: Грант, Мэдисон
#   ✓ Данные идентичны, пропускаем
# [101/200] Обработка: Граудынь, Павел Владимирович
#   + Новая: Год: 2006, Профессия: Спортсмен; спортсмен
# [102/200] Обработка: Грбович, Павле
#   ✓ Данные идентичны, пропускаем
# [103/200] Обработка: Гредлер, Людвиг
#   ↻ Обновление: профессия: 'Биатлонист; ' → 'Военный деятель; солдат, биатлонист'
# [104/200] Обработка: Гречило, Андрей Богданович
#   ✓ Данные идентичны, пропускаем
# [105/200] Обработка: Григорович, Михаил Фролович
#   ✓ Данные идентичны, пропускаем
# [106/200] Обработка: Григорьев, Александр Сергеевич
#   ↻ Обновление: профессия: 'Военный деятель; ' → 'Военный деятель; офицер'
# [107/200] Обработка: Гринберг, Христина Григорьевна
#   ✓ Данные идентичны, пропускаем
# [108/200] Обработка: Гринбергс, Ояр
#   ✓ Данные идентичны, пропускаем
# [109/200] Обработка: Гриневичева, Катя
#   ✓ Данные идентичны, пропускаем
# [110/200] Обработка: Гром, Григорий Иванович
#   ✓ Данные идентичны, пропускаем
# [111/200] Обработка: Громов, Михаил Сергеевич
#   ✓ Данные идентичны, пропускаем
# [112/200] Обработка: Гроссман, Хорст
#   ✓ Данные идентичны, пропускаем
# [113/200] Обработка: Гроу, Малколм
#   ✓ Данные идентичны, пропускаем
# [114/200] Обработка: Гуляев, Анатолий Иванович
#   ↻ Обновление: профессия: 'Военный деятель; ' → 'Военный деятель
#   ↻ Обновление: профессия: 'Государственный деятель; ' → 'Военный деятель; генерал, политик'
# [191/200] Обработка: Екимов, Борис Петрович
#   ✓ Данные идентичны, пропускаем
# [192/200] Обработка: Елизавета Шарлотта Пфальцская (1597—1660)
#   ✓ Данные идентичны, пропускаем
# [193/200] Обработка: Елин, Иван Иванович
#   ✓ Данные идентичны, пропускаем
# [194/200] Обработка: Елисеев, Николай Петрович
#   ↻ Обновление: профессия: 'Персона; ' → 'Государственный деятель; депутат'
# [195/200] Обработка: Енин, Евгений Владимирович
#   ✓ Данные идентичны, пропускаем
# [196/200] Обработка: Ертысбаев, Ермухамет Кабидинович
#   ✓ Данные идентичны, пропускаем
# [197/200] Обработка: Ефрон, Илья Абрамович
#   ✓ Данные идентичны, пропускаем
# [198/200] Обработка: Жан-Мари, Оливье
#   ✓ Данные идентичны, пропускаем
# [199/200] Обработка: Жигарев, Павел Фёдорович
#   ✓ Данные идентичны, пропускаем
# [200/200] Обработка: Жовтенко, Валерий Тимофеевич
#   ↻ Обновление: год: 1957 → 1961, профессия: 'Государственный деятель; ' → 'Государственный деятель; дипломат'
#
# → Переход к следующей странице: https://ru.wikipedia.org/w/index.php?title=%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%A0%D0%BE%D0%B4%D0%B8%D0%B2%D1%88%D0%B8%D0%B5%D1%81%D1%8F_19_%D0%BD%D0%BE%D1%8F%D0%B1%D1%80%D1%8F&pagefrom=%D0%96%D1%83%D0%BA%D0%BE%D0%B2%2C+%D0%92%D0%B0%D1%81%D0%B8%D0%BB%D0%B8%D0%B9+%D0%A4%D1%91%D0%B4%D0%BE%D1%80%D0%BE%D0%B2%D0%B8%D1%87#mw-pages
#
# ============================================================
# --- Парсинг страницы 3 ---
# URL: https://ru.wikipedia.org/w/index.php?title=%D0%9A%D0%B0%D1%82%D0%B5%D0%B3%D0%BE%D1%80%D0%B8%D1%8F:%D0%A0%D0%BE%D0%B4%D0%B8%D0%B2%D1%88%D0%B8%D0%B5%D1%81%D1%8F_19_%D0%BD%D0%BE%D1%8F%D0%B1%D1%80%D1%8F&pagefrom=%D0%96%D1%83%D0%BA%D0%BE%D0%B2%2C+%D0%92%D0%B0%D1%81%D0%B8%D0%BB%D0%B8%D0%B9+%D0%A4%D1%91%D0%B4%D0%BE%D1%80%D0%BE%D0%B2%D0%B8%D1%87#mw-pages
# ============================================================
# Найдено 200 ссылок на людей на этой странице
# [1/200] Обработка: Жуков, Василий Фёдорович
#   ↻ Обновление: профессия: 'Военный деятель; ' → 'Военный деятель; майор'
# [2/200] Обработка: Жуков, Георгий Геннадьевич
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [3/200] Обработка: Жуковский, Александр Борисович
#   ✓ Данные идентичны, пропускаем
# [4/200] Обработка: Журавков, Михаил Анатольевич
#   ↻ Обновление: профессия: 'Государственный деятель; ' → 'Учёный; физик, министр'
# [5/200] Обработка: Журбина, Евгения Исааковна
#   ✓ Данные идентичны, пропускаем
# [6/200] Обработка: Жургенов, Темирбек Караевич
#   ↻ Обновление: профессия: 'Государственный деятель; ' → 'Государственный деятель
#   ↻ Обновление: профессия: 'Военный деятель; ' → 'Военный деятель; лейтенант, партизан'
# [43/200] Обработка: Иварсен, Мортен
#   ↻ Обновление: профессия: 'Спортсмен; ' → 'Спортсмен; спортсмен'
# [44/200] Обработка: Иган, Клэр
#   ↻ Обновление: профессия: 'Биатлонист; ' → 'Спортсмен; биатлонист'
# [45/200] Обработка: Иглз, Крис
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [46/200] Обработка: Игнатьев, Николай Дмитриевич (юрист)
#   ✓ Данные идентичны, пропускаем
# [47/200] Обработка: Игрушкин, Николай Анатольевич
#   ↻ Обновление: профессия: 'Спортсмен; ' → 'Спортсмен; тренер'
# [48/200] Обработка: Изз ад-Дин аль-Кассам
#   ✓ Данные идентичны, пропускаем
# [49/200] Обработка: Илен, Шарлотт
#   + Новая: Год: 1839, Профессия: Врач; врач
# [50/200] Обработка: Илер, Пьер-Мари
#   ↻ Обновление: профессия: 'Легкоатлет; ' → 'Спортсмен; легкоатлет'
# [51/200] Обработка: Илларионов, Дмитрий Николаевич
#   ✓ Данные идентичны, пропускаем
# [52/200] Обработка: Иллигер, Иоганн Карл Вильгельм
#   ✓ Данные идентичны, пропускаем
# [53/200] Обработка: Илугдин, Григорий Львович
#   ✓ Данные идентичны, пропускаем
# [54/200] Обработка: Ильюхина, Мария Сергеевна
#   ✓ Данные идентичны, пропускаем
# [55/200] Обработка: Имаи, Кэйдзо
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [56/200] Обработка: Имас, Александр Давидович
#   ✓ Данные идентичны, пропускаем
# [57/200] Обработка: Инграм, Рой
#   + Новая: Год: 1900, Профессия: Спортсмен; боксёр
# [58/200] Обработка: Инзаркин, Дмитрий Викторович
#   ↻ Обновление: профессия: 'Спортсмен; ' → 'Спортсмен; спортсмен'
# [59/200] Обработка: Инклан, Лили
#   ↻ Обновление: год: 1918 → 2003
# [60/200] Обработка: Иовчук, Михаил Трифонович
#   ✓ Данные идентичны, пропускаем
# [61/200] Обработка: Ипполитов-Иванов, Михаил Михайлович
#   ↻ Обновление: год: 1859 → 1881
# [62/200] Обработка: Искаков, Ахмеди Искакович
#   ✓ Данные идентичны, пропускаем
# [63/200] Обработка: Ихике, Мэри
#   ↻ Обновление: профессия: 'Легкоатлет; ' → 'Спортсмен; легкоатлет'
# [64/200] Обработка: Йенсен, Давид Иванович
#   ✓ Данные идентичны, пропускаем
# [65/200] Обработка: Йокубайтис, Рокас
#   + Новая: Год: 2000, Профессия: Спортсмен; баскетболист
# [66/200] Обработка: Йоците, Юсте
#   ↻ Обновление: профессия: 'Баскетболист; ' → 'Спортсмен; баскетболист'
# [67/200] Обработка: Кавос, Цезарь Альбертович
#   ↻ Обновление: профессия: 'Архитектор; ' → 'Художник; архитектор'
# [68/200] Обработка: Каган, Анатолий Владимирович
#   ✓ Данные идентичны, пропускаем
# [69/200] Обработка: Кадльсберг, Анфинн
#   ↻ Обновление: профессия: 'Государственный деятель; ' → 'Государственный деятель; депутат'
# [70/200] Обработка: Казакбаев, Владимир Манзурович
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [71/200] Обработка: Казакул, Анастасия Валерьевна
#   ↻ Обновление: профессия: 'Лыжник; ' → 'Спортсмен; лыжник'
# [72/200] Обработка: Кайе, Рене
#   ✓ Данные идентичны, пропускаем
# [73/200] Обработка: Кайперт, Гельмут
#   ✓ Данные идентичны, пропускаем
# [74/200] Обработка: Калашник, Григорий Иванович
#   ✓ Данные идентичны, пропускаем
# [75/200] Обработка: Калеников, Иван Емельянович
#   ✓ Данные идентичны, пропускаем
# [76/200] Обработка: Калинин, Михаил Иванович
#   ↻ Обновление: профессия: 'Государственный деятель; ' → 'Инженер; инженер, политик'
# [77/200] Обработка: Калнин, Карл Иванович
#   ✓ Данные идентичны, пропускаем
# [78/200] Обработка: Камга, Ванесса
#   ↻ Обновление: профессия: 'Легкоатлет; ' → 'Спортсмен; легкоатлет'
# [79/200] Обработка: Камино, Рене
#   ↻ Обновление: профессия: 'Баскетболист; ' → 'Спортсмен; баскетболист'
# [80/200] Обработка: Кампанелла, Рой
#   ↻ Обновление: профессия: 'Бейсболист; ' → 'Спортсмен; бейсболист'
# [81/200] Обработка: Кандаратский, Михаил Фёдорович
#   ✓ Данные идентичны, пропускаем
# [82/200] Обработка: Канер, Эмануил Айзикович
#   ✓ Данные идентичны, пропускаем
# [83/200] Обработка: Кантор, Норман
#   ✓ Данные идентичны, пропускаем
# [84/200] Обработка: Кантор, Юрий Израилевич
#   ✓ Данные идентичны, пропускаем
# [85/200] Обработка: Капабланка, Хосе Рауль
#   ✓ Данные идентичны, пропускаем
# [86/200] Обработка: Капка, Дмитрий Леонтьевич
#   ✓ Данные идентичны, пропускаем
# [87/200] Обработка: Джун Каприс
#   ✓ Данные идентичны, пропускаем
# [88/200] Обработка: Карабин, Ярослав Миронович
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [89/200] Обработка: Кареев, Андрей Андреевич
#   ↻ Обновление: профессия: 'Хоккеист; ' → 'Учёный; химик, хоккеист'
# [90/200] Обработка: Карецас, Константинос
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [91/200] Обработка: Кари, Эман
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [92/200] Обработка: Карл (герцог Саксен-Мейнингена)
#   ✓ Данные идентичны, пропускаем
# [93/200] Обработка: Нунес да Силва, Луис Карлос
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [94/200] Обработка: Карлсон, Джейн
#   ↻ Обновление: год: n/a → 1918
# [95/200] Обработка: Кармина, Роса
#   ✓ Данные идентичны, пропускаем
# [96/200] Обработка: Каролат-Бейтен, Элизабет цу
#   ✓ Данные идентичны, пропускаем
# [97/200] Обработка: Карпов, Николай Васильевич
#   ✓ Данные идентичны, пропускаем
# [98/200] Обработка: Карри, Энн
#   ✓ Данные идентичны, пропускаем
# [99/200] Обработка: Каррингтон, Билли
#   ✓ Данные идентичны, пропускаем
# [100/200] Обработка: Карсон, Терренс
#   ✓ Данные идентичны, пропускаем
# [101/200] Обработка: Кастельжо, Поль де
#   ✓ Данные идентичны, пропускаем
# [102/200] Обработка: Кастильо, Леннокс
#   + Новая: Год: 1985, Профессия: Спортсмен; футболист
# [103/200] Обработка: Катеринчук, Николай Дмитриевич
#   ✓ Данные идентичны, пропускаем
# [104/200] Обработка: Катола, Элио
#   + Новая: Год: None, Профессия: Спортсмен; легкоатлет
# [105/200] Обработка: Кауки, Гайя
#   ✓ Данные идентичны, пропускаем
# ...
# ============================================================
# Найдено 172 ссылок на людей на этой странице
# [1/172] Обработка: Фридрих I (пфальцграф Зиммерна)
#   ↻ Обновление: профессия: 'Государственный деятель; ' → 'Государственный деятель; государственный деятель'
# [2/172] Обработка: Фридрих II (курфюрст Бранденбурга)
#   ✓ Данные идентичны, пропускаем
# [3/172] Обработка: Фримен, Джеймс Дарси
#   ✓ Данные идентичны, пропускаем
# [4/172] Обработка: Фудра, Антуан Казимир
#   ✓ Данные идентичны, пропускаем
# [5/172] Обработка: Фурнье, Анри (издатель)
#   ✓ Данные идентичны, пропускаем
# [6/172] Обработка: Фуруи, Ёсикити
#   ✓ Данные идентичны, пропускаем
# [7/172] Обработка: Фусиле, Хорхе
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
#
#   ✓ Данные идентичны, пропускаем
# [112/172] Обработка: Шморанц, Франтишек (младший)
#   ✓ Данные идентичны, пропускаем
# [113/172] Обработка: Шошкич, Бранислав
#   ✓ Данные идентичны, пропускаем
# [114/172] Обработка: Шрумпф, Августа
#   ✓ Данные идентичны, пропускаем
# [115/172] Обработка: Штадтфельд, Мартин
#   ✓ Данные идентичны, пропускаем
# [116/172] Обработка: Штельмахерс, Робертс
#   + Новая: Год: 1974, Профессия: Спортсмен; тренер
# [117/172] Обработка: Штефэнеску, Оана
#   ✓ Данные идентичны, пропускаем
# [118/172] Обработка: Штокхофф, Артур
#   ↻ Обновление: год: n/a → 1879
# [119/172] Обработка: Штольцман, Ян
#   ✓ Данные идентичны, пропускаем
# [120/172] Обработка: Штурм, Ифке
#   ✓ Данные идентичны, пропускаем
# [121/172] Обработка: Шуба, Николай Михайлович
#   ↻ Обновление: профессия: 'Государственный деятель; ' → 'Государственный деятель; депутат'
# [122/172] Обработка: Шубик, Франтишек
#   ✓ Данные идентичны, пропускаем
# [123/172] Обработка: Шулек, Фридьеш
#   ↻ Обновление: профессия: 'Архитектор; ' → 'Художник; архитектор'
# [124/172] Обработка: Щеглов, Борис Григорьевич
#   ✓ Данные идентичны, пропускаем
# [125/172] Обработка: Щепкин, Герман Яковлевич
#   ✓ Данные идентичны, пропускаем
# [126/172] Обработка: Щербаков, Игорь Владимирович
#   ✓ Данные идентичны, пропускаем
# [127/172] Обработка: Эггерт, Виктор Викторович
#   + Новая: Год: 1867, Профессия: Военный деятель; офицер
# [128/172] Обработка: Эдвардс, Отелли
#   + Новая: Год: None, Профессия: Писатель; журналист
# [129/172] Обработка: Эжен де Мирекур
#   ✓ Данные идентичны, пропускаем
# [130/172] Обработка: Экман, Отто
#   ✓ Данные идентичны, пропускаем
# [131/172] Обработка: Эллингсон, Линдсей
#   ✓ Данные идентичны, пропускаем
# [132/172] Обработка: Эллиотт, Уолтер (звуковой монтажёр)
#   ✓ Данные идентичны, пропускаем
# [133/172] Обработка: Эльвар, Антуан
#   ✓ Данные идентичны, пропускаем
# [134/172] Обработка: Энао, Рауль Фернандо
#   ↻ Обновление: профессия: 'Шахматист; ' → 'Спортсмен; шахматист'
# [135/172] Обработка: Эндикотт, Уильям Кроуниншилд
#   ↻ Обновление: профессия: 'Государственный деятель; ' → 'Государственный деятель; политик'
# [136/172] Обработка: Эндрюс, Шелли
#   ↻ Обновление: профессия: 'Спортсмен; ' → 'Спортсмен; хоккеист'
# [137/172] Обработка: Эттингер, Курт
#   ↻ Обновление: профессия: 'Спортсмен; ' → 'Спортсмен; спортсмен'
# [138/172] Обработка: Юденич, Михаил Семёнович
#   ✓ Данные идентичны, пропускаем
# [139/172] Обработка: Юргенс, Йохан
#   ✓ Данные идентичны, пропускаем
# [140/172] Обработка: Юрлов, Никита Александрович
#   ↻ Обновление: профессия: 'Игрок в хоккей с мячом; ' → 'Спортсмен; хоккеист'
# [141/172] Обработка: Юшкевич, Дмитрий Сергеевич
#   ↻ Обновление: профессия: 'Хоккеист; ' → 'Спортсмен; тренер'
# [142/172] Обработка: Ющенко, Александр Андреевич
#   ↻ Обновление: профессия: 'Государственный деятель; ' → 'Государственный деятель; депутат'
# [143/172] Обработка: Ягода, Генрих Григорьевич
#   ↻ Обновление: год: n/a → 1891, профессия: 'Государственный деятель; ' → 'Военный деятель; военнослужащий, политик, филателист'
# [144/172] Обработка: Якимов, Олег Дмитриевич
#   ✓ Данные идентичны, пропускаем
# [145/172] Обработка: Якимчук, Любовь Васильевна
#   ✓ Данные идентичны, пропускаем
# [146/172] Обработка: Якобсен, Мими
#   + Новая: Год: 1948, Профессия: Государственный деятель; политик
# [147/172] Обработка: Яковлев, Михаил Семёнович
#   + Новая: Год: None, Профессия: Учёный; биолог
# [148/172] Обработка: Ямагути, Тосихиро
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [149/172] Обработка: Ямада, Юмико
#   ↻ Обновление: профессия: 'Конькобежец; ' → 'Спортсмен; конькобежец'
# [150/172] Обработка: Янаш, Петш
#   ✓ Данные идентичны, пропускаем
# [151/172] Обработка: Янбаев, Шакир Махиянович
#   ✓ Данные идентичны, пропускаем
# [152/172] Обработка: Янг, Алан
#   ✓ Данные идентичны, пропускаем
# [153/172] Обработка: Янковская, Юлия Викторовна
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [154/172] Обработка: Янковски, Джордж
#   ↻ Обновление: профессия: 'Бейсболист; ' → 'Спортсмен; бейсболист'
# [155/172] Обработка: Янович, Анатолий Кузьмич
#   ✓ Данные идентичны, пропускаем
# [156/172] Обработка: Япи, Даррен
#   ↻ Обновление: профессия: 'Футболист; ' → 'Спортсмен; футболист'
# [157/172] Обработка: Яремийчук, Роман Семёнович
#   ✓ Данные идентичны, пропускаем
# [158/172] Обработка: Яркин, Вячеслав Георгиевич
#   ↻ Обновление: профессия: 'Спортсмен; ' → 'Спортсмен; спортсмен'
# [159/172] Обработка: Яровой, Геннадий Петрович
#   ✓ Данные идентичны, пропускаем
# [160/172] Обработка: Яуналксне-Редере, Илзе
#   ✓ Данные идентичны, пропускаем
# [161/172] Обработка: Яхьяев, Кудратулло
#   ✓ Данные идентичны, пропускаем
# [162/172] Обработка: Blago White
#   ✓ Данные идентичны, пропускаем
# [163/172] Обработка: Cam
#   ✓ Данные идентичны, пропускаем
# [164/172] Обработка: DJ Тенгиз
#   ✓ Данные идентичны, пропускаем
# [165/172] Обработка: Dubee
#   ✓ Данные идентичны, пропускаем
# [166/172] Обработка: E-Moneybags
#   ✓ Данные идентичны, пропускаем
# [167/172] Обработка: Eek-A-Mouse
#   ✓ Данные идентичны, пропускаем
# [168/172] Обработка: Profit (киберспортсмен)
#   + Новая: Год: 1999, Профессия: Спортсмен; спортсмен
# [169/172] Обработка: Rollergirl
#   ✓ Данные идентичны, пропускаем
# [170/172] Обработка: Skerik
#   + Новая: Год: None, Профессия: Музыкант; саксофонист
# [171/172] Обработка: Teloch
#   ✓ Данные идентичны, пропускаем
# [172/172] Обработка: Tyga
#   ✓ Данные идентичны, пропускаем
#
# → Следующих страниц не найдено, завершаем парсинг.
#
# ============================================================
# === Парсинг завершен ===
# Всего страниц запарсено: 7
# Всего персон обработано: 1372
# Всего новых персон: 73
# Всего обновлено (отличающиеся данные): 537
# Всего пропущено (идентичные данные): 762
# Всего не удалось извлечь: 0
# ============================================================
# Written 610 persons to qyy1119.xml
#
# ✓ Успешно записано 610 персон в qyy1119.xml
